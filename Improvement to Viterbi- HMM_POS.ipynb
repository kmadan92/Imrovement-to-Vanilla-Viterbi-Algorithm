# %% [markdown]
# ## POS tagging using modified Viterbi

# %% [markdown]
# ### Data Preparation

# %%
#Importing libraries
import nltk
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
import random
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.tokenize import sent_tokenize
from collections import Counter

# %%
# Import test sentence file

test_file = pd.read_csv('Test_sentences.txt', sep='\n', names=['Message'])

# %%
test_file
# Out:
#                                               Message
# 0   Android is a mobile operating system developed...
# 1   Android has been the best-selling OS worldwide...
# 2   Google and Twitter made a deal in 2015 that ga...
# 3   Twitter is an online news and social networkin...
# 4   Before entering politics, Donald Trump was a d...
# 5   The 2018 FIFA World Cup is the 21st FIFA World...
# 6   This is the first World Cup to be held in East...
# 7   Show me the cheapest round trips from Dallas t...
# 8   I would like to see flights from Denver to Phi...
# 9   Show me the price of the flights leaving Atlan...
# 10  NASA invited social media users to experience ...

# %%
# Tokenizing Sentence
tokens = list(test_file['Message'].apply(word_tokenize))

# %%
tokens
# Out:
# [['Android',
#   'is',
#   'a',
#   'mobile',
#   'operating',
#   'system',
#   'developed',
#   'by',
#   'Google',
#   '.'],
#  ['Android',
#   'has',
#   'been',
#   'the',
#   'best-selling',
#   'OS',
#   'worldwide',
#   'on',
#   'smartphones',
#   'since',
#   '2011',
#   'and',
#   'on',
#   'tablets',
#   'since',
#   '2013',
#   '.'],
#  ['Google',
#   'and',
#   'Twitter',
#   'made',
#   'a',
#   'deal',
#   'in',
#   '2015',
#   'that',
#   'gave',
#   'Google',
#   'access',
#   'to',
#   'Twitter',
#   "'s",
#   'firehose',
#   '.'],
#  ['Twitter',
#   'is',
#   'an',
#   'online',
#   'news',
#   'and',
#   'social',
#   'networking',
#   'service',
#   'on',
#   'which',
#   'users',
#   'post',
#   'and',
#   'interact',
#   'with',
#   'messages',
#   'known',
#   'as',
#   'tweets',
#   '.'],
#  ['Before',
#   'entering',
#   'politics',
#   ',',
#   'Donald',
#   'Trump',
#   'was',
#   'a',
#   'domineering',
#   'businessman',
#   'and',
#   'a',
#   'television',
#   'personality',
#   '.'],
#  ['The',
#   '2018',
#   'FIFA',
#   'World',
#   'Cup',
#   'is',
#   'the',
#   '21st',
#   'FIFA',
#   'World',
#   'Cup',
#   ',',
#   'an',
#   'international',
#   'football',
#   'tournament',
#   'contested',
#   'once',
#   'every',
#   'four',
#   'years',
#   '.'],
#  ['This',
#   'is',
#   'the',
#   'first',
#   'World',
#   'Cup',
#   'to',
#   'be',
#   'held',
#   'in',
#   'Eastern',
#   'Europe',
#   'and',
#   'the',
#   '11th',
#   'time',
#   'that',
#   'it',
#   'has',
#   'been',
#   'held',
#   'in',
#   'Europe',
#   '.'],
#  ['Show',
#   'me',
#   'the',
#   'cheapest',
#   'round',
#   'trips',
#   'from',
#   'Dallas',
#   'to',
#   'Atlanta'],
#  ['I',
#   'would',
#   'like',
#   'to',
#   'see',
#   'flights',
#   'from',
#   'Denver',
#   'to',
#   'Philadelphia',
#   '.'],
#  ['Show',
#   'me',
#   'the',
#   'price',
#   'of',
#   'the',
#   'flights',
#   'leaving',
#   'Atlanta',
#   'at',
#   'about',
#   '3',
#   'in',
#   'the',
#   'afternoon',
#   'and',
#   'arriving',
#   'in',
#   'San',
#   'Francisco',
#   '.'],
#  ['NASA',
#   'invited',
#   'social',
#   'media',
#   'users',
#   'to',
#   'experience',
#   'the',
#   'launch',
#   'of',
#   'ICESAT-2',
#   'Satellite',
#   '.']]

# %%
word_list = [t for tk in tokens for t in tk]

# %%
word_list
# Out:
# ['Android',
#  'is',
#  'a',
#  'mobile',
#  'operating',
#  'system',
#  'developed',
#  'by',
#  'Google',
#  '.',
#  'Android',
#  'has',
#  'been',
#  'the',
#  'best-selling',
#  'OS',
#  'worldwide',
#  'on',
#  'smartphones',
#  'since',
#  '2011',
#  'and',
#  'on',
#  'tablets',
#  'since',
#  '2013',
#  '.',
#  'Google',
#  'and',
#  'Twitter',
#  'made',
#  'a',
#  'deal',
#  'in',
#  '2015',
#  'that',
#  'gave',
#  'Google',
#  'access',
#  'to',
#  'Twitter',
#  "'s",
#  'firehose',
#  '.',
#  'Twitter',
#  'is',
#  'an',
#  'online',
#  'news',
#  'and',
#  'social',
#  'networking',
#  'service',
#  'on',
#  'which',
#  'users',
#  'post',
#  'and',
#  'interact',
#  'with',
#  'messages',
#  'known',
#  'as',
#  'tweets',
#  '.',
#  'Before',
#  'entering',
#  'politics',
#  ',',
#  'Donald',
#  'Trump',
#  'was',
#  'a',
#  'domineering',
#  'businessman',
#  'and',
#  'a',
#  'television',
#  'personality',
#  '.',
#  'The',
#  '2018',
#  'FIFA',
#  'World',
#  'Cup',
#  'is',
#  'the',
#  '21st',
#  'FIFA',
#  'World',
#  'Cup',
#  ',',
#  'an',
#  'international',
#  'football',
#  'tournament',
#  'contested',
#  'once',
#  'every',
#  'four',
#  'years',
#  '.',
#  'This',
#  'is',
#  'the',
#  'first',
#  'World',
#  'Cup',
#  'to',
#  'be',
#  'held',
#  'in',
#  'Eastern',
#  'Europe',
#  'and',
#  'the',
#  '11th',
#  'time',
#  'that',
#  'it',
#  'has',
#  'been',
#  'held',
#  'in',
#  'Europe',
#  '.',
#  'Show',
#  'me',
#  'the',
#  'cheapest',
#  'round',
#  'trips',
#  'from',
#  'Dallas',
#  'to',
#  'Atlanta',
#  'I',
#  'would',
#  'like',
#  'to',
#  'see',
#  'flights',
#  'from',
#  'Denver',
#  'to',
#  'Philadelphia',
#  '.',
#  'Show',
#  'me',
#  'the',
#  'price',
#  'of',
#  'the',
#  'flights',
#  'leaving',
#  'Atlanta',
#  'at',
#  'about',
#  '3',
#  'in',
#  'the',
#  'afternoon',
#  'and',
#  'arriving',
#  'in',
#  'San',
#  'Francisco',
#  '.',
#  'NASA',
#  'invited',
#  'social',
#  'media',
#  'users',
#  'to',
#  'experience',
#  'the',
#  'launch',
#  'of',
#  'ICESAT-2',
#  'Satellite',
#  '.']

# %%
word_list=list(set(word_list))

# %%
word_list
# Out:
# ['with',
#  '2018',
#  'as',
#  'NASA',
#  'and',
#  ',',
#  'flights',
#  'at',
#  'mobile',
#  'system',
#  'Dallas',
#  '2011',
#  'Francisco',
#  'Eastern',
#  'experience',
#  'I',
#  'tournament',
#  'ICESAT-2',
#  'businessman',
#  'has',
#  'tablets',
#  'operating',
#  'access',
#  'first',
#  'service',
#  'Donald',
#  '2015',
#  'to',
#  'interact',
#  'which',
#  'launch',
#  'round',
#  'Philadelphia',
#  'San',
#  'best-selling',
#  'domineering',
#  'Before',
#  'once',
#  'time',
#  'Android',
#  'see',
#  'been',
#  'known',
#  'developed',
#  'in',
#  'made',
#  'gave',
#  'international',
#  'it',
#  'social',
#  'Atlanta',
#  "'s",
#  'would',
#  'was',
#  'me',
#  'Cup',
#  'contested',
#  'about',
#  'afternoon',
#  'post',
#  'deal',
#  'invited',
#  'by',
#  'FIFA',
#  'trips',
#  'Trump',
#  'This',
#  'users',
#  'television',
#  'Satellite',
#  'cheapest',
#  'tweets',
#  'politics',
#  'football',
#  'is',
#  'leaving',
#  'media',
#  '11th',
#  'price',
#  '3',
#  'World',
#  'that',
#  'Twitter',
#  'Google',
#  'messages',
#  'the',
#  'held',
#  'smartphones',
#  '21st',
#  'a',
#  'personality',
#  'every',
#  'since',
#  '2013',
#  'Denver',
#  'arriving',
#  'The',
#  'worldwide',
#  'like',
#  'Show',
#  'of',
#  'be',
#  'entering',
#  'OS',
#  'on',
#  'firehose',
#  'an',
#  'Europe',
#  'news',
#  'years',
#  'four',
#  'from',
#  '.',
#  'online',
#  'networking']

# %%
# reading the Treebank tagged words
nltk_data = list(nltk.corpus.treebank.tagged_words(tagset='universal'))

# %%
# Splitting into train and test
random.seed(1234)
train_set, test_set = train_test_split(nltk_data,test_size=0.05)

# %%
train_set
# Out:
# [('.', '.'),
#  ('an', 'DET'),
#  ('enters', 'VERB'),
#  (':', '.'),
#  ('*-1', 'X'),
#  ('Georgia', 'NOUN'),
#  ('.', '.'),
#  ('*-1', 'X'),
#  ('with', 'ADP'),
#  ('would', 'VERB'),
#  ('San', 'NOUN'),
#  ('of', 'ADP'),
#  ('at', 'ADP'),
#  ('.', '.'),
#  ('have', 'VERB'),
#  ('stock', 'NOUN'),
#  ('.', '.'),
#  ('government', 'NOUN'),
#  ('you', 'PRON'),
#  ('troubles', 'NOUN'),
#  ('In', 'ADP'),
#  ('owner', 'NOUN'),
#  ('.', '.'),
#  ('Research', 'NOUN'),
#  ('take', 'VERB'),
#  ('The', 'DET'),
#  ('futures', 'NOUN'),
#  ('eliminates', 'VERB'),
#  ('and', 'CONJ'),
#  ('.', '.'),
#  ('also', 'ADV'),
#  ('are', 'VERB'),
#  ('forward', 'ADV'),
#  (',', '.'),
#  ('Treasury', 'NOUN'),
#  (',', '.'),
#  ('that', 'DET'),
#  ('discuss', 'VERB'),
#  (',', '.'),
#  ('of', 'ADP'),
#  ('5.70', 'NUM'),
#  ('issues', 'NOUN'),
#  ('growing', 'VERB'),
#  ('lower', 'ADJ'),
#  ('gain', 'NOUN'),
#  ('Washington', 'NOUN'),
#  ('measurement', 'NOUN'),
#  ('bid', 'NOUN'),
#  ('stop', 'VERB'),
#  ('*T*-1', 'X'),
#  ('3', 'NUM'),
#  ('and', 'CONJ'),
#  ('the', 'DET'),
#  ("'s", 'PRT'),
#  ('the', 'DET'),
#  ('*-1', 'X'),
#  ('.', '.'),
#  ('*U*', 'X'),
#  ('*U*', 'X'),
#  ('is', 'VERB'),
#  ('it', 'PRON'),
#  ('catch', 'NOUN'),
#  ('$', '.'),
#  ('estimates', 'NOUN'),
#  ('INTER-TEL', 'NOUN'),
#  ('each', 'DET'),
#  ('under', 'ADP'),
#  ('of', 'ADP'),
#  ('investor', 'NOUN'),
#  ('$', '.'),
#  ('into', 'ADP'),
#  ('.', '.'),
#  (',', '.'),
#  ('authority', 'NOUN'),
#  ('gives', 'VERB'),
#  ('of', 'ADP'),
#  ('.', '.'),
#  ('were', 'VERB'),
#  ('share', 'NOUN'),
#  ('of', 'ADP'),
#  ('0', 'X'),
#  ('1986', 'NUM'),
#  ('shows', 'VERB'),
#  ('Robert', 'NOUN'),
#  ('.', '.'),
#  ('will', 'VERB'),
#  (':', '.'),
#  ('Food', 'NOUN'),
#  ('said', 'VERB'),
#  ('%', 'NOUN'),
#  ('the', 'DET'),
#  ('*T*-1', 'X'),
#  ('be', 'VERB'),
#  ('lose', 'VERB'),
#  ('expected', 'VERB'),
#  ('leaders', 'NOUN'),
#  ('2.75', 'NUM'),
#  ('after', 'ADP'),
#  ('them', 'PRON'),
#  ('who', 'PRON'),
#  ('these', 'DET'),
#  ('-LRB-', '.'),
#  ('*-1', 'X'),
#  ('the', 'DET'),
#  ('Two', 'NUM'),
#  ('Loan', 'NOUN'),
#  ('European', 'ADJ'),
#  ('a', 'DET'),
#  ('prices', 'NOUN'),
#  ('*-1', 'X'),
#  ('shared', 'VERB'),
#  ('of', 'ADP'),
#  ('exchange', 'NOUN'),
#  ('Bill', 'NOUN'),
#  (',', '.'),
#  ('in', 'ADP'),
#  ('0', 'X'),
#  ('expect', 'VERB'),
#  ('pass', 'VERB'),
#  ('at', 'ADP'),
#  (',', '.'),
#  ('said', 'VERB'),
#  ('million', 'NUM'),
#  (',', '.'),
#  ('act', 'NOUN'),
#  ('business', 'NOUN'),
#  ('more', 'ADV'),
#  ('after', 'ADV'),
#  ('aid', 'NOUN'),
#  ('the', 'DET'),
#  ('.', '.'),
#  ('needed', 'VERB'),
#  ('Both', 'DET'),
#  ('fourth', 'ADJ'),
#  ('*T*-1', 'X'),
#  ('to', 'PRT'),
#  ('it', 'PRON'),
#  ('mutual', 'ADJ'),
#  ('people', 'NOUN'),
#  ('wine', 'NOUN'),
#  ('Fla.', 'NOUN'),
#  ('*', 'X'),
#  ('during', 'ADP'),
#  ('group', 'NOUN'),
#  ('on', 'ADP'),
#  ('of', 'ADP'),
#  ('0', 'X'),
#  ('other', 'ADJ'),
#  ('legislature', 'NOUN'),
#  ('But', 'CONJ'),
#  ('crippled', 'VERB'),
#  (',', '.'),
#  ('vice', 'NOUN'),
#  ('surprising', 'ADJ'),
#  ('visit', 'NOUN'),
#  ('*-2', 'X'),
#  ('...', '.'),
#  ('And', 'CONJ'),
#  ('a', 'DET'),
#  ('shares', 'NOUN'),
#  ('confirmed', 'VERB'),
#  ('.', '.'),
#  ('scheduled', 'VERB'),
#  ('be', 'VERB'),
#  ('at', 'ADP'),
#  ('*T*-1', 'X'),
#  ('production', 'NOUN'),
#  ('before', 'ADV'),
#  ('for', 'ADP'),
#  ('Schroder', 'NOUN'),
#  (',', '.'),
#  ('.', '.'),
#  ('the', 'DET'),
#  ('Possibly', 'ADV'),
#  ('.', '.'),
#  ('hit', 'VERB'),
#  ('River', 'NOUN'),
#  ('was', 'VERB'),
#  ('billion', 'NUM'),
#  ('12-point', 'ADJ'),
#  ('at', 'ADP'),
#  (',', '.'),
#  (',', '.'),
#  ('it', 'PRON'),
#  ('silent', 'ADJ'),
#  ('the', 'DET'),
#  ('examined', 'VERB'),
#  ('says', 'VERB'),
#  ('from', 'ADP'),
#  ('Japan', 'NOUN'),
#  ('have', 'VERB'),
#  ('.', '.'),
#  ("'s", 'PRT'),
#  ('sell', 'VERB'),
#  ('last', 'ADJ'),
#  ('class', 'NOUN'),
#  ('to', 'PRT'),
#  ('million', 'NUM'),
#  ('electronic', 'ADJ'),
#  ('reinstatement', 'NOUN'),
#  ('inherited', 'VERB'),
#  ('stay', 'VERB'),
#  ('that', 'ADP'),
#  ('At', 'ADP'),
#  ('argued', 'VERB'),
#  ('Mrs.', 'NOUN'),
#  ('0', 'X'),
#  ('senior', 'ADJ'),
#  ('firms', 'NOUN'),
#  ('issue', 'NOUN'),
#  ('forms', 'NOUN'),
#  ('*T*-1', 'X'),
#  ('brought', 'VERB'),
#  ('1989', 'NUM'),
#  ('government', 'NOUN'),
#  ("''", '.'),
#  ('the', 'DET'),
#  ('which', 'DET'),
#  ('and', 'CONJ'),
#  ('all', 'DET'),
#  ('*', 'X'),
#  ('according', 'VERB'),
#  ('light', 'NOUN'),
#  ("''", '.'),
#  ('.', '.'),
#  ('City', 'NOUN'),
#  ('volume', 'NOUN'),
#  ('Italian', 'ADJ'),
#  ('the', 'DET'),
#  ('skip', 'VERB'),
#  ('and', 'CONJ'),
#  ('back', 'ADV'),
#  ('serve', 'VERB'),
#  ('and', 'CONJ'),
#  ('there', 'DET'),
#  (',', '.'),
#  ('above', 'ADP'),
#  (',', '.'),
#  ('dinosaurs', 'NOUN'),
#  ('had', 'VERB'),
#  ('controls', 'NOUN'),
#  ('The', 'DET'),
#  ('its', 'PRON'),
#  ('image', 'NOUN'),
#  ('blocked', 'VERB'),
#  ('trading', 'NOUN'),
#  ('assessed', 'VERB'),
#  ('he', 'PRON'),
#  ('0', 'X'),
#  ('the', 'DET'),
#  ('its', 'PRON'),
#  ('acting', 'ADJ'),
#  ('its', 'PRON'),
#  ('were', 'VERB'),
#  ('structures', 'NOUN'),
#  ('1990', 'NUM'),
#  ('Mr.', 'NOUN'),
#  ('who', 'PRON'),
#  ('Mrs.', 'NOUN'),
#  ('says', 'VERB'),
#  ('to', 'PRT'),
#  ('to', 'PRT'),
#  ('*U*', 'X'),
#  ('Communication', 'NOUN'),
#  ('financial-services', 'ADJ'),
#  ('has', 'VERB'),
#  ('using', 'VERB'),
#  ('decided', 'VERB'),
#  ('``', '.'),
#  ('the', 'DET'),
#  ('legislation', 'NOUN'),
#  ('of', 'ADP'),
#  ('.', '.'),
#  (',', '.'),
#  ('the', 'DET'),
#  ('An', 'DET'),
#  ('from', 'ADP'),
#  ('for', 'ADP'),
#  ('Ensrud', 'NOUN'),
#  ('*T*-1', 'X'),
#  ('you', 'PRON'),
#  ('depressed', 'VERB'),
#  ('be', 'VERB'),
#  ('veto', 'VERB'),
#  ('California', 'NOUN'),
#  ('had', 'VERB'),
#  ('Louis', 'NOUN'),
#  ('``', '.'),
#  (',', '.'),
#  ('``', '.'),
#  ('*?*', 'X'),
#  (',', '.'),
#  ('Austin', 'NOUN'),
#  ('came', 'VERB'),
#  ('the', 'DET'),
#  ('stake', 'NOUN'),
#  ('Phelan', 'NOUN'),
#  ('I', 'PRON'),
#  ('good', 'ADJ'),
#  ('.', '.'),
#  ('who', 'PRON'),
#  ('I', 'NOUN'),
#  ('farmers', 'NOUN'),
#  ('for', 'ADP'),
#  ('of', 'ADP'),
#  ('with', 'ADP'),
#  ('*-1', 'X'),
#  ('$', '.'),
#  ('*-47', 'X'),
#  ('*-1', 'X'),
#  ('succeeded', 'VERB'),
#  ('latest', 'ADJ'),
#  ('Association', 'NOUN'),
#  ('funds', 'NOUN'),
#  ('``', '.'),
#  ('for', 'ADP'),
#  ('arbitrage', 'NOUN'),
#  ('of', 'ADP'),
#  ('15', 'NUM'),
#  ('%', 'NOUN'),
#  ('recent', 'ADJ'),
#  ('telecommunications', 'NOUN'),
#  ('dozens', 'NOUN'),
#  ('drooled', 'VERB'),
#  ('*', 'X'),
#  ('has', 'VERB'),
#  ('off', 'PRT'),
#  ('offer', 'NOUN'),
#  ('.', '.'),
#  ('wheels', 'NOUN'),
#  ('cut', 'VERB'),
#  (',', '.'),
#  ('beautiful', 'ADJ'),
#  ('an', 'DET'),
#  ('90', 'NUM'),
#  ('with', 'ADP'),
#  ('agreement', 'NOUN'),
#  ('Indeed', 'ADV'),
#  ('supercomputer', 'NOUN'),
#  ('council', 'NOUN'),
#  ('of', 'ADP'),
#  ('*T*-1', 'X'),
#  ('have', 'VERB'),
#  ('stock', 'NOUN'),
#  ('7.40', 'NUM'),
#  ('would', 'VERB'),
#  ('0', 'X'),
#  ('if', 'ADP'),
#  ('Gerald', 'NOUN'),
#  ('Korea', 'NOUN'),
#  ('detail', 'NOUN'),
#  ('is', 'VERB'),
#  ('reports', 'NOUN'),
#  ('the', 'DET'),
#  ('passions', 'NOUN'),
#  ('is', 'VERB'),
#  ('refunding', 'NOUN'),
#  ('Nekoosa', 'NOUN'),
#  (',', '.'),
#  ('Barbaresco', 'NOUN'),
#  ('4.3', 'NUM'),
#  ('to', 'PRT'),
#  ('particularly', 'ADV'),
#  ('There', 'DET'),
#  ('and', 'CONJ'),
#  ('*-1', 'X'),
#  ('scientists', 'NOUN'),
#  ('the', 'DET'),
#  (',', '.'),
#  ("''", '.'),
#  ('through', 'ADP'),
#  ('Financial', 'NOUN'),
#  ('trades', 'NOUN'),
#  ('0', 'X'),
#  ('chauffeur', 'NOUN'),
#  ('*-1', 'X'),
#  ('disappointing', 'ADJ'),
#  ('riskier', 'ADJ'),
#  ("''", '.'),
#  ('restrictions', 'NOUN'),
#  ('fail', 'VERB'),
#  ('to', 'PRT'),
#  ('Strong', 'ADJ'),
#  ('and', 'CONJ'),
#  ('to', 'PRT'),
#  ('the', 'DET'),
#  ('0', 'X'),
#  ('return', 'NOUN'),
#  ('fell', 'VERB'),
#  ('Democrats', 'NOUN'),
#  ('fine', 'NOUN'),
#  ('and', 'CONJ'),
#  ('is', 'VERB'),
#  ('But', 'CONJ'),
#  ('is', 'VERB'),
#  ('.', '.'),
#  (',', '.'),
#  ('but', 'CONJ'),
#  (';', '.'),
#  ('*-1', 'X'),
#  ('require', 'VERB'),
#  ('from', 'ADP'),
#  ('to', 'PRT'),
#  (',', '.'),
#  ('pre-approved', 'ADJ'),
#  ('a', 'DET'),
#  ('fired', 'VERB'),
#  ('.', '.'),
#  ('that', 'DET'),
#  ('as', 'ADP'),
#  ('in', 'ADP'),
#  ('.', '.'),
#  ('*-1', 'X'),
#  ('*T*-205', 'X'),
#  ('--', '.'),
#  ('years', 'NOUN'),
#  ('Macheski', 'NOUN'),
#  ('5.4', 'NUM'),
#  (',', '.'),
#  ('hour', 'NOUN'),
#  ('.', '.'),
#  ('.', '.'),
#  ('trading', 'NOUN'),
#  ('head', 'NOUN'),
#  ('stock', 'NOUN'),
#  ('Mercantile', 'NOUN'),
#  ('thus', 'ADV'),
#  ('certain', 'ADJ'),
#  ('make', 'VERB'),
#  ('Random', 'NOUN'),
#  ('D.', 'NOUN'),
#  ('Mr.', 'NOUN'),
#  ('greater', 'ADJ'),
#  ('has', 'VERB'),
#  ('quarter', 'NOUN'),
#  ('research', 'NOUN'),
#  ('difference', 'NOUN'),
#  ('rights', 'NOUN'),
#  ('--', '.'),
#  ('banks', 'NOUN'),
#  ('the', 'DET'),
#  ('99', 'NUM'),
#  ('were', 'VERB'),
#  ('said', 'VERB'),
#  ('the', 'DET'),
#  ('It', 'PRON'),
#  (',', '.'),
#  ('commitment', 'NOUN'),
#  ('buy-outs', 'NOUN'),
#  ('Barnum', 'NOUN'),
#  ('do', 'VERB'),
#  ('was', 'VERB'),
#  (',', '.'),
#  ('to', 'PRT'),
#  ("''", '.'),
#  ('and', 'CONJ'),
#  ('up', 'PRT'),
#  ('%', 'NOUN'),
#  ("n't", 'ADV'),
#  ('small', 'ADJ'),
#  (',', '.'),
#  ('often', 'ADV'),
#  ("'s", 'PRT'),
#  ('or', 'CONJ'),
#  ('could', 'VERB'),
#  ('the', 'DET'),
#  ('its', 'PRON'),
#  ('was', 'VERB'),
#  ('anti-dumping', 'ADJ'),
#  ('possible', 'ADJ'),
#  ('*-1', 'X'),
#  ('the', 'DET'),
#  ('Longwood', 'NOUN'),
#  ('are', 'VERB'),
#  ('have', 'VERB'),
#  ('and', 'CONJ'),
#  ('securities', 'NOUN'),
#  ("'s", 'PRT'),
#  ('well', 'ADV'),
#  ('three', 'NUM'),
#  ('responsibilities', 'NOUN'),
#  ('professor', 'NOUN'),
#  ('.', '.'),
#  ('company', 'NOUN'),
#  ('Earnings', 'NOUN'),
#  ('Senate', 'NOUN'),
#  (',', '.'),
#  ('higher', 'ADJ'),
#  ('.', '.'),
#  (',', '.'),
#  ('in', 'ADP'),
#  ('*-1', 'X'),
#  ('to', 'PRT'),
#  ('0', 'X'),
#  ('or', 'CONJ'),
#  ('1.916', 'NUM'),
#  ('to', 'PRT'),
#  ('which', 'DET'),
#  ('and', 'CONJ'),
#  ('shot', 'VERB'),
#  ('Why', 'ADV'),
#  ('interest', 'NOUN'),
#  ('drawing', 'NOUN'),
#  ('October', 'NOUN'),
#  ('business', 'NOUN'),
#  ('that', 'ADP'),
#  ('.', '.'),
#  ('retired', 'VERB'),
#  ('you', 'PRON'),
#  ('0', 'X'),
#  ('semiconductors', 'NOUN'),
#  ('caused', 'VERB'),
#  ('life', 'NOUN'),
#  ('is', 'VERB'),
#  ('that', 'ADP'),
#  (',', '.'),
#  ('of', 'ADP'),
#  ('The', 'DET'),
#  ('.', '.'),
#  ('prices', 'NOUN'),
#  ('is', 'VERB'),
#  ('vs.', 'ADP'),
#  ('.', '.'),
#  ('$', '.'),
#  ('the', 'DET'),
#  ('0', 'X'),
#  ('withdrawn', 'VERB'),
#  ('the', 'DET'),
#  ('Fund', 'NOUN'),
#  ('I', 'PRON'),
#  ("n't", 'ADV'),
#  ('.', '.'),
#  ('and', 'CONJ'),
#  ('.', '.'),
#  ('warrants', 'NOUN'),
#  ('trading', 'NOUN'),
#  ('authorities', 'NOUN'),
#  ('shares', 'NOUN'),
#  ('Lambert', 'NOUN'),
#  ('in', 'ADP'),
#  ('*T*-81', 'X'),
#  ('yen', 'NOUN'),
#  (',', '.'),
#  ('Judith', 'NOUN'),
#  ('to', 'PRT'),
#  ('0', 'X'),
#  ('shares', 'NOUN'),
#  ('their', 'PRON'),
#  ('indirect', 'ADJ'),
#  ('million', 'NUM'),
#  ('said', 'VERB'),
#  ('on', 'ADP'),
#  ('on', 'ADP'),
#  ('0', 'X'),
#  ('easy', 'ADJ'),
#  ('Prof.', 'NOUN'),
#  ('between', 'ADP'),
#  ('*-1', 'X'),
#  ('for', 'ADP'),
#  ('J.', 'NOUN'),
#  ('Goldsmith', 'NOUN'),
#  ('in', 'ADP'),
#  ('first', 'ADV'),
#  ('.', '.'),
#  ('current', 'ADJ'),
#  ('the', 'DET'),
#  ('*RNR*-2', 'X'),
#  ('remains', 'VERB'),
#  ('and', 'CONJ'),
#  ('believes', 'VERB'),
#  ('plans', 'VERB'),
#  ('It', 'PRON'),
#  ('stock-index', 'ADJ'),
#  ('information', 'NOUN'),
#  ('said', 'VERB'),
#  ('growers', 'NOUN'),
#  ('Backe', 'NOUN'),
#  ('reaches', 'VERB'),
#  ('does', 'VERB'),
#  ('restore', 'VERB'),
#  ('company', 'NOUN'),
#  ('*U*', 'X'),
#  ('But', 'CONJ'),
#  ('.', '.'),
#  ('and', 'CONJ'),
#  ('willing', 'ADJ'),
#  ('trading', 'NOUN'),
#  ('*', 'X'),
#  ('early', 'ADJ'),
#  ('robotic', 'ADJ'),
#  ('*T*-2', 'X'),
#  ('$', '.'),
#  ('will', 'VERB'),
#  ('other', 'ADJ'),
#  ('diaper', 'NOUN'),
#  ('.', '.'),
#  ('&', 'CONJ'),
#  ('troubles', 'NOUN'),
#  ('$', '.'),
#  ('for', 'ADP'),
#  ('due', 'ADJ'),
#  ('are', 'ADP'),
#  ('have', 'VERB'),
#  ('later', 'ADJ'),
#  ('that', 'DET'),
#  ('presidency', 'NOUN'),
#  ('capital-gains', 'ADJ'),
#  ('Trade', 'NOUN'),
#  ('debacle', 'NOUN'),
#  ('Stoll', 'NOUN'),
#  ('refusal', 'NOUN'),
#  ('in', 'ADP'),
#  ('market', 'NOUN'),
#  ('.', '.'),
#  ('Each', 'DET'),
#  ('one-time', 'ADJ'),
#  ('millions', 'NOUN'),
#  ('about', 'ADP'),
#  ('markup', 'NOUN'),
#  ('also', 'ADV'),
#  ('he', 'PRON'),
#  ('a', 'DET'),
#  (',', '.'),
#  (',', '.'),
#  ('US$', '.'),
#  ('.', '.'),
#  ('by', 'ADP'),
#  ('reservations', 'NOUN'),
#  ('on', 'ADP'),
#  ('engaged', 'VERB'),
#  ('House', 'NOUN'),
#  ('encroaching', 'VERB'),
#  ('Learning', 'NOUN'),
#  ('to', 'PRT'),
#  ('profitable', 'ADJ'),
#  ('adviser', 'NOUN'),
#  ('In', 'ADP'),
#  ('contract', 'NOUN'),
#  ('round', 'NOUN'),
#  ('a', 'DET'),
#  ('chosen', 'VERB'),
#  (',', '.'),
#  ('ended', 'VERB'),
#  ('BTR', 'NOUN'),
#  ('help', 'VERB'),
#  ('of', 'ADP'),
#  ('at', 'ADP'),
#  ('The', 'DET'),
#  ('made', 'VERB'),
#  ('things', 'NOUN'),
#  ('taking', 'VERB'),
#  ('Legg', 'NOUN'),
#  ('Corp.', 'NOUN'),
#  ('in', 'ADP'),
#  ('F.', 'NOUN'),
#  (';', '.'),
#  ('3\\/4', 'NUM'),
#  ('the', 'DET'),
#  (',', '.'),
#  ('said', 'VERB'),
#  ('field', 'NOUN'),
#  ('heightened', 'VERB'),
#  ('F.W.', 'NOUN'),
#  ('to', 'PRT'),
#  ('negative', 'ADJ'),
#  ('.', '.'),
#  ('in', 'ADP'),
#  ('of', 'ADP'),
#  ('at', 'ADP'),
#  ('to', 'PRT'),
#  ('old', 'ADJ'),
#  ('when', 'ADV'),
#  ('1990', 'NUM'),
#  ('passage', 'NOUN'),
#  (',', '.'),
#  ('.', '.'),
#  ('sugar', 'NOUN'),
#  ('*', 'X'),
#  ('sign', 'NOUN'),
#  ('under', 'ADP'),
#  ('two', 'NUM'),
#  ('bid', 'VERB'),
#  (',', '.'),
#  ('has', 'VERB'),
#  ("''", '.'),
#  ('year', 'NOUN'),
#  ('is', 'VERB'),
#  ('analyst', 'NOUN'),
#  ('company', 'NOUN'),
#  ('New', 'NOUN'),
#  ('advertisers', 'NOUN'),
#  ('II', 'NOUN'),
#  ('have', 'VERB'),
#  ('*T*-1', 'X'),
#  ('prevent', 'VERB'),
#  ('salary', 'NOUN'),
#  ('the', 'DET'),
#  ('*-2', 'X'),
#  ('reforms', 'NOUN'),
#  ('Today', 'NOUN'),
#  ('some', 'DET'),
#  ('*', 'X'),
#  ('million', 'NUM'),
#  ('an', 'DET'),
#  ('1960s', 'NUM'),
#  (',', '.'),
#  ('.', '.'),
#  ('standards', 'NOUN'),
#  ('trades', 'NOUN'),
#  ('Frank', 'NOUN'),
#  (',', '.'),
#  ('mostly', 'ADV'),
#  ('court', 'NOUN'),
#  ('to', 'PRT'),
#  ('lenders', 'NOUN'),
#  ('a', 'DET'),
#  (',', '.'),
#  ('its', 'PRON'),
#  ('uptick', 'NOUN'),
#  ('the', 'DET'),
#  ('about', 'ADP'),
#  ('.', '.'),
#  ('NASD', 'NOUN'),
#  ('closer', 'ADJ'),
#  ('Yet', 'ADV'),
#  ('*T*-43', 'X'),
#  ('.', '.'),
#  ('short', 'ADJ'),
#  ('with', 'ADP'),
#  ('industrials', 'NOUN'),
#  ('million', 'NUM'),
#  ('restrictions', 'NOUN'),
#  ('.', '.'),
#  ('And', 'CONJ'),
#  ('the', 'DET'),
#  (',', '.'),
#  ('Experts', 'NOUN'),
#  ('later', 'ADJ'),
#  ('placed', 'VERB'),
#  ('off', 'ADP'),
#  ('general', 'ADJ'),
#  ('will', 'VERB'),
#  ('.', '.'),
#  ('.', '.'),
#  ("'s", 'PRT'),
#  ('even', 'ADJ'),
#  ('that', 'ADP'),
#  (',', '.'),
#  ('the', 'ADJ'),
#  ('regarded', 'VERB'),
#  ('*-88', 'X'),
#  (',', '.'),
#  ('United', 'NOUN'),
#  ('as', 'ADP'),
#  ('on', 'ADP'),
#  ('the', 'DET'),
#  ('.', '.'),
#  ('finally', 'ADV'),
#  ('there', 'DET'),
#  ('annoyed', 'VERB'),
#  (',', '.'),
#  ('the', 'DET'),
#  ('*-1', 'X'),
#  (',', '.'),
#  ('.', '.'),
#  ('current', 'ADJ'),
#  ('the', 'DET'),
#  ('magazine', 'NOUN'),
#  ('.', '.'),
#  ('the', 'DET'),
#  (',', '.'),
#  ('On', 'ADP'),
#  ('volatility', 'NOUN'),
#  ('the', 'DET'),
#  ('reached', 'VERB'),
#  ('always', 'ADV'),
#  ('valued', 'VERB'),
#  ('Sales', 'NOUN'),
#  ('bank', 'NOUN'),
#  ('lesson', 'NOUN'),
#  ('six', 'NUM'),
#  ('take', 'VERB'),
#  ('organized', 'VERB'),
#  ('they', 'PRON'),
#  ('full', 'ADJ'),
#  ('reformers', 'NOUN'),
#  ('tight', 'ADJ'),
#  ('year', 'NOUN'),
#  ('officer', 'NOUN'),
#  (',', '.'),
#  ('*', 'X'),
#  ('Orleans', 'NOUN'),
#  ('first-half', 'ADJ'),
#  ('3\\/4', 'NUM'),
#  ('Boca', 'NOUN'),
#  ('in', 'ADP'),
#  ('*T*-32', 'X'),
#  ('made', 'VERB'),
#  ('because', 'ADP'),
#  ('187', 'NUM'),
#  ('optimism', 'NOUN'),
#  ('corporate', 'ADJ'),
#  ('a', 'DET'),
#  (',', '.'),
#  ('South', 'NOUN'),
#  ('Mr.', 'NOUN'),
#  ('Chicago', 'NOUN'),
#  ('today', 'NOUN'),
#  ('.', '.'),
#  ('``', '.'),
#  ('Philadelphia', 'NOUN'),
#  ('group', 'NOUN'),
#  ("n't", 'ADV'),
#  ('No.', 'NOUN'),
#  ('to', 'PRT'),
#  ('empire', 'NOUN'),
#  (',', '.'),
#  ('the', 'DET'),
#  ('.', '.'),
#  ('.', '.'),
#  ('Engineers', 'NOUN'),
#  ('and', 'CONJ'),
#  ('.', '.'),
#  ('do', 'VERB'),
#  ('said', 'VERB'),
#  ('by', 'ADP'),
#  ('400', 'NUM'),
#  ('damage', 'NOUN'),
#  ('us', 'PRON'),
#  (',', '.'),
#  ("'s", 'PRT'),
#  ('excessive', 'ADJ'),
#  ('Section', 'NOUN'),
#  ('*-1', 'X'),
#  ('floating-rate', 'ADJ'),
#  ('week', 'NOUN'),
#  ('of', 'ADP'),
#  ('Mitsubishi', 'NOUN'),
#  ('role', 'NOUN'),
#  ('Conn', 'NOUN'),
#  ('Chamber', 'NOUN'),
#  ('product', 'NOUN'),
#  ('punishable', 'ADJ'),
#  ('problem', 'NOUN'),
#  ('recommendations', 'NOUN'),
#  ('support', 'NOUN'),
#  ('sold', 'VERB'),
#  ('have', 'VERB'),
#  ('the', 'DET'),
#  ('0', 'X'),
#  ('seats', 'NOUN'),
#  ('farm', 'NOUN'),
#  ('Thomas', 'NOUN'),
#  ('the', 'DET'),
#  ('The', 'DET'),
#  ('Texas', 'NOUN'),
#  ('wines', 'NOUN'),
#  ('the', 'DET'),
#  ('agree', 'VERB'),
#  ('.', '.'),
#  ('who', 'PRON'),
#  ('of', 'ADP'),
#  ('to', 'PRT'),
#  ('can', 'VERB'),
#  (',', '.'),
#  ('classes', 'NOUN'),
#  ('or', 'CONJ'),
#  ('changes', 'NOUN'),
#  ('of', 'ADP'),
#  ('information', 'NOUN'),
#  ('*U*', 'X'),
#  ('.', '.'),
#  ('stands', 'VERB'),
#  ('net', 'ADJ'),
#  ('that', 'ADP'),
#  ('gains', 'NOUN'),
#  ('But', 'CONJ'),
#  ('development', 'NOUN'),
#  ('year', 'NOUN'),
#  ('500', 'NUM'),
#  ('proposal', 'NOUN'),
#  ('small', 'ADJ'),
#  ('*-1', 'X'),
#  ('attorney', 'NOUN'),
#  ('of', 'ADP'),
#  (',', '.'),
#  ('research', 'NOUN'),
#  ('of', 'ADP'),
#  ('booming', 'VERB'),
#  (',', '.'),
#  ('government', 'NOUN'),
#  ('wrote', 'VERB'),
#  ('action', 'NOUN'),
#  ('than', 'ADP'),
#  ('Smith', 'NOUN'),
#  ('beauty', 'NOUN'),
#  (',', '.'),
#  (',', '.'),
#  ('debentures', 'NOUN'),
#  ('Sigler', 'NOUN'),
#  ('be', 'VERB'),
#  ('some', 'DET'),
#  ('on', 'PRT'),
#  ('*', 'X'),
#  ('15', 'NUM'),
#  (',', '.'),
#  ('*-2', 'X'),
#  ("''", '.'),
#  ('water-authority', 'NOUN'),
#  ('suffered', 'VERB'),
#  ('closely', 'ADV'),
#  ('old-style', 'ADJ'),
#  ('in', 'ADP'),
#  ('executives', 'NOUN'),
#  ('One', 'NUM'),
#  ('packaging', 'VERB'),
#  ('Sachs', 'NOUN'),
#  ('Who', 'PRON'),
#  ('.', '.'),
#  ('``', '.'),
#  ('0', 'X'),
#  ('test', 'NOUN'),
#  ('*T*-1', 'X'),
#  ("'s", 'PRT'),
#  ('Logic', 'NOUN'),
#  ('about', 'ADP'),
#  ('$', '.'),
#  ('responded', 'VERB'),
#  ('flows', 'VERB'),
#  ("'s", 'PRT'),
#  ('of', 'ADP'),
#  ('Robert', 'NOUN'),
#  ('-RCB-', '.'),
#  ('the', 'DET'),
#  ('some', 'DET'),
#  ('China', 'NOUN'),
#  ('the', 'DET'),
#  ('Mr.', 'NOUN'),
#  (',', '.'),
#  ('have', 'VERB'),
#  ('did', 'VERB'),
#  (',', '.'),
#  (',', '.'),
#  ('recently', 'ADV'),
#  ('were', 'VERB'),
#  ('of', 'ADP'),
#  ('which', 'DET'),
#  ('*T*-1', 'X'),
#  ('Have', 'NOUN'),
#  ('applications', 'NOUN'),
#  ('convertible', 'ADJ'),
#  ('rate', 'NOUN'),
#  ('in', 'ADP'),
#  (',', '.'),
#  ('*T*-2', 'X'),
#  ('game', 'NOUN'),
#  ('*T*-4', 'X'),
#  ('amazingly', 'ADV'),
#  ('Section', 'NOUN'),
#  ('an', 'DET'),
#  ('2.50', 'NUM'),
#  ('.', '.'),
#  ('type', 'NOUN'),
#  ('of', 'ADP'),
#  ('Stock', 'NOUN'),
#  ('the', 'DET'),
#  ('index-arbitrage', 'ADJ'),
#  ('Charities', 'NOUN'),
#  ('*T*-1', 'X'),
#  ('that', 'ADP'),
#  ('volatile', 'ADJ'),
#  ('13', 'NUM'),
#  ('liquidity', 'NOUN'),
#  ('supercomputer', 'NOUN'),
#  ('minimum', 'ADJ'),
#  ('government', 'NOUN'),
#  ('pulp', 'NOUN'),
#  ('as', 'ADP'),
#  ('had', 'VERB'),
#  ('reports', 'VERB'),
#  ('would', 'VERB'),
#  ('studied', 'VERB'),
#  ('the', 'DET'),
#  ('Partners', 'NOUN'),
#  ('a', 'DET'),
#  ('Poor', 'NOUN'),
#  ('prosecutors', 'NOUN'),
#  ('trading', 'NOUN'),
#  ('with', 'ADP'),
#  ('share', 'NOUN'),
#  ('*-97', 'X'),
#  ('Florio', 'NOUN'),
#  ('and', 'CONJ'),
#  ('one', 'NUM'),
#  ('place', 'NOUN'),
#  ('Machines', 'NOUN'),
#  ('buy', 'VERB'),
#  ('outright', 'ADJ'),
#  ('has', 'VERB'),
#  ('The', 'DET'),
#  ...]

# %%
words_train = [pair[0] for pair in train_set]

# %%
len(words_train)
# Out:
# 95642

# %%
V = set(words_train)

# %%
len(V)
# Out:
# 12082

# %%
tags_train = [pair[1] for pair in train_set]

# %%
T = set(tags_train)

# %%
len(T)
# Out:
# 12

# %%
print(T)
# Out:
# {'NUM', 'CONJ', 'ADJ', 'ADV', 'ADP', 'PRT', 'DET', 'VERB', '.', 'PRON', 'NOUN', 'X'}

# %% [markdown]
# ### Build the vanilla Viterbi based POS tagger

# %% [markdown]
# ### Emission Probabilties

# %%
# computing P(w/t) and storing in T x V matrix
t = len(T)
v = len(V)
w_given_t = np.zeros((t, v))

# %%
# compute word given tag: Emission Probability
def word_given_tag(word, tag, train_bag = train_set):
    tag_list = [pair for pair in train_bag if pair[1]==tag]
    count_tag = len(tag_list)
    w_given_tag_list = [pair[0] for pair in tag_list if pair[0]==word]
    count_w_given_tag = len(w_given_tag_list)
    
    return (count_w_given_tag, count_tag)

# %% [markdown]
# ### Transition Probability

# %%
# compute tag given tag: tag2(t2) given tag1 (t1), i.e. Transition Probability

def t2_given_t1(t2, t1, train_bag = train_set):
    tags = [pair[1] for pair in train_bag]
    count_t1 = len([t for t in tags if t==t1])
    count_t2_t1 = 0
    for index in range(len(tags)-1):
        if tags[index]==t1 and tags[index+1] == t2:
            count_t2_t1 += 1
    return (count_t2_t1, count_t1)

# %%
# creating t x t transition matrix of tags
# each column is t2, each row is t1
# thus M(i, j) represents P(tj given ti)

tags_matrix = np.zeros((len(T), len(T)), dtype='float32')
for i, t1 in enumerate(list(T)):
    for j, t2 in enumerate(list(T)): 
        tags_matrix[i, j] = t2_given_t1(t2, t1)[0]/t2_given_t1(t2, t1)[1]

# %%
tags_matrix
# Out:
# array([[0.03583159, 0.02179755, 0.05494177, 0.02866527, 0.09853688,
#         0.03075545, 0.08330845, 0.12869513, 0.11077934, 0.02806808,
#         0.31233203, 0.06628844],
#        [0.03601108, 0.02400739, 0.05263158, 0.03370268, 0.10203139,
#         0.03231763, 0.0923361 , 0.13665743, 0.11218837, 0.03047091,
#         0.27839336, 0.06925208],
#        [0.03417533, 0.02245336, 0.06438831, 0.03136867, 0.09691266,
#         0.03169886, 0.09146442, 0.1398382 , 0.11953112, 0.02459964,
#         0.2829784 , 0.06059105],
#        [0.04270109, 0.02581926, 0.05991394, 0.03243959, 0.0959947 ,
#         0.03078451, 0.08407812, 0.12810327, 0.11254551, 0.02615028,
#         0.29261833, 0.06885137],
#        [0.0359666 , 0.02065939, 0.06251338, 0.03136373, 0.09880111,
#         0.03114965, 0.08606294, 0.13166346, 0.1137872 , 0.02847356,
#         0.28976664, 0.06979234],
#        [0.03543307, 0.02034121, 0.06594488, 0.02821522, 0.10006562,
#         0.03313648, 0.09383202, 0.14238845, 0.11778215, 0.02690289,
#         0.27526248, 0.06069554],
#        [0.03089314, 0.02235846, 0.06082462, 0.02981128, 0.09832913,
#         0.03209521, 0.0872701 , 0.13258806, 0.12477461, 0.02884962,
#         0.28164443, 0.07056136],
#        [0.03483861, 0.02164804, 0.06385785, 0.03289882, 0.09621353,
#         0.03111422, 0.08449721, 0.1359404 , 0.11739603, 0.02909683,
#         0.2894941 , 0.06300434],
#        [0.03684731, 0.02471466, 0.06533657, 0.03091579, 0.09760043,
#         0.03325245, 0.08789431, 0.13040352, 0.12303406, 0.02543363,
#         0.28084838, 0.06371889],
#        [0.02629544, 0.02049497, 0.07192575, 0.03866976, 0.10827533,
#         0.0317092 , 0.09203403, 0.13495746, 0.112529  , 0.02745553,
#         0.26836812, 0.06728538],
#        [0.03544497, 0.02400641, 0.06418709, 0.03161998, 0.09693636,
#         0.03176569, 0.08648137, 0.13547777, 0.11365706, 0.02604641,
#         0.28898764, 0.06535281],
#        [0.03403308, 0.01908397, 0.0634542 , 0.03196565, 0.09557888,
#         0.03276081, 0.08540076, 0.14138041, 0.11052799, 0.02639949,
#         0.2913486 , 0.06806616]], dtype=float32)

# %%
# convert the matrix to a df for better readability
tags_df = pd.DataFrame(tags_matrix, columns = list(T), index=list(T))

# %%
tags_df
# Out:
#            NUM      CONJ       ADJ       ADV       ADP       PRT       DET  \
# NUM   0.035832  0.021798  0.054942  0.028665  0.098537  0.030755  0.083308
# CONJ  0.036011  0.024007  0.052632  0.033703  0.102031  0.032318  0.092336
# ADJ   0.034175  0.022453  0.064388  0.031369  0.096913  0.031699  0.091464
# ADV   0.042701  0.025819  0.059914  0.032440  0.095995  0.030785  0.084078
# ADP   0.035967  0.020659  0.062513  0.031364  0.098801  0.031150  0.086063
# PRT   0.035433  0.020341  0.065945  0.028215  0.100066  0.033136  0.093832
# DET   0.030893  0.022358  0.060825  0.029811  0.098329  0.032095  0.087270
# VERB  0.034839  0.021648  0.063858  0.032899  0.096214  0.031114  0.084497
# .     0.036847  0.024715  0.065337  0.030916  0.097600  0.033252  0.087894
# PRON  0.026295  0.020495  0.071926  0.038670  0.108275  0.031709  0.092034
# NOUN  0.035445  0.024006  0.064187  0.031620  0.096936  0.031766  0.086481
# X     0.034033  0.019084  0.063454  0.031966  0.095579  0.032761  0.085401
#
#           VERB         .      PRON      NOUN         X
# NUM   0.128695  0.110779  0.028068  0.312332  0.066288
# CONJ  0.136657  0.112188  0.030471  0.278393  0.069252
# ADJ   0.139838  0.119531  0.024600  0.282978  0.060591
# ADV   0.128103  0.112546  0.026150  0.292618  0.068851
# ADP   0.131663  0.113787  0.028474  0.289767  0.069792
# PRT   0.142388  0.117782  0.026903  0.275262  0.060696
# DET   0.132588  0.124775  0.028850  0.281644  0.070561
# VERB  0.135940  0.117396  0.029097  0.289494  0.063004
# .     0.130404  0.123034  0.025434  0.280848  0.063719
# PRON  0.134957  0.112529  0.027456  0.268368  0.067285
# NOUN  0.135478  0.113657  0.026046  0.288988  0.065353
# X     0.141380  0.110528  0.026399  0.291349  0.068066

# %% [markdown]
# #### Vanilla Viterbi Algorithm

# %%
# Viterbi Heuristic
def Viterbi(words, train_bag = train_set):
    state = []
    T = list(set([pair[1] for pair in train_bag]))
    
    for key, word in enumerate(words):
        #initialise list of probability column for a given observation
        p = [] 
        for tag in T:
            if key == 0:
                transition_p = tags_df.loc['.', tag]
            else:
                transition_p = tags_df.loc[state[-1], tag]
                
            # compute emission and state probabilities
            emission_p = word_given_tag(words[key], tag)[0]/word_given_tag(words[key], tag)[1]
            state_probability = emission_p * transition_p    
            p.append(state_probability)
            
        pmax = max(p)
        # getting state for which probability is maximum
        state_max = T[p.index(pmax)] 
        state.append(state_max)
    return list(zip(words, state))

# %%
words_test = [pairs[0] for pairs in test_set]

# %%
len(words_test)
# Out:
# 5034

# %%
words_test
# Out:
# ['was',
#  'constituent',
#  'operating',
#  'among',
#  'Association',
#  'OSHA',
#  'Who',
#  'threatened',
#  'the',
#  '*',
#  '.',
#  'daily',
#  'Mr.',
#  'gets',
#  '``',
#  '``',
#  'to',
#  'and',
#  'several',
#  'they',
#  '*-2',
#  '.',
#  'types',
#  "'s",
#  '.',
#  '1986',
#  'rose',
#  'should',
#  '*-3',
#  '*T*-1',
#  '.',
#  ',',
#  'Courter',
#  'dividends',
#  'prices',
#  'in',
#  'now',
#  'year',
#  'of',
#  'federal',
#  'a',
#  'months',
#  ',',
#  'Express',
#  'Jr.',
#  'meeting',
#  "''",
#  'is',
#  'criminal',
#  '*-3',
#  'sold',
#  'the',
#  'since',
#  'in',
#  '%',
#  'the',
#  'the',
#  'Southeast',
#  'says',
#  ',',
#  '.',
#  'a',
#  'closing',
#  'give',
#  'that',
#  'funding',
#  ',',
#  'of',
#  'equity',
#  'cost',
#  'reported',
#  'says',
#  'Raul',
#  'their',
#  ':',
#  'from',
#  'federal',
#  'a',
#  'the',
#  'Hospital',
#  'rain',
#  'administration',
#  ',',
#  'Nine',
#  'market',
#  'Connecticut',
#  'U.S.',
#  'in',
#  'shares',
#  'yesterday',
#  'that',
#  'have',
#  'Service',
#  'some',
#  'Markey',
#  'computer',
#  'could',
#  'of',
#  'the',
#  '*T*-1',
#  'well-known',
#  'The',
#  'share',
#  'believe',
#  '.',
#  'Courter',
#  'Stephen',
#  '.',
#  'Greenville',
#  'survey',
#  'Washington',
#  'recent',
#  'acceded',
#  'cancer',
#  'We',
#  '.',
#  'officials',
#  'in',
#  'judge',
#  '$',
#  'Article',
#  'increase',
#  '*',
#  'million',
#  'council',
#  'in',
#  'aggressive',
#  'million',
#  '7\\/8',
#  'continuing',
#  '.',
#  'stations',
#  'of',
#  ',',
#  'some',
#  '1992',
#  'Pratt',
#  'stadium',
#  'Germany-based',
#  "'",
#  'about',
#  'confirm',
#  'to',
#  'Waertsilae',
#  ',',
#  'and',
#  'B.',
#  ',',
#  '*U*',
#  'cents',
#  "'s",
#  'were',
#  'estimate',
#  'activity',
#  'U.S.',
#  'on',
#  'is',
#  ';',
#  'to',
#  'New',
#  'say',
#  'voluntarily',
#  'decided',
#  'earthquake',
#  ',',
#  '*',
#  'the',
#  'business',
#  'it',
#  'new',
#  'directors',
#  '$',
#  'though',
#  'proposed',
#  '*-25',
#  'is',
#  'capital',
#  'says',
#  'for',
#  'Corp.',
#  'into',
#  '6.20',
#  '.',
#  'for',
#  ',',
#  'a',
#  '$',
#  'trading',
#  'venture',
#  'and',
#  'or',
#  'it',
#  ',',
#  'of',
#  ',',
#  'than',
#  '*-1',
#  'to',
#  'million',
#  'With',
#  '--',
#  'will',
#  'to',
#  'a',
#  'anticipating',
#  'Mitsui',
#  'student',
#  'further',
#  'that',
#  '0',
#  'County',
#  'down',
#  'right',
#  'sources',
#  'the',
#  '$',
#  'WHAS',
#  'after',
#  'indexers',
#  'It',
#  'USX',
#  'shares',
#  'niches',
#  'could',
#  'is',
#  ',',
#  'the',
#  'retailing',
#  ',',
#  'answers',
#  'to',
#  '*T*-3',
#  'because',
#  'is',
#  'the',
#  'the',
#  'take',
#  'Each',
#  'to',
#  'Administration',
#  '3.7',
#  'stock',
#  'unchanged',
#  'as',
#  ',',
#  'would',
#  'the',
#  '*',
#  '*-1',
#  ',',
#  'three',
#  'sort',
#  'will',
#  '``',
#  'notion',
#  'took',
#  '.',
#  'China',
#  ',',
#  'cultivation',
#  'units',
#  ',',
#  'to',
#  'freedom',
#  'New',
#  'plunged',
#  'field',
#  '*T*-57',
#  'Then',
#  'features',
#  '%',
#  'trade',
#  '.',
#  'By',
#  'investor',
#  'new',
#  "'s",
#  'say',
#  'main',
#  'of',
#  'two',
#  'of',
#  'the',
#  'pyramids',
#  '0',
#  '*U*',
#  'trading',
#  ',',
#  'became',
#  ',',
#  'development',
#  'Jim',
#  'will',
#  'the',
#  '0',
#  'together',
#  'Travelers',
#  '.',
#  'in',
#  'those',
#  'Mr.',
#  ',',
#  'constitutional',
#  '38',
#  'banks',
#  '0',
#  'enforcement',
#  'While',
#  '*T*-155',
#  ',',
#  'several',
#  'commercial',
#  'ground',
#  'received',
#  'some',
#  'Johns',
#  'that',
#  'introduce',
#  'Treasury',
#  'as',
#  'extend',
#  'Sun',
#  '.',
#  'pass',
#  'advertisers',
#  'to',
#  'gives',
#  'beverage',
#  '$',
#  'Forster',
#  'list',
#  "n't",
#  'chief',
#  'billion',
#  'airline',
#  '120',
#  'Inc.',
#  'pay',
#  '``',
#  'in',
#  'matter',
#  '2.1',
#  '--',
#  'related',
#  '%',
#  'unsettled',
#  'extraordinary',
#  'elementary',
#  'appeals',
#  'because',
#  'Negus',
#  'problems',
#  'first',
#  'five-cent',
#  'banks',
#  '.',
#  'with',
#  'back',
#  'Valhi',
#  'Year',
#  'the',
#  'big',
#  ',',
#  'bank',
#  'test',
#  'offer',
#  '.',
#  'it',
#  'for',
#  'cigarette',
#  'trade',
#  'days',
#  '*',
#  'rose',
#  'going',
#  'do',
#  'a',
#  '-RRB-',
#  'any',
#  "'",
#  'and',
#  "''",
#  '18-a-share',
#  'the',
#  'growth',
#  '0',
#  'drugs',
#  'were',
#  '.',
#  'make',
#  'unexpected',
#  '*U*',
#  '2',
#  'the',
#  'the',
#  'and',
#  '*-1',
#  ',',
#  '.',
#  ',',
#  '*T*-2',
#  "'s",
#  'are',
#  'trade',
#  'however',
#  'Big',
#  'construction',
#  'since',
#  'the',
#  'a',
#  'from',
#  'said',
#  ',',
#  '*T*-1',
#  '.',
#  'for',
#  'bankrupt',
#  'in',
#  '$',
#  'offered',
#  'from',
#  '-RRB-',
#  'Pro-forma',
#  '*U*',
#  'at',
#  "'s",
#  '*T*-2',
#  'expected',
#  'Service',
#  'placing',
#  'his',
#  'performance',
#  'the',
#  "'s",
#  'was',
#  'is',
#  'hand',
#  '.',
#  'forecast',
#  'was',
#  'Hugo',
#  'subindustry',
#  'from',
#  'included',
#  'guild',
#  '*U*',
#  '.',
#  'of',
#  "''",
#  'the',
#  'said',
#  '*T*-1',
#  'the',
#  '0',
#  "'",
#  'billion',
#  'company',
#  'sale',
#  'for',
#  'Nippon',
#  'their',
#  ',',
#  'Japanese',
#  'one',
#  'who',
#  'gunship',
#  ',',
#  'Your',
#  "'s",
#  'are',
#  "n't",
#  'probably',
#  '.',
#  'from',
#  'and',
#  'interests',
#  'supercomputer',
#  'to',
#  'liability',
#  'of',
#  'bonds',
#  '$',
#  'bottle',
#  'the',
#  'their',
#  'market',
#  'in',
#  'Japanese',
#  'year',
#  'whipping',
#  'modestly',
#  'his',
#  'of',
#  'find',
#  'process',
#  'two',
#  ',',
#  '1990s',
#  '30',
#  ',',
#  'friendship',
#  'demand',
#  'stock',
#  'protesters',
#  'rose',
#  'has',
#  'goods',
#  '.',
#  'company',
#  'these',
#  'COMMUNICATIONS',
#  'article',
#  'an',
#  'on',
#  ',',
#  'expelled',
#  'on',
#  'some',
#  'Altogether',
#  'he',
#  ',',
#  'in',
#  'big',
#  'notes',
#  'ban',
#  'Sales',
#  'in',
#  'underwriter',
#  '%',
#  'The',
#  'of',
#  '0',
#  'index',
#  ',',
#  '*T*-1',
#  'billion',
#  'during',
#  'those',
#  ',',
#  'in',
#  ',',
#  '.',
#  'choosing',
#  'positions',
#  'absorbed',
#  'Christopher',
#  'the',
#  'D.',
#  'Toronto',
#  'as',
#  '*T*-31',
#  'deviant',
#  '*',
#  '.',
#  '2',
#  '*T*-1',
#  'tumbled',
#  'companies',
#  'even',
#  'Mexico',
#  'outbid',
#  'researchers',
#  'the',
#  'also',
#  'seeing',
#  'the',
#  'on',
#  'Mr.',
#  'years',
#  'more',
#  'for',
#  'excessive',
#  'Nelson',
#  'help',
#  'probably',
#  'president',
#  'fixed',
#  'of',
#  'the',
#  'Previously',
#  'extent',
#  'University',
#  'been',
#  ',',
#  'minimum',
#  '.',
#  'Mrs.',
#  'shipyard',
#  'it',
#  'conference',
#  'certain',
#  'new',
#  'semiliterate',
#  '0',
#  'said',
#  'stock-index',
#  'of',
#  'insiders',
#  ',',
#  'near',
#  'in',
#  '*U*',
#  'seven',
#  ',',
#  'president',
#  'Used',
#  'was',
#  'fully',
#  'Johnny',
#  'other',
#  'is',
#  'be',
#  'Ford',
#  'Imports',
#  'could',
#  '.',
#  'a',
#  '.',
#  'us',
#  'stock',
#  'hauling',
#  'International',
#  'of',
#  '*',
#  'a',
#  'fell',
#  'its',
#  'Donald',
#  'group',
#  'billion',
#  '.',
#  'investments',
#  'that',
#  'Angeles',
#  'that',
#  'refinery',
#  'the',
#  'trade',
#  'for',
#  'judges',
#  'fined',
#  'Department',
#  ',',
#  '*U*',
#  'If',
#  'fields',
#  'as',
#  "'s",
#  'would',
#  '7.88',
#  'moves',
#  'Boston',
#  '*U*',
#  'managers',
#  ',',
#  '*-1',
#  '.',
#  '.',
#  'of',
#  'what',
#  'The',
#  'expected',
#  'raise',
#  'bad',
#  'was',
#  '%',
#  'soared',
#  'of',
#  'cars',
#  'is',
#  'deals',
#  'executive',
#  '.',
#  'newspapers',
#  ',',
#  'relations',
#  'of',
#  'other',
#  'is',
#  'performance',
#  'to',
#  'assets',
#  'joining',
#  'the',
#  '.',
#  'have',
#  '``',
#  'Congress',
#  'to',
#  'declined',
#  'editor',
#  'are',
#  'We',
#  '*ICH*-1',
#  'thrifts',
#  ',',
#  'independent',
#  'board',
#  ',',
#  'the',
#  '*-2',
#  ',',
#  ',',
#  'she',
#  'fixed',
#  "'re",
#  'lying',
#  '&',
#  'profit',
#  'of',
#  '.',
#  'advertise',
#  'Friedrichs',
#  'the',
#  'to',
#  'Black',
#  'demand',
#  'number',
#  ',',
#  'new',
#  'the',
#  'omnipresent',
#  'a',
#  'the',
#  'earlier',
#  'young',
#  'plant',
#  'Scoring',
#  '750',
#  'even',
#  'to',
#  'been',
#  'not',
#  '*',
#  '*T*-55',
#  'and',
#  'of',
#  'says',
#  ',',
#  '*U*',
#  'NBI',
#  '$',
#  '*-1',
#  'including',
#  'to',
#  '*-1',
#  'of',
#  'Poland',
#  'people',
#  'amount',
#  'says',
#  '*T*-1',
#  'what',
#  'sentiment',
#  'Elisabeth',
#  'the',
#  'Chicago',
#  'new',
#  'crystals',
#  'But',
#  '29.9',
#  'program',
#  'rather',
#  'would',
#  '*-1',
#  ',',
#  'Among',
#  'by',
#  'was',
#  '-LRB-',
#  'which',
#  'ones',
#  'We',
#  '%',
#  'loss',
#  'in',
#  'improvement',
#  '``',
#  'consumer',
#  'the',
#  ',',
#  'RMS',
#  'to',
#  'prices',
#  'which',
#  'lesser',
#  'Newsweek',
#  '.',
#  '*-3',
#  'Dominion',
#  'a',
#  '*-2',
#  'Wednesday',
#  'of',
#  'losses',
#  '*',
#  'Mr.',
#  '.',
#  'but',
#  '.',
#  'rose',
#  'Korea',
#  'to',
#  'the',
#  'farm',
#  'conditions',
#  'investor',
#  'of',
#  '.',
#  'have',
#  'have',
#  'the',
#  'write-downs',
#  'researchers',
#  'and',
#  'to',
#  'Its',
#  'William',
#  'paid',
#  'Dover',
#  '45',
#  'installment',
#  ',',
#  'earnings',
#  'allegedly',
#  'He',
#  'were',
#  '0',
#  'deposit',
#  'allow',
#  'the',
#  'a',
#  'walls',
#  '9.9',
#  'health',
#  'the',
#  ',',
#  'U.S.',
#  '*',
#  'hoped',
#  'days',
#  'be',
#  '*-2',
#  'down',
#  'chief',
#  'offer',
#  '--',
#  'victims',
#  'change',
#  'dissemination',
#  'less',
#  'Its',
#  'from',
#  'fees',
#  'Tribune',
#  "''",
#  '*T*-1',
#  'most',
#  'Coleco',
#  'and',
#  'Despite',
#  'the',
#  'two',
#  'found',
#  '*-2',
#  'Rapanelli',
#  'between',
#  'result',
#  'than',
#  'link',
#  'one',
#  'year',
#  'for',
#  'Still',
#  'a',
#  'special',
#  '.',
#  '.',
#  'the',
#  '.',
#  'unless',
#  'Iowa',
#  "''",
#  'with',
#  '*-2',
#  ',',
#  'see',
#  'completed',
#  '.',
#  'from',
#  'in',
#  'customers',
#  'September',
#  'students',
#  'could',
#  'ever',
#  '*-1',
#  'off',
#  "''",
#  'Chicago',
#  'Columbia',
#  'become',
#  'they',
#  'Bund',
#  '*-101',
#  'and',
#  'clerics',
#  'his',
#  'certain',
#  'amicable',
#  'almost',
#  '$',
#  'on',
#  'of',
#  'profit',
#  'as',
#  '*T*-3',
#  'departure',
#  'would',
#  'smiles',
#  '0',
#  '*T*-1',
#  'trade',
#  '10',
#  'about',
#  'decision',
#  '.',
#  'selected',
#  'type',
#  '*T*-2',
#  'High',
#  'campaigning',
#  'futures',
#  'of',
#  'highly',
#  '.',
#  'chairman',
#  'decline',
#  'down',
#  ',',
#  'advertising',
#  'least',
#  '.',
#  'he',
#  'government',
#  '15',
#  "'s",
#  '--',
#  'have',
#  '``',
#  'Sen.',
#  '*-1',
#  'of',
#  'anti-drug',
#  'run',
#  'legal',
#  'about',
#  'and',
#  'other',
#  '1',
#  'river',
#  'Something',
#  'classics',
#  'is',
#  'Home',
#  '.',
#  'actions',
#  'It',
#  'it',
#  'days',
#  'was',
#  'The',
#  'he',
#  'proportion',
#  'the',
#  'panel',
#  '80',
#  '.',
#  'breaks',
#  'approved',
#  'legislators',
#  'citing',
#  'it',
#  'feel',
#  '*T*-1',
#  '*T*-1',
#  'sure',
#  '$',
#  'private',
#  'N.C.',
#  "'s",
#  'Stories',
#  ',',
#  'Crane',
#  'by',
#  'Prater',
#  'if',
#  'during',
#  'Says',
#  'of',
#  ...]

# %%
tagged_seq = Viterbi(words_test)

# %%
tagged_seq
# Out:
# [('was', 'VERB'),
#  ('constituent', 'NUM'),
#  ('operating', 'NOUN'),
#  ('among', 'ADP'),
#  ('Association', 'NOUN'),
#  ('OSHA', 'NOUN'),
#  ('Who', 'PRON'),
#  ('threatened', 'VERB'),
#  ('the', 'DET'),
#  ('*', 'X'),
#  ('.', '.'),
#  ('daily', 'ADJ'),
#  ('Mr.', 'NOUN'),
#  ('gets', 'VERB'),
#  ('``', '.'),
#  ('``', '.'),
#  ('to', 'PRT'),
#  ('and', 'CONJ'),
#  ('several', 'ADJ'),
#  ('they', 'PRON'),
#  ('*-2', 'X'),
#  ('.', '.'),
#  ('types', 'NOUN'),
#  ("'s", 'PRT'),
#  ('.', '.'),
#  ('1986', 'NUM'),
#  ('rose', 'VERB'),
#  ('should', 'VERB'),
#  ('*-3', 'X'),
#  ('*T*-1', 'X'),
#  ('.', '.'),
#  (',', '.'),
#  ('Courter', 'NOUN'),
#  ('dividends', 'NOUN'),
#  ('prices', 'NOUN'),
#  ('in', 'ADP'),
#  ('now', 'ADV'),
#  ('year', 'NOUN'),
#  ('of', 'ADP'),
#  ('federal', 'ADJ'),
#  ('a', 'DET'),
#  ('months', 'NOUN'),
#  (',', '.'),
#  ('Express', 'NOUN'),
#  ('Jr.', 'NOUN'),
#  ('meeting', 'NOUN'),
#  ("''", '.'),
#  ('is', 'VERB'),
#  ('criminal', 'ADJ'),
#  ('*-3', 'X'),
#  ('sold', 'VERB'),
#  ('the', 'DET'),
#  ('since', 'ADP'),
#  ('in', 'ADP'),
#  ('%', 'NOUN'),
#  ('the', 'DET'),
#  ('the', 'DET'),
#  ('Southeast', 'NOUN'),
#  ('says', 'VERB'),
#  (',', '.'),
#  ('.', '.'),
#  ('a', 'DET'),
#  ('closing', 'ADJ'),
#  ('give', 'VERB'),
#  ('that', 'ADP'),
#  ('funding', 'NOUN'),
#  (',', '.'),
#  ('of', 'ADP'),
#  ('equity', 'NOUN'),
#  ('cost', 'NOUN'),
#  ('reported', 'VERB'),
#  ('says', 'VERB'),
#  ('Raul', 'NUM'),
#  ('their', 'PRON'),
#  (':', '.'),
#  ('from', 'ADP'),
#  ('federal', 'ADJ'),
#  ('a', 'DET'),
#  ('the', 'DET'),
#  ('Hospital', 'NOUN'),
#  ('rain', 'NOUN'),
#  ('administration', 'NOUN'),
#  (',', '.'),
#  ('Nine', 'NUM'),
#  ('market', 'NOUN'),
#  ('Connecticut', 'NOUN'),
#  ('U.S.', 'NOUN'),
#  ('in', 'ADP'),
#  ('shares', 'NOUN'),
#  ('yesterday', 'NOUN'),
#  ('that', 'ADP'),
#  ('have', 'VERB'),
#  ('Service', 'NOUN'),
#  ('some', 'DET'),
#  ('Markey', 'NOUN'),
#  ('computer', 'NOUN'),
#  ('could', 'VERB'),
#  ('of', 'ADP'),
#  ('the', 'DET'),
#  ('*T*-1', 'X'),
#  ('well-known', 'ADJ'),
#  ('The', 'DET'),
#  ('share', 'NOUN'),
#  ('believe', 'VERB'),
#  ('.', '.'),
#  ('Courter', 'NOUN'),
#  ('Stephen', 'NOUN'),
#  ('.', '.'),
#  ('Greenville', 'NOUN'),
#  ('survey', 'NOUN'),
#  ('Washington', 'NOUN'),
#  ('recent', 'ADJ'),
#  ('acceded', 'NUM'),
#  ('cancer', 'NOUN'),
#  ('We', 'PRON'),
#  ('.', '.'),
#  ('officials', 'NOUN'),
#  ('in', 'ADP'),
#  ('judge', 'NOUN'),
#  ('$', '.'),
#  ('Article', 'NOUN'),
#  ('increase', 'NOUN'),
#  ('*', 'X'),
#  ('million', 'NUM'),
#  ('council', 'NOUN'),
#  ('in', 'ADP'),
#  ('aggressive', 'ADJ'),
#  ('million', 'NUM'),
#  ('7\\/8', 'NUM'),
#  ('continuing', 'VERB'),
#  ('.', '.'),
#  ('stations', 'NOUN'),
#  ('of', 'ADP'),
#  (',', '.'),
#  ('some', 'DET'),
#  ('1992', 'NUM'),
#  ('Pratt', 'NOUN'),
#  ('stadium', 'NOUN'),
#  ('Germany-based', 'NUM'),
#  ("'", 'PRT'),
#  ('about', 'ADP'),
#  ('confirm', 'VERB'),
#  ('to', 'PRT'),
#  ('Waertsilae', 'NOUN'),
#  (',', '.'),
#  ('and', 'CONJ'),
#  ('B.', 'NOUN'),
#  (',', '.'),
#  ('*U*', 'X'),
#  ('cents', 'NOUN'),
#  ("'s", 'PRT'),
#  ('were', 'VERB'),
#  ('estimate', 'NOUN'),
#  ('activity', 'NOUN'),
#  ('U.S.', 'NOUN'),
#  ('on', 'ADP'),
#  ('is', 'VERB'),
#  (';', '.'),
#  ('to', 'PRT'),
#  ('New', 'NOUN'),
#  ('say', 'VERB'),
#  ('voluntarily', 'ADV'),
#  ('decided', 'VERB'),
#  ('earthquake', 'NOUN'),
#  (',', '.'),
#  ('*', 'X'),
#  ('the', 'DET'),
#  ('business', 'NOUN'),
#  ('it', 'PRON'),
#  ('new', 'ADJ'),
#  ('directors', 'NOUN'),
#  ('$', '.'),
#  ('though', 'ADP'),
#  ('proposed', 'VERB'),
#  ('*-25', 'X'),
#  ('is', 'VERB'),
#  ('capital', 'NOUN'),
#  ('says', 'VERB'),
#  ('for', 'ADP'),
#  ('Corp.', 'NOUN'),
#  ('into', 'ADP'),
#  ('6.20', 'NUM'),
#  ('.', '.'),
#  ('for', 'ADP'),
#  (',', '.'),
#  ('a', 'DET'),
#  ('$', '.'),
#  ('trading', 'NOUN'),
#  ('venture', 'NOUN'),
#  ('and', 'CONJ'),
#  ('or', 'CONJ'),
#  ('it', 'PRON'),
#  (',', '.'),
#  ('of', 'ADP'),
#  (',', '.'),
#  ('than', 'ADP'),
#  ('*-1', 'X'),
#  ('to', 'PRT'),
#  ('million', 'NUM'),
#  ('With', 'ADP'),
#  ('--', '.'),
#  ('will', 'VERB'),
#  ('to', 'PRT'),
#  ('a', 'DET'),
#  ('anticipating', 'NUM'),
#  ('Mitsui', 'NOUN'),
#  ('student', 'NOUN'),
#  ('further', 'ADJ'),
#  ('that', 'ADP'),
#  ('0', 'X'),
#  ('County', 'NOUN'),
#  ('down', 'ADV'),
#  ('right', 'NOUN'),
#  ('sources', 'NOUN'),
#  ('the', 'DET'),
#  ('$', '.'),
#  ('WHAS', 'NUM'),
#  ('after', 'ADP'),
#  ('indexers', 'NOUN'),
#  ('It', 'PRON'),
#  ('USX', 'NOUN'),
#  ('shares', 'NOUN'),
#  ('niches', 'NUM'),
#  ('could', 'VERB'),
#  ('is', 'VERB'),
#  (',', '.'),
#  ('the', 'DET'),
#  ('retailing', 'NOUN'),
#  (',', '.'),
#  ('answers', 'NOUN'),
#  ('to', 'PRT'),
#  ('*T*-3', 'X'),
#  ('because', 'ADP'),
#  ('is', 'VERB'),
#  ('the', 'DET'),
#  ('the', 'DET'),
#  ('take', 'VERB'),
#  ('Each', 'DET'),
#  ('to', 'PRT'),
#  ('Administration', 'NOUN'),
#  ('3.7', 'NUM'),
#  ('stock', 'NOUN'),
#  ('unchanged', 'ADJ'),
#  ('as', 'ADP'),
#  (',', '.'),
#  ('would', 'VERB'),
#  ('the', 'DET'),
#  ('*', 'X'),
#  ('*-1', 'X'),
#  (',', '.'),
#  ('three', 'NUM'),
#  ('sort', 'NOUN'),
#  ('will', 'VERB'),
#  ('``', '.'),
#  ('notion', 'NOUN'),
#  ('took', 'VERB'),
#  ('.', '.'),
#  ('China', 'NOUN'),
#  (',', '.'),
#  ('cultivation', 'NUM'),
#  ('units', 'NOUN'),
#  (',', '.'),
#  ('to', 'PRT'),
#  ('freedom', 'NOUN'),
#  ('New', 'NOUN'),
#  ('plunged', 'VERB'),
#  ('field', 'NOUN'),
#  ('*T*-57', 'X'),
#  ('Then', 'ADV'),
#  ('features', 'NOUN'),
#  ('%', 'NOUN'),
#  ('trade', 'NOUN'),
#  ('.', '.'),
#  ('By', 'ADP'),
#  ('investor', 'NOUN'),
#  ('new', 'ADJ'),
#  ("'s", 'PRT'),
#  ('say', 'VERB'),
#  ('main', 'ADJ'),
#  ('of', 'ADP'),
#  ('two', 'NUM'),
#  ('of', 'ADP'),
#  ('the', 'DET'),
#  ('pyramids', 'NOUN'),
#  ('0', 'X'),
#  ('*U*', 'X'),
#  ('trading', 'NOUN'),
#  (',', '.'),
#  ('became', 'VERB'),
#  (',', '.'),
#  ('development', 'NOUN'),
#  ('Jim', 'NOUN'),
#  ('will', 'VERB'),
#  ('the', 'DET'),
#  ('0', 'X'),
#  ('together', 'ADV'),
#  ('Travelers', 'NOUN'),
#  ('.', '.'),
#  ('in', 'ADP'),
#  ('those', 'DET'),
#  ('Mr.', 'NOUN'),
#  (',', '.'),
#  ('constitutional', 'ADJ'),
#  ('38', 'NUM'),
#  ('banks', 'NOUN'),
#  ('0', 'X'),
#  ('enforcement', 'NOUN'),
#  ('While', 'ADP'),
#  ('*T*-155', 'NUM'),
#  (',', '.'),
#  ('several', 'ADJ'),
#  ('commercial', 'ADJ'),
#  ('ground', 'NOUN'),
#  ('received', 'VERB'),
#  ('some', 'DET'),
#  ('Johns', 'NUM'),
#  ('that', 'ADP'),
#  ('introduce', 'VERB'),
#  ('Treasury', 'NOUN'),
#  ('as', 'ADP'),
#  ('extend', 'VERB'),
#  ('Sun', 'NOUN'),
#  ('.', '.'),
#  ('pass', 'VERB'),
#  ('advertisers', 'NOUN'),
#  ('to', 'PRT'),
#  ('gives', 'VERB'),
#  ('beverage', 'NUM'),
#  ('$', '.'),
#  ('Forster', 'NOUN'),
#  ('list', 'NOUN'),
#  ("n't", 'ADV'),
#  ('chief', 'NOUN'),
#  ('billion', 'NUM'),
#  ('airline', 'NOUN'),
#  ('120', 'NUM'),
#  ('Inc.', 'NOUN'),
#  ('pay', 'VERB'),
#  ('``', '.'),
#  ('in', 'ADP'),
#  ('matter', 'NOUN'),
#  ('2.1', 'NUM'),
#  ('--', '.'),
#  ('related', 'VERB'),
#  ('%', 'NOUN'),
#  ('unsettled', 'NUM'),
#  ('extraordinary', 'ADJ'),
#  ('elementary', 'NUM'),
#  ('appeals', 'NOUN'),
#  ('because', 'ADP'),
#  ('Negus', 'NUM'),
#  ('problems', 'NOUN'),
#  ('first', 'ADJ'),
#  ('five-cent', 'NUM'),
#  ('banks', 'NOUN'),
#  ('.', '.'),
#  ('with', 'ADP'),
#  ('back', 'ADV'),
#  ('Valhi', 'NOUN'),
#  ('Year', 'NOUN'),
#  ('the', 'DET'),
#  ('big', 'ADJ'),
#  (',', '.'),
#  ('bank', 'NOUN'),
#  ('test', 'NOUN'),
#  ('offer', 'NOUN'),
#  ('.', '.'),
#  ('it', 'PRON'),
#  ('for', 'ADP'),
#  ('cigarette', 'NOUN'),
#  ('trade', 'NOUN'),
#  ('days', 'NOUN'),
#  ('*', 'X'),
#  ('rose', 'VERB'),
#  ('going', 'VERB'),
#  ('do', 'VERB'),
#  ('a', 'DET'),
#  ('-RRB-', '.'),
#  ('any', 'DET'),
#  ("'", 'PRT'),
#  ('and', 'CONJ'),
#  ("''", '.'),
#  ('18-a-share', 'NUM'),
#  ('the', 'DET'),
#  ('growth', 'NOUN'),
#  ('0', 'X'),
#  ('drugs', 'NOUN'),
#  ('were', 'VERB'),
#  ('.', '.'),
#  ('make', 'VERB'),
#  ('unexpected', 'NUM'),
#  ('*U*', 'X'),
#  ('2', 'NUM'),
#  ('the', 'DET'),
#  ('the', 'DET'),
#  ('and', 'CONJ'),
#  ('*-1', 'X'),
#  (',', '.'),
#  ('.', '.'),
#  (',', '.'),
#  ('*T*-2', 'X'),
#  ("'s", 'PRT'),
#  ('are', 'VERB'),
#  ('trade', 'NOUN'),
#  ('however', 'ADV'),
#  ('Big', 'NOUN'),
#  ('construction', 'NOUN'),
#  ('since', 'ADP'),
#  ('the', 'DET'),
#  ('a', 'DET'),
#  ('from', 'ADP'),
#  ('said', 'VERB'),
#  (',', '.'),
#  ('*T*-1', 'X'),
#  ('.', '.'),
#  ('for', 'ADP'),
#  ('bankrupt', 'NUM'),
#  ('in', 'ADP'),
#  ('$', '.'),
#  ('offered', 'VERB'),
#  ('from', 'ADP'),
#  ('-RRB-', '.'),
#  ('Pro-forma', 'NUM'),
#  ('*U*', 'X'),
#  ('at', 'ADP'),
#  ("'s", 'PRT'),
#  ('*T*-2', 'X'),
#  ('expected', 'VERB'),
#  ('Service', 'NOUN'),
#  ('placing', 'VERB'),
#  ('his', 'PRON'),
#  ('performance', 'NOUN'),
#  ('the', 'DET'),
#  ("'s", 'PRT'),
#  ('was', 'VERB'),
#  ('is', 'VERB'),
#  ('hand', 'NOUN'),
#  ('.', '.'),
#  ('forecast', 'NOUN'),
#  ('was', 'VERB'),
#  ('Hugo', 'NOUN'),
#  ('subindustry', 'NUM'),
#  ('from', 'ADP'),
#  ('included', 'VERB'),
#  ('guild', 'NOUN'),
#  ('*U*', 'X'),
#  ('.', '.'),
#  ('of', 'ADP'),
#  ("''", '.'),
#  ('the', 'DET'),
#  ('said', 'VERB'),
#  ('*T*-1', 'X'),
#  ('the', 'DET'),
#  ('0', 'X'),
#  ("'", 'PRT'),
#  ('billion', 'NUM'),
#  ('company', 'NOUN'),
#  ('sale', 'NOUN'),
#  ('for', 'ADP'),
#  ('Nippon', 'NOUN'),
#  ('their', 'PRON'),
#  (',', '.'),
#  ('Japanese', 'ADJ'),
#  ('one', 'NUM'),
#  ('who', 'PRON'),
#  ('gunship', 'NOUN'),
#  (',', '.'),
#  ('Your', 'PRON'),
#  ("'s", 'PRT'),
#  ('are', 'VERB'),
#  ("n't", 'ADV'),
#  ('probably', 'ADV'),
#  ('.', '.'),
#  ('from', 'ADP'),
#  ('and', 'CONJ'),
#  ('interests', 'NOUN'),
#  ('supercomputer', 'NOUN'),
#  ('to', 'PRT'),
#  ('liability', 'NOUN'),
#  ('of', 'ADP'),
#  ('bonds', 'NOUN'),
#  ('$', '.'),
#  ('bottle', 'NOUN'),
#  ('the', 'DET'),
#  ('their', 'PRON'),
#  ('market', 'NOUN'),
#  ('in', 'ADP'),
#  ('Japanese', 'ADJ'),
#  ('year', 'NOUN'),
#  ('whipping', 'NUM'),
#  ('modestly', 'ADV'),
#  ('his', 'PRON'),
#  ('of', 'ADP'),
#  ('find', 'VERB'),
#  ('process', 'NOUN'),
#  ('two', 'NUM'),
#  (',', '.'),
#  ('1990s', 'NUM'),
#  ('30', 'NUM'),
#  (',', '.'),
#  ('friendship', 'NUM'),
#  ('demand', 'NOUN'),
#  ('stock', 'NOUN'),
#  ('protesters', 'NOUN'),
#  ('rose', 'VERB'),
#  ('has', 'VERB'),
#  ('goods', 'NOUN'),
#  ('.', '.'),
#  ('company', 'NOUN'),
#  ('these', 'DET'),
#  ('COMMUNICATIONS', 'NUM'),
#  ('article', 'NOUN'),
#  ('an', 'DET'),
#  ('on', 'ADP'),
#  (',', '.'),
#  ('expelled', 'VERB'),
#  ('on', 'ADP'),
#  ('some', 'DET'),
#  ('Altogether', 'NUM'),
#  ('he', 'PRON'),
#  (',', '.'),
#  ('in', 'ADP'),
#  ('big', 'ADJ'),
#  ('notes', 'NOUN'),
#  ('ban', 'NOUN'),
#  ('Sales', 'NOUN'),
#  ('in', 'ADP'),
#  ('underwriter', 'NOUN'),
#  ('%', 'NOUN'),
#  ('The', 'DET'),
#  ('of', 'ADP'),
#  ('0', 'X'),
#  ('index', 'NOUN'),
#  (',', '.'),
#  ('*T*-1', 'X'),
#  ('billion', 'NUM'),
#  ('during', 'ADP'),
#  ('those', 'DET'),
#  (',', '.'),
#  ('in', 'ADP'),
#  (',', '.'),
#  ('.', '.'),
#  ('choosing', 'VERB'),
#  ('positions', 'NOUN'),
#  ('absorbed', 'VERB'),
#  ('Christopher', 'NOUN'),
#  ('the', 'DET'),
#  ('D.', 'NOUN'),
#  ('Toronto', 'NOUN'),
#  ('as', 'ADP'),
#  ('*T*-31', 'X'),
#  ('deviant', 'NUM'),
#  ('*', 'X'),
#  ('.', '.'),
#  ('2', 'NUM'),
#  ('*T*-1', 'X'),
#  ('tumbled', 'VERB'),
#  ('companies', 'NOUN'),
#  ('even', 'ADV'),
#  ('Mexico', 'NOUN'),
#  ('outbid', 'NUM'),
#  ('researchers', 'NOUN'),
#  ('the', 'DET'),
#  ('also', 'ADV'),
#  ('seeing', 'VERB'),
#  ('the', 'DET'),
#  ('on', 'ADP'),
#  ('Mr.', 'NOUN'),
#  ('years', 'NOUN'),
#  ('more', 'ADJ'),
#  ('for', 'ADP'),
#  ('excessive', 'ADJ'),
#  ('Nelson', 'NOUN'),
#  ('help', 'VERB'),
#  ('probably', 'ADV'),
#  ('president', 'NOUN'),
#  ('fixed', 'VERB'),
#  ('of', 'ADP'),
#  ('the', 'DET'),
#  ('Previously', 'ADV'),
#  ('extent', 'NOUN'),
#  ('University', 'NOUN'),
#  ('been', 'VERB'),
#  (',', '.'),
#  ('minimum', 'ADJ'),
#  ('.', '.'),
#  ('Mrs.', 'NOUN'),
#  ('shipyard', 'NOUN'),
#  ('it', 'PRON'),
#  ('conference', 'NOUN'),
#  ('certain', 'ADJ'),
#  ('new', 'ADJ'),
#  ('semiliterate', 'NUM'),
#  ('0', 'X'),
#  ('said', 'VERB'),
#  ('stock-index', 'NOUN'),
#  ('of', 'ADP'),
#  ('insiders', 'NOUN'),
#  (',', '.'),
#  ('near', 'ADP'),
#  ('in', 'ADP'),
#  ('*U*', 'X'),
#  ('seven', 'NUM'),
#  (',', '.'),
#  ('president', 'NOUN'),
#  ('Used', 'NUM'),
#  ('was', 'VERB'),
#  ('fully', 'ADV'),
#  ('Johnny', 'NUM'),
#  ('other', 'ADJ'),
#  ('is', 'VERB'),
#  ('be', 'VERB'),
#  ('Ford', 'NOUN'),
#  ('Imports', 'NOUN'),
#  ('could', 'VERB'),
#  ('.', '.'),
#  ('a', 'DET'),
#  ('.', '.'),
#  ('us', 'PRON'),
#  ('stock', 'NOUN'),
#  ('hauling', 'NUM'),
#  ('International', 'NOUN'),
#  ('of', 'ADP'),
#  ('*', 'X'),
#  ('a', 'DET'),
#  ('fell', 'VERB'),
#  ('its', 'PRON'),
#  ('Donald', 'NOUN'),
#  ('group', 'NOUN'),
#  ('billion', 'NUM'),
#  ('.', '.'),
#  ('investments', 'NOUN'),
#  ('that', 'ADP'),
#  ('Angeles', 'NOUN'),
#  ('that', 'ADP'),
#  ('refinery', 'NUM'),
#  ('the', 'DET'),
#  ('trade', 'NOUN'),
#  ('for', 'ADP'),
#  ('judges', 'NOUN'),
#  ('fined', 'VERB'),
#  ('Department', 'NOUN'),
#  (',', '.'),
#  ('*U*', 'X'),
#  ('If', 'ADP'),
#  ('fields', 'NOUN'),
#  ('as', 'ADP'),
#  ("'s", 'PRT'),
#  ('would', 'VERB'),
#  ('7.88', 'NUM'),
#  ('moves', 'NOUN'),
#  ('Boston', 'NOUN'),
#  ('*U*', 'X'),
#  ('managers', 'NOUN'),
#  (',', '.'),
#  ('*-1', 'X'),
#  ('.', '.'),
#  ('.', '.'),
#  ('of', 'ADP'),
#  ('what', 'PRON'),
#  ('The', 'DET'),
#  ('expected', 'VERB'),
#  ('raise', 'VERB'),
#  ('bad', 'ADJ'),
#  ('was', 'VERB'),
#  ('%', 'NOUN'),
#  ('soared', 'VERB'),
#  ('of', 'ADP'),
#  ('cars', 'NOUN'),
#  ('is', 'VERB'),
#  ('deals', 'NOUN'),
#  ('executive', 'NOUN'),
#  ('.', '.'),
#  ('newspapers', 'NOUN'),
#  (',', '.'),
#  ('relations', 'NOUN'),
#  ('of', 'ADP'),
#  ('other', 'ADJ'),
#  ('is', 'VERB'),
#  ('performance', 'NOUN'),
#  ('to', 'PRT'),
#  ('assets', 'NOUN'),
#  ('joining', 'VERB'),
#  ('the', 'DET'),
#  ('.', '.'),
#  ('have', 'VERB'),
#  ('``', '.'),
#  ('Congress', 'NOUN'),
#  ('to', 'PRT'),
#  ('declined', 'VERB'),
#  ('editor', 'NOUN'),
#  ('are', 'VERB'),
#  ('We', 'PRON'),
#  ('*ICH*-1', 'X'),
#  ('thrifts', 'NOUN'),
#  (',', '.'),
#  ('independent', 'ADJ'),
#  ('board', 'NOUN'),
#  (',', '.'),
#  ('the', 'DET'),
#  ('*-2', 'X'),
#  (',', '.'),
#  (',', '.'),
#  ('she', 'PRON'),
#  ('fixed', 'VERB'),
#  ("'re", 'VERB'),
#  ('lying', 'VERB'),
#  ('&', 'CONJ'),
#  ('profit', 'NOUN'),
#  ('of', 'ADP'),
#  ('.', '.'),
#  ('advertise', 'VERB'),
#  ('Friedrichs', 'NUM'),
#  ('the', 'DET'),
#  ('to', 'PRT'),
#  ('Black', 'NOUN'),
#  ('demand', 'NOUN'),
#  ('number', 'NOUN'),
#  (',', '.'),
#  ('new', 'ADJ'),
#  ('the', 'DET'),
#  ('omnipresent', 'NUM'),
#  ('a', 'DET'),
#  ('the', 'DET'),
#  ('earlier', 'ADJ'),
#  ('young', 'ADJ'),
#  ('plant', 'NOUN'),
#  ('Scoring', 'NOUN'),
#  ('750', 'NUM'),
#  ('even', 'ADV'),
#  ('to', 'PRT'),
#  ('been', 'VERB'),
#  ('not', 'ADV'),
#  ('*', 'X'),
#  ('*T*-55', 'X'),
#  ('and', 'CONJ'),
#  ('of', 'ADP'),
#  ('says', 'VERB'),
#  (',', '.'),
#  ('*U*', 'X'),
#  ('NBI', 'NOUN'),
#  ('$', '.'),
#  ('*-1', 'X'),
#  ('including', 'VERB'),
#  ('to', 'PRT'),
#  ('*-1', 'X'),
#  ('of', 'ADP'),
#  ('Poland', 'NOUN'),
#  ('people', 'NOUN'),
#  ('amount', 'NOUN'),
#  ('says', 'VERB'),
#  ('*T*-1', 'X'),
#  ('what', 'PRON'),
#  ('sentiment', 'NOUN'),
#  ('Elisabeth', 'NUM'),
#  ('the', 'DET'),
#  ('Chicago', 'NOUN'),
#  ('new', 'ADJ'),
#  ('crystals', 'NOUN'),
#  ('But', 'CONJ'),
#  ('29.9', 'NUM'),
#  ('program', 'NOUN'),
#  ('rather', 'ADV'),
#  ('would', 'VERB'),
#  ('*-1', 'X'),
#  (',', '.'),
#  ('Among', 'ADP'),
#  ('by', 'ADP'),
#  ('was', 'VERB'),
#  ('-LRB-', '.'),
#  ('which', 'DET'),
#  ('ones', 'NOUN'),
#  ('We', 'PRON'),
#  ('%', 'NOUN'),
#  ('loss', 'NOUN'),
#  ('in', 'ADP'),
#  ('improvement', 'NOUN'),
#  ('``', '.'),
#  ('consumer', 'NOUN'),
#  ('the', 'DET'),
#  (',', '.'),
#  ('RMS', 'NOUN'),
#  ('to', 'PRT'),
#  ('prices', 'NOUN'),
#  ('which', 'DET'),
#  ('lesser', 'NUM'),
#  ('Newsweek', 'NOUN'),
#  ('.', '.'),
#  ('*-3', 'X'),
#  ('Dominion', 'NUM'),
#  ('a', 'DET'),
#  ('*-2', 'X'),
#  ('Wednesday', 'NOUN'),
#  ('of', 'ADP'),
#  ('losses', 'NOUN'),
#  ('*', 'X'),
#  ('Mr.', 'NOUN'),
#  ('.', '.'),
#  ('but', 'CONJ'),
#  ('.', '.'),
#  ('rose', 'VERB'),
#  ('Korea', 'NOUN'),
#  ('to', 'PRT'),
#  ('the', 'DET'),
#  ('farm', 'NOUN'),
#  ('conditions', 'NOUN'),
#  ('investor', 'NOUN'),
#  ('of', 'ADP'),
#  ('.', '.'),
#  ('have', 'VERB'),
#  ('have', 'VERB'),
#  ('the', 'DET'),
#  ('write-downs', 'NUM'),
#  ('researchers', 'NOUN'),
#  ('and', 'CONJ'),
#  ('to', 'PRT'),
#  ('Its', 'PRON'),
#  ('William', 'NOUN'),
#  ('paid', 'VERB'),
#  ('Dover', 'NOUN'),
#  ('45', 'NUM'),
#  ('installment', 'NOUN'),
#  (',', '.'),
#  ('earnings', 'NOUN'),
#  ('allegedly', 'ADV'),
#  ('He', 'PRON'),
#  ('were', 'VERB'),
#  ('0', 'X'),
#  ('deposit', 'NOUN'),
#  ('allow', 'VERB'),
#  ('the', 'DET'),
#  ('a', 'DET'),
#  ('walls', 'NUM'),
#  ('9.9', 'NUM'),
#  ('health', 'NOUN'),
#  ('the', 'DET'),
#  (',', '.'),
#  ('U.S.', 'NOUN'),
#  ('*', 'X'),
#  ('hoped', 'NUM'),
#  ('days', 'NOUN'),
#  ('be', 'VERB'),
#  ('*-2', 'X'),
#  ('down', 'ADV'),
#  ('chief', 'NOUN'),
#  ('offer', 'NOUN'),
#  ('--', '.'),
#  ('victims', 'NOUN'),
#  ('change', 'NOUN'),
#  ('dissemination', 'NOUN'),
#  ('less', 'ADJ'),
#  ('Its', 'PRON'),
#  ('from', 'ADP'),
#  ('fees', 'NOUN'),
#  ('Tribune', 'NUM'),
#  ("''", '.'),
#  ('*T*-1', 'X'),
#  ('most', 'ADJ'),
#  ('Coleco', 'NOUN'),
#  ('and', 'CONJ'),
#  ('Despite', 'ADP'),
#  ('the', 'DET'),
#  ('two', 'NUM'),
#  ('found', 'VERB'),
#  ('*-2', 'X'),
#  ('Rapanelli', 'NOUN'),
#  ('between', 'ADP'),
#  ('result', 'VERB'),
#  ('than', 'ADP'),
#  ('link', 'NOUN'),
#  ('one', 'NUM'),
#  ('year', 'NOUN'),
#  ('for', 'ADP'),
#  ('Still', 'ADV'),
#  ('a', 'DET'),
#  ('special', 'ADJ'),
#  ('.', '.'),
#  ('.', '.'),
#  ('the', 'DET'),
#  ('.', '.'),
#  ('unless', 'ADP'),
#  ('Iowa', 'NOUN'),
#  ("''", '.'),
#  ('with', 'ADP'),
#  ('*-2', 'X'),
#  (',', '.'),
#  ('see', 'VERB'),
#  ('completed', 'VERB'),
#  ('.', '.'),
#  ('from', 'ADP'),
#  ('in', 'ADP'),
#  ('customers', 'NOUN'),
#  ('September', 'NOUN'),
#  ('students', 'NOUN'),
#  ('could', 'VERB'),
#  ('ever', 'ADV'),
#  ('*-1', 'X'),
#  ('off', 'PRT'),
#  ("''", '.'),
#  ('Chicago', 'NOUN'),
#  ('Columbia', 'NOUN'),
#  ('become', 'VERB'),
#  ('they', 'PRON'),
#  ('Bund', 'NUM'),
#  ('*-101', 'NUM'),
#  ('and', 'CONJ'),
#  ('clerics', 'NUM'),
#  ('his', 'PRON'),
#  ('certain', 'ADJ'),
#  ('amicable', 'NUM'),
#  ('almost', 'ADV'),
#  ('$', '.'),
#  ('on', 'ADP'),
#  ('of', 'ADP'),
#  ('profit', 'NOUN'),
#  ('as', 'ADP'),
#  ('*T*-3', 'X'),
#  ('departure', 'NOUN'),
#  ('would', 'VERB'),
#  ('smiles', 'NUM'),
#  ('0', 'X'),
#  ('*T*-1', 'X'),
#  ('trade', 'NOUN'),
#  ('10', 'NUM'),
#  ('about', 'ADP'),
#  ('decision', 'NOUN'),
#  ('.', '.'),
#  ('selected', 'VERB'),
#  ('type', 'NOUN'),
#  ('*T*-2', 'X'),
#  ('High', 'NOUN'),
#  ('campaigning', 'NOUN'),
#  ('futures', 'NOUN'),
#  ('of', 'ADP'),
#  ('highly', 'ADV'),
#  ('.', '.'),
#  ('chairman', 'NOUN'),
#  ('decline', 'NOUN'),
#  ('down', 'ADV'),
#  (',', '.'),
#  ('advertising', 'NOUN'),
#  ('least', 'ADJ'),
#  ('.', '.'),
#  ('he', 'PRON'),
#  ('government', 'NOUN'),
#  ('15', 'NUM'),
#  ("'s", 'PRT'),
#  ('--', '.'),
#  ('have', 'VERB'),
#  ('``', '.'),
#  ('Sen.', 'NOUN'),
#  ('*-1', 'X'),
#  ('of', 'ADP'),
#  ('anti-drug', 'NUM'),
#  ('run', 'VERB'),
#  ('legal', 'ADJ'),
#  ('about', 'ADP'),
#  ('and', 'CONJ'),
#  ('other', 'ADJ'),
#  ('1', 'NUM'),
#  ('river', 'NOUN'),
#  ('Something', 'NUM'),
#  ('classics', 'NOUN'),
#  ('is', 'VERB'),
#  ('Home', 'NOUN'),
#  ('.', '.'),
#  ('actions', 'NOUN'),
#  ('It', 'PRON'),
#  ('it', 'PRON'),
#  ('days', 'NOUN'),
#  ('was', 'VERB'),
#  ('The', 'DET'),
#  ('he', 'PRON'),
#  ('proportion', 'NUM'),
#  ('the', 'DET'),
#  ('panel', 'NOUN'),
#  ('80', 'NUM'),
#  ('.', '.'),
#  ('breaks', 'VERB'),
#  ('approved', 'VERB'),
#  ('legislators', 'NUM'),
#  ('citing', 'VERB'),
#  ('it', 'PRON'),
#  ('feel', 'VERB'),
#  ('*T*-1', 'X'),
#  ('*T*-1', 'X'),
#  ('sure', 'ADJ'),
#  ('$', '.'),
#  ('private', 'ADJ'),
#  ('N.C.', 'NOUN'),
#  ("'s", 'PRT'),
#  ('Stories', 'NOUN'),
#  (',', '.'),
#  ('Crane', 'NOUN'),
#  ('by', 'ADP'),
#  ('Prater', 'NUM'),
#  ('if', 'ADP'),
#  ('during', 'ADP'),
#  ('Says', 'VERB'),
#  ('of', 'ADP'),
#  ...]

# %%
# accuracy
check = [i for i, j in zip(tagged_seq, test_set) if i == j] 
accuracy = len(check)/len(tagged_seq)
accuracy
# Out:
# 0.9119984108065157

# %% [markdown]
# #### Analyzing Incorrect tags

# %%
incorrect_tagged_cases = [j[0] for i, j in enumerate(zip(tagged_seq, test_set)) if j[0]!=j[1]]
incorrect_tagged_cases
# Out:
# [('constituent', 'NUM'),
#  ('closing', 'ADJ'),
#  ('Raul', 'NUM'),
#  ('acceded', 'NUM'),
#  ('increase', 'NOUN'),
#  ('Germany-based', 'NUM'),
#  ('anticipating', 'NUM'),
#  ('down', 'ADV'),
#  ('right', 'NOUN'),
#  ('WHAS', 'NUM'),
#  ('niches', 'NUM'),
#  ('cultivation', 'NUM'),
#  ('together', 'ADV'),
#  ('*T*-155', 'NUM'),
#  ('Johns', 'NUM'),
#  ('that', 'ADP'),
#  ('beverage', 'NUM'),
#  ('unsettled', 'NUM'),
#  ('elementary', 'NUM'),
#  ('Negus', 'NUM'),
#  ('five-cent', 'NUM'),
#  ('back', 'ADV'),
#  ('offer', 'NOUN'),
#  ('18-a-share', 'NUM'),
#  ('unexpected', 'NUM'),
#  ('trade', 'NOUN'),
#  ('bankrupt', 'NUM'),
#  ('Pro-forma', 'NUM'),
#  ('subindustry', 'NUM'),
#  ('Japanese', 'ADJ'),
#  ('Japanese', 'ADJ'),
#  ('whipping', 'NUM'),
#  ('1990s', 'NUM'),
#  ('friendship', 'NUM'),
#  ('COMMUNICATIONS', 'NUM'),
#  ('Altogether', 'NUM'),
#  ('choosing', 'VERB'),
#  ('deviant', 'NUM'),
#  ('outbid', 'NUM'),
#  ('more', 'ADJ'),
#  ('help', 'VERB'),
#  ('minimum', 'ADJ'),
#  ('semiliterate', 'NUM'),
#  ('stock-index', 'NOUN'),
#  ('Used', 'NUM'),
#  ('Johnny', 'NUM'),
#  ('hauling', 'NUM'),
#  ('that', 'ADP'),
#  ('refinery', 'NUM'),
#  ('trade', 'NOUN'),
#  ('Friedrichs', 'NUM'),
#  ('omnipresent', 'NUM'),
#  ('Elisabeth', 'NUM'),
#  ('lesser', 'NUM'),
#  ('Dominion', 'NUM'),
#  ('write-downs', 'NUM'),
#  ('walls', 'NUM'),
#  ('hoped', 'NUM'),
#  ('down', 'ADV'),
#  ('change', 'NOUN'),
#  ('Tribune', 'NUM'),
#  ('most', 'ADJ'),
#  ('result', 'VERB'),
#  ('link', 'NOUN'),
#  ('Bund', 'NUM'),
#  ('*-101', 'NUM'),
#  ('clerics', 'NUM'),
#  ('amicable', 'NUM'),
#  ('smiles', 'NUM'),
#  ('decline', 'NOUN'),
#  ('down', 'ADV'),
#  ('anti-drug', 'NUM'),
#  ('Something', 'NUM'),
#  ('proportion', 'NUM'),
#  ('legislators', 'NUM'),
#  ('sure', 'ADJ'),
#  ('Prater', 'NUM'),
#  ('controls', 'NOUN'),
#  ('Woodcliff', 'NUM'),
#  ('that', 'ADP'),
#  ('dissident', 'NUM'),
#  ('lending', 'NUM'),
#  ('that', 'ADP'),
#  ('rise', 'VERB'),
#  ('Landor', 'NUM'),
#  ('conducted', 'NUM'),
#  ('Solaia', 'NUM'),
#  ('Prior', 'NUM'),
#  ('Kappa', 'NUM'),
#  ('mood', 'NUM'),
#  ('that', 'ADP'),
#  ('range', 'NOUN'),
#  ('injecting', 'NUM'),
#  ('highway', 'NUM'),
#  ('skittishness', 'NUM'),
#  ('house', 'NOUN'),
#  ('which', 'DET'),
#  ('Soviet', 'ADJ'),
#  ('much', 'ADV'),
#  ('unitary', 'NUM'),
#  ('octogenarians', 'NUM'),
#  ('five-point', 'NUM'),
#  ('pressman', 'NUM'),
#  ('that', 'ADP'),
#  ('advance', 'NOUN'),
#  ('colder', 'NUM'),
#  ('tracking', 'NUM'),
#  ('greenmailer', 'NUM'),
#  ('attributes', 'NUM'),
#  ('lover', 'NUM'),
#  ('adverse', 'NUM'),
#  ('reeling', 'NUM'),
#  ('blindfold', 'NUM'),
#  ('styles', 'NUM'),
#  ('bunches', 'NUM'),
#  ('zoomed', 'NUM'),
#  ('abide', 'NUM'),
#  ('Rill', 'NUM'),
#  ('solicitous', 'NUM'),
#  ('shows', 'VERB'),
#  ('hard', 'ADJ'),
#  ('adequate', 'NUM'),
#  ('philosophy', 'NUM'),
#  ('that', 'ADP'),
#  ('better', 'ADV'),
#  ('requesting', 'NUM'),
#  ('10th', 'NUM'),
#  ('foods', 'NUM'),
#  ('circle', 'NUM'),
#  ('Hale', 'NUM'),
#  ('fizzled', 'NUM'),
#  ('curses', 'NUM'),
#  ('storm', 'NUM'),
#  ('Ian', 'NUM'),
#  ('profit', 'NOUN'),
#  ('common', 'ADJ'),
#  ('that', 'ADP'),
#  ('yield', 'VERB'),
#  ('Mutual', 'NUM'),
#  ('entertainment', 'NUM'),
#  ('glory', 'NUM'),
#  ('sluggishness', 'NUM'),
#  ('brilliantly', 'NUM'),
#  ('fanciful', 'NUM'),
#  ('intricate', 'NUM'),
#  ('TEXAS', 'NUM'),
#  ('15-day', 'NUM'),
#  ('Darrell', 'NUM'),
#  ('notified', 'NUM'),
#  ('ushered', 'NUM'),
#  ('Traditional', 'NUM'),
#  ('so', 'ADV'),
#  ('hint', 'NUM'),
#  ('senior', 'ADJ'),
#  ('existed', 'NUM'),
#  ('stick', 'NUM'),
#  ('act', 'NOUN'),
#  ('conduct', 'VERB'),
#  ('that', 'ADP'),
#  ('heavy-truck', 'NUM'),
#  ('copying', 'NUM'),
#  ('baskets', 'NUM'),
#  ('acetate', 'NUM'),
#  ('addressing', 'NUM'),
#  ('machinists', 'NUM'),
#  ('for', 'ADP'),
#  ('report', 'NOUN'),
#  ('executive', 'NOUN'),
#  ('Dynamics', 'NUM'),
#  ('rang', 'NUM'),
#  ('next', 'ADJ'),
#  ('only', 'ADV'),
#  ('rap', 'NUM'),
#  ('notwithstanding', 'NUM'),
#  ('penchant', 'NUM'),
#  ('indexes', 'NUM'),
#  ('morale-damaging', 'NUM'),
#  ('comment', 'NOUN'),
#  ('rescheduled', 'NUM'),
#  ('ancillary', 'NUM'),
#  ('workplace', 'NUM'),
#  ('increase', 'NOUN'),
#  ('digs', 'NUM'),
#  ('infringed', 'NUM'),
#  ('total', 'NOUN'),
#  ('rate-sensitive', 'NUM'),
#  ('yield', 'VERB'),
#  ('Northampton', 'NUM'),
#  ('broaden', 'NUM'),
#  ('*-132', 'NUM'),
#  ('replies', 'NOUN'),
#  ('So', 'ADV'),
#  ('British', 'ADJ'),
#  ('adjustment', 'NUM'),
#  ('that', 'ADP'),
#  ('accountant', 'NUM'),
#  ('consumption', 'NUM'),
#  ('more', 'ADJ'),
#  ('Austrian', 'NUM'),
#  ('surveyed', 'NUM'),
#  ('*T*-147', 'NUM'),
#  ('used', 'VERB'),
#  ('*T*-142', 'NUM'),
#  ('much', 'ADV'),
#  ('suit', 'NOUN'),
#  ('stock-selection', 'NUM'),
#  ('Patients', 'NUM'),
#  ('American', 'NOUN'),
#  ('five-point', 'NUM'),
#  ('*T*-247', 'NUM'),
#  ('trade', 'NOUN'),
#  ('booklet', 'NUM'),
#  ('painted', 'NUM'),
#  ('expression', 'NUM'),
#  ('stock-index', 'NOUN'),
#  ('up', 'PRT'),
#  ('Rhone', 'NUM'),
#  ('immense', 'NUM'),
#  ('Syracuse', 'NUM'),
#  ('OFFERED', 'NUM'),
#  ('threat', 'NUM'),
#  ('four-foot-high', 'NUM'),
#  ('cozy', 'NUM'),
#  ('creator', 'NUM'),
#  ('Jews', 'NUM'),
#  ('matters', 'NOUN'),
#  ('floral', 'NUM'),
#  ('line', 'NOUN'),
#  ('8300s', 'NUM'),
#  ('that', 'ADP'),
#  ('centralized', 'NUM'),
#  ('domestically', 'NUM'),
#  ('Centerbank', 'NUM'),
#  ('Corazon', 'NUM'),
#  ('silicone', 'NUM'),
#  ('much', 'ADV'),
#  ('Lefcourt', 'NUM'),
#  ('out', 'PRT'),
#  ('that', 'ADP'),
#  ('single-family', 'ADJ'),
#  ('B-1B', 'ADJ'),
#  ('Wellington', 'NUM'),
#  ('view', 'NOUN'),
#  ('Hammerton', 'NUM'),
#  ('winning', 'ADJ'),
#  ('dumbfounded', 'NUM'),
#  ('Cluff', 'NUM'),
#  ('joint-venture', 'NUM'),
#  ('support', 'NOUN'),
#  ('jeopardy', 'NUM'),
#  ('as', 'ADP'),
#  ('as', 'ADP'),
#  ('offers', 'VERB'),
#  ('Kensington', 'NUM'),
#  ('magnified', 'NUM'),
#  ('Guerrilla', 'NUM'),
#  ('live', 'VERB'),
#  ("CREATOR'S", 'NUM'),
#  ('boyfriends', 'NUM'),
#  ('tracked', 'NUM'),
#  ('graphs', 'NUM'),
#  ('redemption', 'NUM'),
#  ('writing', 'VERB'),
#  ('encounter', 'NUM'),
#  ('repay', 'NUM'),
#  ('lead', 'VERB'),
#  ('Portugal', 'NUM'),
#  ('Christie', 'NUM'),
#  ('battered', 'NUM'),
#  ('Brady', 'NUM'),
#  ('Municipal', 'ADJ'),
#  ('tumultuous', 'NUM'),
#  ('Ogilvy', 'NUM'),
#  ('Resistance', 'NUM'),
#  ('advice', 'NUM'),
#  ('binge', 'NUM'),
#  ('underlying', 'VERB'),
#  ('lending', 'NUM'),
#  ('starts', 'VERB'),
#  ('Chafic', 'NUM'),
#  ('remarkable', 'NUM'),
#  ('appeal', 'NOUN'),
#  ('anticipates', 'NUM'),
#  ('intrusions', 'NUM'),
#  ('stream', 'NUM'),
#  ('anticipates', 'NUM'),
#  ('that', 'ADP'),
#  ('Craftsmen', 'NUM'),
#  ('astonishment', 'NUM'),
#  ('enthusiasm', 'NUM'),
#  ('quantitive', 'NUM'),
#  ('feudal', 'NUM'),
#  ('pep', 'NUM'),
#  ('Notes', 'NUM'),
#  ('much', 'ADV'),
#  ('slack', 'NOUN'),
#  ('150-point', 'NUM'),
#  ('childish', 'NUM'),
#  ('restructure', 'NOUN'),
#  ('COMPUTERS', 'NUM'),
#  ('All', 'DET'),
#  ('record', 'NOUN'),
#  ('close', 'NOUN'),
#  ('electric-utility', 'NUM'),
#  ('issuing', 'NUM'),
#  ('Practical', 'NUM'),
#  ('review', 'NOUN'),
#  ('Personal', 'NUM'),
#  ('sleep', 'NOUN'),
#  ('black-and-white', 'NUM'),
#  ('signals', 'VERB'),
#  ('correct', 'ADJ'),
#  ("'s", 'PRT'),
#  ('highlight', 'NUM'),
#  ('Ravenswood', 'NUM'),
#  ('most', 'ADJ'),
#  ('ballroom', 'NUM'),
#  ('co-chairman', 'NUM'),
#  ('participant', 'NUM'),
#  ('free-enterprise', 'NUM'),
#  ('premises', 'NUM'),
#  ('early', 'ADJ'),
#  ('advisory', 'NUM'),
#  ('Gunmen', 'NUM'),
#  ('crash', 'NOUN'),
#  ('early-retirement', 'NUM'),
#  ('occupant', 'NUM'),
#  ('stand', 'VERB'),
#  ('downfall', 'NUM'),
#  ('*T*-87', 'NUM'),
#  ('rises', 'NUM'),
#  ('more', 'ADJ'),
#  ('racing', 'NUM'),
#  ('tallies', 'NUM'),
#  ('advocating', 'NUM'),
#  ('Proceeds', 'NUM'),
#  ('Crime', 'NUM'),
#  ('grants', 'NUM'),
#  ('Julia', 'NUM'),
#  ('237-seat', 'NUM'),
#  ('summons', 'NUM'),
#  ('migrate', 'NUM'),
#  ('Pick', 'NUM'),
#  ('enthusiasm', 'NUM'),
#  ('good-faith', 'NUM'),
#  ('HOME', 'NUM'),
#  ('report', 'NOUN'),
#  ('pretax', 'NOUN'),
#  ('disappears', 'NUM'),
#  ('plans', 'VERB'),
#  ('wasted', 'NUM'),
#  ('classmates', 'NUM'),
#  ('mandates', 'NUM'),
#  ('Pattenden', 'NUM'),
#  ('charts', 'NUM'),
#  ('constitutional-law', 'NUM'),
#  ('threat', 'NUM'),
#  ('crossed', 'NUM'),
#  ('as', 'ADP'),
#  ('Uzi-model', 'NUM'),
#  ('underperforming', 'NUM'),
#  ('color', 'NOUN'),
#  ('Woodward', 'NUM'),
#  ('reprove', 'NUM'),
#  ('averaged', 'NUM'),
#  ('move', 'NOUN'),
#  ("'s", 'PRT'),
#  ('shipyards', 'NUM'),
#  ('hoopla', 'NUM'),
#  ('Rent-A-Car', 'NUM'),
#  ('*T*-172', 'NUM'),
#  ('Kathryn', 'NUM'),
#  ('bid', 'NOUN'),
#  ('Contra', 'NUM'),
#  ('prisoners', 'NUM'),
#  ('Gelles', 'NUM'),
#  ('reportedly', 'NUM'),
#  ('Bellows', 'NUM'),
#  ('Garanti', 'NUM'),
#  ('executive', 'NOUN'),
#  ('maybe', 'NUM'),
#  ('treats', 'NUM'),
#  ('reasonably', 'NUM'),
#  ('answer', 'NOUN'),
#  ('Piero', 'NUM'),
#  ('in', 'ADP'),
#  ('listeners', 'NUM'),
#  ('statutory', 'NUM'),
#  ('away', 'ADV'),
#  ('spotted', 'NUM'),
#  ('up', 'PRT'),
#  ('EC', 'NUM'),
#  ('Westport', 'NUM'),
#  ('appearing', 'NUM'),
#  ('funded', 'VERB'),
#  ('Wilmington', 'NUM'),
#  ('more', 'ADJ'),
#  ('dominating', 'NUM'),
#  ('Village', 'NUM'),
#  ('old-fashioned', 'NUM'),
#  ('much', 'ADV'),
#  ('Civil', 'NUM'),
#  ('more', 'ADJ'),
#  ('utterly', 'NUM'),
#  ('Soups', 'NUM'),
#  ('more', 'ADJ'),
#  ('males', 'NUM'),
#  ('cheat', 'NUM'),
#  ('fund', 'NOUN'),
#  ('b', 'NUM'),
#  ('flexibility', 'NUM'),
#  ('gilt', 'NUM'),
#  ('Chicago-style', 'NUM'),
#  ("'s", 'PRT'),
#  ('that', 'ADP'),
#  ('nondurable', 'NUM'),
#  ('down', 'ADV'),
#  ('bakery', 'NUM'),
#  ('Often', 'NUM'),
#  ('Orrick', 'NUM'),
#  ('*T*-107', 'NUM'),
#  ('slew', 'NUM'),
#  ('Bates', 'NUM'),
#  ('crystal-lattice', 'NOUN'),
#  ('folded', 'NUM'),
#  ('personally', 'NUM'),
#  ('plane', 'NUM'),
#  ('draws', 'NUM'),
#  ('yen-denominated', 'NUM'),
#  ('shipboard', 'NUM'),
#  ('reclaimed', 'NUM'),
#  ('*T*-118', 'NUM'),
#  ('laid', 'NUM'),
#  ('much', 'ADV'),
#  ('papers', 'NUM'),
#  ('Hackensack', 'NUM'),
#  ('Fulbright', 'NUM'),
#  ('baskets', 'NUM'),
#  ('attempts', 'NOUN'),
#  ('Orville', 'NUM'),
#  ('Islamic', 'NUM'),
#  ('fall', 'NOUN'),
#  ('down', 'ADV')]

# %%
len(incorrect_tagged_cases)
# Out:
# 443

# %%
set(incorrect_tagged_cases)
# Out:
# {("'s", 'PRT'),
#  ('*-101', 'NUM'),
#  ('*-132', 'NUM'),
#  ('*T*-107', 'NUM'),
#  ('*T*-118', 'NUM'),
#  ('*T*-142', 'NUM'),
#  ('*T*-147', 'NUM'),
#  ('*T*-155', 'NUM'),
#  ('*T*-172', 'NUM'),
#  ('*T*-247', 'NUM'),
#  ('*T*-87', 'NUM'),
#  ('10th', 'NUM'),
#  ('15-day', 'NUM'),
#  ('150-point', 'NUM'),
#  ('18-a-share', 'NUM'),
#  ('1990s', 'NUM'),
#  ('237-seat', 'NUM'),
#  ('8300s', 'NUM'),
#  ('All', 'DET'),
#  ('Altogether', 'NUM'),
#  ('American', 'NOUN'),
#  ('Austrian', 'NUM'),
#  ('B-1B', 'ADJ'),
#  ('Bates', 'NUM'),
#  ('Bellows', 'NUM'),
#  ('Brady', 'NUM'),
#  ('British', 'ADJ'),
#  ('Bund', 'NUM'),
#  ('COMMUNICATIONS', 'NUM'),
#  ('COMPUTERS', 'NUM'),
#  ("CREATOR'S", 'NUM'),
#  ('Centerbank', 'NUM'),
#  ('Chafic', 'NUM'),
#  ('Chicago-style', 'NUM'),
#  ('Christie', 'NUM'),
#  ('Civil', 'NUM'),
#  ('Cluff', 'NUM'),
#  ('Contra', 'NUM'),
#  ('Corazon', 'NUM'),
#  ('Craftsmen', 'NUM'),
#  ('Crime', 'NUM'),
#  ('Darrell', 'NUM'),
#  ('Dominion', 'NUM'),
#  ('Dynamics', 'NUM'),
#  ('EC', 'NUM'),
#  ('Elisabeth', 'NUM'),
#  ('Friedrichs', 'NUM'),
#  ('Fulbright', 'NUM'),
#  ('Garanti', 'NUM'),
#  ('Gelles', 'NUM'),
#  ('Germany-based', 'NUM'),
#  ('Guerrilla', 'NUM'),
#  ('Gunmen', 'NUM'),
#  ('HOME', 'NUM'),
#  ('Hackensack', 'NUM'),
#  ('Hale', 'NUM'),
#  ('Hammerton', 'NUM'),
#  ('Ian', 'NUM'),
#  ('Islamic', 'NUM'),
#  ('Japanese', 'ADJ'),
#  ('Jews', 'NUM'),
#  ('Johnny', 'NUM'),
#  ('Johns', 'NUM'),
#  ('Julia', 'NUM'),
#  ('Kappa', 'NUM'),
#  ('Kathryn', 'NUM'),
#  ('Kensington', 'NUM'),
#  ('Landor', 'NUM'),
#  ('Lefcourt', 'NUM'),
#  ('Municipal', 'ADJ'),
#  ('Mutual', 'NUM'),
#  ('Negus', 'NUM'),
#  ('Northampton', 'NUM'),
#  ('Notes', 'NUM'),
#  ('OFFERED', 'NUM'),
#  ('Often', 'NUM'),
#  ('Ogilvy', 'NUM'),
#  ('Orrick', 'NUM'),
#  ('Orville', 'NUM'),
#  ('Patients', 'NUM'),
#  ('Pattenden', 'NUM'),
#  ('Personal', 'NUM'),
#  ('Pick', 'NUM'),
#  ('Piero', 'NUM'),
#  ('Portugal', 'NUM'),
#  ('Practical', 'NUM'),
#  ('Prater', 'NUM'),
#  ('Prior', 'NUM'),
#  ('Pro-forma', 'NUM'),
#  ('Proceeds', 'NUM'),
#  ('Raul', 'NUM'),
#  ('Ravenswood', 'NUM'),
#  ('Rent-A-Car', 'NUM'),
#  ('Resistance', 'NUM'),
#  ('Rhone', 'NUM'),
#  ('Rill', 'NUM'),
#  ('So', 'ADV'),
#  ('Solaia', 'NUM'),
#  ('Something', 'NUM'),
#  ('Soups', 'NUM'),
#  ('Soviet', 'ADJ'),
#  ('Syracuse', 'NUM'),
#  ('TEXAS', 'NUM'),
#  ('Traditional', 'NUM'),
#  ('Tribune', 'NUM'),
#  ('Used', 'NUM'),
#  ('Uzi-model', 'NUM'),
#  ('Village', 'NUM'),
#  ('WHAS', 'NUM'),
#  ('Wellington', 'NUM'),
#  ('Westport', 'NUM'),
#  ('Wilmington', 'NUM'),
#  ('Woodcliff', 'NUM'),
#  ('Woodward', 'NUM'),
#  ('abide', 'NUM'),
#  ('acceded', 'NUM'),
#  ('accountant', 'NUM'),
#  ('acetate', 'NUM'),
#  ('act', 'NOUN'),
#  ('addressing', 'NUM'),
#  ('adequate', 'NUM'),
#  ('adjustment', 'NUM'),
#  ('advance', 'NOUN'),
#  ('adverse', 'NUM'),
#  ('advice', 'NUM'),
#  ('advisory', 'NUM'),
#  ('advocating', 'NUM'),
#  ('amicable', 'NUM'),
#  ('ancillary', 'NUM'),
#  ('answer', 'NOUN'),
#  ('anti-drug', 'NUM'),
#  ('anticipates', 'NUM'),
#  ('anticipating', 'NUM'),
#  ('appeal', 'NOUN'),
#  ('appearing', 'NUM'),
#  ('as', 'ADP'),
#  ('astonishment', 'NUM'),
#  ('attempts', 'NOUN'),
#  ('attributes', 'NUM'),
#  ('averaged', 'NUM'),
#  ('away', 'ADV'),
#  ('b', 'NUM'),
#  ('back', 'ADV'),
#  ('bakery', 'NUM'),
#  ('ballroom', 'NUM'),
#  ('bankrupt', 'NUM'),
#  ('baskets', 'NUM'),
#  ('battered', 'NUM'),
#  ('better', 'ADV'),
#  ('beverage', 'NUM'),
#  ('bid', 'NOUN'),
#  ('binge', 'NUM'),
#  ('black-and-white', 'NUM'),
#  ('blindfold', 'NUM'),
#  ('booklet', 'NUM'),
#  ('boyfriends', 'NUM'),
#  ('brilliantly', 'NUM'),
#  ('broaden', 'NUM'),
#  ('bunches', 'NUM'),
#  ('centralized', 'NUM'),
#  ('change', 'NOUN'),
#  ('charts', 'NUM'),
#  ('cheat', 'NUM'),
#  ('childish', 'NUM'),
#  ('choosing', 'VERB'),
#  ('circle', 'NUM'),
#  ('classmates', 'NUM'),
#  ('clerics', 'NUM'),
#  ('close', 'NOUN'),
#  ('closing', 'ADJ'),
#  ('co-chairman', 'NUM'),
#  ('colder', 'NUM'),
#  ('color', 'NOUN'),
#  ('comment', 'NOUN'),
#  ('common', 'ADJ'),
#  ('conduct', 'VERB'),
#  ('conducted', 'NUM'),
#  ('constituent', 'NUM'),
#  ('constitutional-law', 'NUM'),
#  ('consumption', 'NUM'),
#  ('controls', 'NOUN'),
#  ('copying', 'NUM'),
#  ('correct', 'ADJ'),
#  ('cozy', 'NUM'),
#  ('crash', 'NOUN'),
#  ('creator', 'NUM'),
#  ('crossed', 'NUM'),
#  ('crystal-lattice', 'NOUN'),
#  ('cultivation', 'NUM'),
#  ('curses', 'NUM'),
#  ('decline', 'NOUN'),
#  ('deviant', 'NUM'),
#  ('digs', 'NUM'),
#  ('disappears', 'NUM'),
#  ('dissident', 'NUM'),
#  ('domestically', 'NUM'),
#  ('dominating', 'NUM'),
#  ('down', 'ADV'),
#  ('downfall', 'NUM'),
#  ('draws', 'NUM'),
#  ('dumbfounded', 'NUM'),
#  ('early', 'ADJ'),
#  ('early-retirement', 'NUM'),
#  ('electric-utility', 'NUM'),
#  ('elementary', 'NUM'),
#  ('encounter', 'NUM'),
#  ('entertainment', 'NUM'),
#  ('enthusiasm', 'NUM'),
#  ('executive', 'NOUN'),
#  ('existed', 'NUM'),
#  ('expression', 'NUM'),
#  ('fall', 'NOUN'),
#  ('fanciful', 'NUM'),
#  ('feudal', 'NUM'),
#  ('five-cent', 'NUM'),
#  ('five-point', 'NUM'),
#  ('fizzled', 'NUM'),
#  ('flexibility', 'NUM'),
#  ('floral', 'NUM'),
#  ('folded', 'NUM'),
#  ('foods', 'NUM'),
#  ('for', 'ADP'),
#  ('four-foot-high', 'NUM'),
#  ('free-enterprise', 'NUM'),
#  ('friendship', 'NUM'),
#  ('fund', 'NOUN'),
#  ('funded', 'VERB'),
#  ('gilt', 'NUM'),
#  ('glory', 'NUM'),
#  ('good-faith', 'NUM'),
#  ('grants', 'NUM'),
#  ('graphs', 'NUM'),
#  ('greenmailer', 'NUM'),
#  ('hard', 'ADJ'),
#  ('hauling', 'NUM'),
#  ('heavy-truck', 'NUM'),
#  ('help', 'VERB'),
#  ('highlight', 'NUM'),
#  ('highway', 'NUM'),
#  ('hint', 'NUM'),
#  ('hoopla', 'NUM'),
#  ('hoped', 'NUM'),
#  ('house', 'NOUN'),
#  ('immense', 'NUM'),
#  ('in', 'ADP'),
#  ('increase', 'NOUN'),
#  ('indexes', 'NUM'),
#  ('infringed', 'NUM'),
#  ('injecting', 'NUM'),
#  ('intricate', 'NUM'),
#  ('intrusions', 'NUM'),
#  ('issuing', 'NUM'),
#  ('jeopardy', 'NUM'),
#  ('joint-venture', 'NUM'),
#  ('laid', 'NUM'),
#  ('lead', 'VERB'),
#  ('legislators', 'NUM'),
#  ('lending', 'NUM'),
#  ('lesser', 'NUM'),
#  ('line', 'NOUN'),
#  ('link', 'NOUN'),
#  ('listeners', 'NUM'),
#  ('live', 'VERB'),
#  ('lover', 'NUM'),
#  ('machinists', 'NUM'),
#  ('magnified', 'NUM'),
#  ('males', 'NUM'),
#  ('mandates', 'NUM'),
#  ('matters', 'NOUN'),
#  ('maybe', 'NUM'),
#  ('migrate', 'NUM'),
#  ('minimum', 'ADJ'),
#  ('mood', 'NUM'),
#  ('morale-damaging', 'NUM'),
#  ('more', 'ADJ'),
#  ('most', 'ADJ'),
#  ('move', 'NOUN'),
#  ('much', 'ADV'),
#  ('next', 'ADJ'),
#  ('niches', 'NUM'),
#  ('nondurable', 'NUM'),
#  ('notified', 'NUM'),
#  ('notwithstanding', 'NUM'),
#  ('occupant', 'NUM'),
#  ('octogenarians', 'NUM'),
#  ('offer', 'NOUN'),
#  ('offers', 'VERB'),
#  ('old-fashioned', 'NUM'),
#  ('omnipresent', 'NUM'),
#  ('only', 'ADV'),
#  ('out', 'PRT'),
#  ('outbid', 'NUM'),
#  ('painted', 'NUM'),
#  ('papers', 'NUM'),
#  ('participant', 'NUM'),
#  ('penchant', 'NUM'),
#  ('pep', 'NUM'),
#  ('personally', 'NUM'),
#  ('philosophy', 'NUM'),
#  ('plane', 'NUM'),
#  ('plans', 'VERB'),
#  ('premises', 'NUM'),
#  ('pressman', 'NUM'),
#  ('pretax', 'NOUN'),
#  ('prisoners', 'NUM'),
#  ('profit', 'NOUN'),
#  ('proportion', 'NUM'),
#  ('quantitive', 'NUM'),
#  ('racing', 'NUM'),
#  ('rang', 'NUM'),
#  ('range', 'NOUN'),
#  ('rap', 'NUM'),
#  ('rate-sensitive', 'NUM'),
#  ('reasonably', 'NUM'),
#  ('reclaimed', 'NUM'),
#  ('record', 'NOUN'),
#  ('redemption', 'NUM'),
#  ('reeling', 'NUM'),
#  ('refinery', 'NUM'),
#  ('remarkable', 'NUM'),
#  ('repay', 'NUM'),
#  ('replies', 'NOUN'),
#  ('report', 'NOUN'),
#  ('reportedly', 'NUM'),
#  ('reprove', 'NUM'),
#  ('requesting', 'NUM'),
#  ('rescheduled', 'NUM'),
#  ('restructure', 'NOUN'),
#  ('result', 'VERB'),
#  ('review', 'NOUN'),
#  ('right', 'NOUN'),
#  ('rise', 'VERB'),
#  ('rises', 'NUM'),
#  ('semiliterate', 'NUM'),
#  ('senior', 'ADJ'),
#  ('shipboard', 'NUM'),
#  ('shipyards', 'NUM'),
#  ('shows', 'VERB'),
#  ('signals', 'VERB'),
#  ('silicone', 'NUM'),
#  ('single-family', 'ADJ'),
#  ('skittishness', 'NUM'),
#  ('slack', 'NOUN'),
#  ('sleep', 'NOUN'),
#  ('slew', 'NUM'),
#  ('sluggishness', 'NUM'),
#  ('smiles', 'NUM'),
#  ('so', 'ADV'),
#  ('solicitous', 'NUM'),
#  ('spotted', 'NUM'),
#  ('stand', 'VERB'),
#  ('starts', 'VERB'),
#  ('statutory', 'NUM'),
#  ('stick', 'NUM'),
#  ('stock-index', 'NOUN'),
#  ('stock-selection', 'NUM'),
#  ('storm', 'NUM'),
#  ('stream', 'NUM'),
#  ('styles', 'NUM'),
#  ('subindustry', 'NUM'),
#  ('suit', 'NOUN'),
#  ('summons', 'NUM'),
#  ('support', 'NOUN'),
#  ('sure', 'ADJ'),
#  ('surveyed', 'NUM'),
#  ('tallies', 'NUM'),
#  ('that', 'ADP'),
#  ('threat', 'NUM'),
#  ('together', 'ADV'),
#  ('total', 'NOUN'),
#  ('tracked', 'NUM'),
#  ('tracking', 'NUM'),
#  ('trade', 'NOUN'),
#  ('treats', 'NUM'),
#  ('tumultuous', 'NUM'),
#  ('underlying', 'VERB'),
#  ('underperforming', 'NUM'),
#  ('unexpected', 'NUM'),
#  ('unitary', 'NUM'),
#  ('unsettled', 'NUM'),
#  ('up', 'PRT'),
#  ('used', 'VERB'),
#  ('ushered', 'NUM'),
#  ('utterly', 'NUM'),
#  ('view', 'NOUN'),
#  ('walls', 'NUM'),
#  ('wasted', 'NUM'),
#  ('which', 'DET'),
#  ('whipping', 'NUM'),
#  ('winning', 'ADJ'),
#  ('workplace', 'NUM'),
#  ('write-downs', 'NUM'),
#  ('writing', 'VERB'),
#  ('yen-denominated', 'NUM'),
#  ('yield', 'VERB'),
#  ('zoomed', 'NUM')}

# %%
len(set(incorrect_tagged_cases))
# Out:
# 396

# %% [markdown]
# #### Analyzing which tags are assined to unknown words and why?

# %% [markdown]
# The algorithm assign the first tag for the uknown words. Below you acn see the first tag assigned and the count of it

# %%
# Observe that the first tag assigned is DET
T = list(set([pair[1] for pair in train_set]))
T
# Out:
# ['NUM',
#  'CONJ',
#  'ADJ',
#  'ADV',
#  'ADP',
#  'PRT',
#  'DET',
#  'VERB',
#  '.',
#  'PRON',
#  'NOUN',
#  'X']

# %%
tags = [cnt[1] for cnt in set(incorrect_tagged_cases)]

# %%
# Count the most frequent tag 
incorrect_tag_counts = Counter(tags)
incorrect_tag_counts
# Out:
# Counter({'NUM': 300,
#          'NOUN': 42,
#          'ADJ': 18,
#          'VERB': 18,
#          'ADP': 4,
#          'ADV': 9,
#          'PRT': 3,
#          'DET': 2})

# %% [markdown]
# ### Solve the problem of unknown words

# %% [markdown]
# #### Viterbi Modification - Technique 1

# %% [markdown]
# In this, we will define a rule based tagger which will assign tags for the unkown words based on predefined rules.

# %%
# specify patterns for tagging
# example from the NLTK book
patterns = [
    (r'.*ing$', 'VERB'),              # gerund
    (r'.*ed$', 'VERB'),               # past tense
    (r'.*es$', 'VERB'),               # 3rd singular present
    (r'.*ould$', 'VERB'),              # modals
    (r'.*\'s$', 'NOUN'),              # possessive nouns
    (r'.*s$', 'NOUN'),                # plural nouns
    (r'^-?[0-9]+(.[0-9]+)?$', 'NUM'), # cardinal numbers
    (r'.*', 'NOUN')                    # nouns

]

# %%
regexp_tagger = nltk.RegexpTagger(patterns)

# %%
# Viterbi Heuristic
def Viterbi1(words, train_bag = train_set):
    state = []
    T = list(set([pair[1] for pair in train_bag]))
    
    for key, word in enumerate(words):
        if word not in V:
            state.append(regexp_tagger.choose_tag(word,0,state[:key]))
        else:
            #initialise list of probability column for a given observation
            p = [] 
            for tag in T:
                if key == 0:
                    transition_p = tags_df.loc['.', tag]
                else:
                    transition_p = tags_df.loc[state[-1], tag]
                
                # compute emission and state probabilities
                emission_p = word_given_tag(words[key], tag)[0]/word_given_tag(words[key], tag)[1]
                state_probability = emission_p * transition_p    
                p.append(state_probability)
            
            pmax = max(p)
            # getting state for which probability is maximum
            state_max = T[p.index(pmax)] 
            state.append(state_max)
    return list(zip(words, state))

# %%
tagged_seq1 = Viterbi1(words_test)

# %%
set(tagged_seq1)
# Out:
# {('Village', 'NOUN'),
#  ('over', 'ADP'),
#  ('Canepa', 'NOUN'),
#  ('Julia', 'NOUN'),
#  ("'d", 'VERB'),
#  ('IX', 'NOUN'),
#  ('styles', 'NOUN'),
#  ('Carla', 'NOUN'),
#  ('dumbfounded', 'NOUN'),
#  ('status', 'NOUN'),
#  ('I', 'PRON'),
#  ('put', 'VERB'),
#  ('ordered', 'VERB'),
#  ('railroad', 'NOUN'),
#  ('Bush', 'NOUN'),
#  ('black', 'ADJ'),
#  ('*-7', 'X'),
#  ('injecting', 'NOUN'),
#  ('early', 'ADJ'),
#  ('we', 'PRON'),
#  ('marketing', 'NOUN'),
#  ('extend', 'VERB'),
#  ('what', 'PRON'),
#  ('time', 'NOUN'),
#  ('members', 'NOUN'),
#  ('competitive', 'ADJ'),
#  ('Gunmen', 'NOUN'),
#  ('ads', 'NOUN'),
#  ('fines', 'NOUN'),
#  ('broaden', 'NOUN'),
#  ('shipboard', 'NOUN'),
#  ('sort', 'NOUN'),
#  ('convenient', 'ADJ'),
#  ('commercial', 'ADJ'),
#  ('run', 'VERB'),
#  ('Martin', 'NOUN'),
#  ('crystal-lattice', 'NOUN'),
#  ('4', 'NUM'),
#  ('Jeffrey', 'NOUN'),
#  ('costly', 'ADJ'),
#  ('Black', 'NOUN'),
#  ('bonds', 'NOUN'),
#  ('stocks', 'NOUN'),
#  ('Dominion', 'NOUN'),
#  ('spotted', 'NOUN'),
#  ('decision', 'NOUN'),
#  ('includes', 'VERB'),
#  ('more', 'ADJ'),
#  ('consent', 'NOUN'),
#  ('debt', 'NOUN'),
#  ('provides', 'VERB'),
#  ('NBI', 'NOUN'),
#  ('greenmailer', 'NOUN'),
#  ('hand', 'NOUN'),
#  ('board', 'NOUN'),
#  ('president', 'NOUN'),
#  ('*T*-155', 'NOUN'),
#  ('community', 'NOUN'),
#  ('in', 'ADP'),
#  ('20,000', 'NUM'),
#  ('sheets', 'NOUN'),
#  ('Wellington', 'NOUN'),
#  ('boosted', 'VERB'),
#  ('harass', 'VERB'),
#  ('appliances', 'NOUN'),
#  ('92.9', 'NUM'),
#  ('is', 'VERB'),
#  ('Pro-forma', 'NOUN'),
#  ('supercomputer', 'NOUN'),
#  ('three', 'NUM'),
#  ('3\\/4', 'NUM'),
#  ('see', 'VERB'),
#  ('bad', 'ADJ'),
#  ('run-down', 'ADJ'),
#  ('Johns', 'NOUN'),
#  ('average', 'ADJ'),
#  ('improvement', 'NOUN'),
#  ('virtually', 'ADV'),
#  ('close', 'NOUN'),
#  ('plans', 'VERB'),
#  ('located', 'VERB'),
#  ('alternative', 'NOUN'),
#  ('Woodcliff', 'NOUN'),
#  ('unsettled', 'NOUN'),
#  ('possible', 'ADJ'),
#  ('every', 'DET'),
#  ('scrambled', 'VERB'),
#  ('reportedly', 'NOUN'),
#  ('EC', 'NOUN'),
#  ('officials', 'NOUN'),
#  ('professors', 'NOUN'),
#  ('workers', 'NOUN'),
#  ('1934', 'NUM'),
#  ('Says', 'VERB'),
#  ('imports', 'NOUN'),
#  ('Institute', 'NOUN'),
#  ('hefty', 'ADJ'),
#  ('3', 'NUM'),
#  ('drugs', 'NOUN'),
#  ('overall', 'ADJ'),
#  ('beverage', 'NOUN'),
#  ('short-term', 'ADJ'),
#  ('7\\/8', 'NUM'),
#  ('charge', 'NOUN'),
#  ('little', 'ADJ'),
#  ('group', 'NOUN'),
#  ('remarkable', 'NOUN'),
#  ('team', 'NOUN'),
#  ('adds', 'VERB'),
#  ('7.40', 'NUM'),
#  ('boost', 'VERB'),
#  ('due', 'ADJ'),
#  ('fields', 'NOUN'),
#  ('Pa.', 'NOUN'),
#  ('Like', 'ADP'),
#  ('Robbie', 'NOUN'),
#  ('still', 'ADV'),
#  ('?', '.'),
#  ('own', 'ADJ'),
#  ('does', 'VERB'),
#  ('British', 'ADJ'),
#  ('school', 'NOUN'),
#  ('playing', 'VERB'),
#  ('addition', 'NOUN'),
#  ('Wayne', 'NOUN'),
#  ('increased', 'VERB'),
#  ('system', 'NOUN'),
#  ('rapidly', 'ADV'),
#  ('yesterday', 'NOUN'),
#  ('Soups', 'NOUN'),
#  ('*T*-2', 'X'),
#  ('added', 'VERB'),
#  ('workplace', 'NOUN'),
#  ('supply', 'NOUN'),
#  ('Learning', 'NOUN'),
#  ('our', 'PRON'),
#  ('types', 'NOUN'),
#  ('capital', 'NOUN'),
#  ('proposing', 'VERB'),
#  ('deviant', 'NOUN'),
#  ('1990s', 'NUM'),
#  ('black-and-white', 'NOUN'),
#  ('shares', 'NOUN'),
#  ('October', 'NOUN'),
#  ('Northampton', 'NOUN'),
#  ('forecast', 'NOUN'),
#  ('modestly', 'ADV'),
#  ('fifth', 'ADJ'),
#  ('future', 'ADJ'),
#  ('least', 'ADJ'),
#  ("Dunkin'", 'NOUN'),
#  ('accommodate', 'VERB'),
#  ('together', 'ADV'),
#  ('included', 'VERB'),
#  ('equity', 'NOUN'),
#  ('requesting', 'NOUN'),
#  ('management', 'NOUN'),
#  ('executive', 'NOUN'),
#  ('failed', 'VERB'),
#  ('rap', 'NOUN'),
#  ('nondurable', 'NOUN'),
#  ('those', 'DET'),
#  ('winning', 'ADJ'),
#  ('Its', 'PRON'),
#  ('personal', 'ADJ'),
#  ('contributed', 'VERB'),
#  ('old', 'ADJ'),
#  ('reported', 'VERB'),
#  ('banking', 'NOUN'),
#  ('control', 'NOUN'),
#  ('Indonesia', 'NOUN'),
#  ('interests', 'NOUN'),
#  ('expert', 'NOUN'),
#  ('2.1', 'NUM'),
#  ('mood', 'NOUN'),
#  ('Stephen', 'NOUN'),
#  ('after', 'ADP'),
#  ('rear-seat', 'NOUN'),
#  ('health', 'NOUN'),
#  ('Growth', 'NOUN'),
#  ('mandates', 'NOUN'),
#  ('report', 'NOUN'),
#  ('home', 'NOUN'),
#  ('weak', 'ADJ'),
#  ('on', 'ADP'),
#  ('Securities', 'NOUN'),
#  ('were', 'VERB'),
#  ('data', 'NOUN'),
#  ('Federal', 'NOUN'),
#  ('yen', 'NOUN'),
#  ('biggest', 'ADJ'),
#  ('amount', 'NOUN'),
#  ('Nelson', 'NOUN'),
#  ('states', 'NOUN'),
#  ('130', 'NUM'),
#  ('Each', 'DET'),
#  ('post', 'NOUN'),
#  ('Stronach', 'NOUN'),
#  ('Bronx', 'NOUN'),
#  ('Big', 'NOUN'),
#  ('stem', 'VERB'),
#  ('appear', 'VERB'),
#  ('*-14', 'X'),
#  ('72.7', 'NUM'),
#  ('impact', 'NOUN'),
#  ('curses', 'NOUN'),
#  ('David', 'NOUN'),
#  ('company', 'NOUN'),
#  ('Marine', 'NOUN'),
#  ('early-retirement', 'NOUN'),
#  ('Cluff', 'NOUN'),
#  ('Connecticut', 'NOUN'),
#  ('now', 'ADV'),
#  ('losses', 'NOUN'),
#  ('Credit', 'NOUN'),
#  ('decline', 'NOUN'),
#  ('lead', 'VERB'),
#  ('request', 'NOUN'),
#  ('leveraged', 'ADJ'),
#  ('shipped', 'VERB'),
#  ('lesser', 'NOUN'),
#  ('worked', 'VERB'),
#  ('Kensington', 'NOUN'),
#  ('unit', 'NOUN'),
#  ('8.64', 'NUM'),
#  ('discretionary', 'ADJ'),
#  ('Columbia', 'NOUN'),
#  ('council', 'NOUN'),
#  ('largest', 'ADJ'),
#  ('1977', 'NUM'),
#  ('Saudi', 'NOUN'),
#  ('Maughan', 'NOUN'),
#  ('The', 'DET'),
#  ('free-enterprise', 'NOUN'),
#  ('thrifts', 'NOUN'),
#  ('believes', 'VERB'),
#  ('*T*-53', 'X'),
#  ('out', 'PRT'),
#  ('ounces', 'NOUN'),
#  ('astonishment', 'NOUN'),
#  ('January', 'NOUN'),
#  ('Practical', 'NOUN'),
#  ('rescheduled', 'NOUN'),
#  ('old-fashioned', 'NOUN'),
#  ('amendment', 'NOUN'),
#  ('Year', 'NOUN'),
#  ('with', 'ADP'),
#  ('eliminates', 'VERB'),
#  ('blindfold', 'NOUN'),
#  ('domestically', 'NOUN'),
#  ('85', 'NUM'),
#  ('utility', 'NOUN'),
#  ('technology', 'NOUN'),
#  ('lover', 'NOUN'),
#  ('said', 'VERB'),
#  ('disputes', 'NOUN'),
#  ('says', 'VERB'),
#  ('1\\/4', 'NUM'),
#  ('Friedrichs', 'NOUN'),
#  ('she', 'PRON'),
#  ('debate', 'NOUN'),
#  ('entered', 'VERB'),
#  ('good', 'ADJ'),
#  ('corporate', 'ADJ'),
#  ('certain', 'ADJ'),
#  ('dropped', 'VERB'),
#  ('attempt', 'NOUN'),
#  ('policies', 'NOUN'),
#  ('banks', 'NOUN'),
#  ('common', 'ADJ'),
#  ('listed', 'VERB'),
#  ('Yesterday', 'NOUN'),
#  ('What', 'PRON'),
#  ('Notes', 'NOUN'),
#  ('information', 'NOUN'),
#  ('instruments', 'NOUN'),
#  ('McFall', 'NOUN'),
#  ('acquired', 'VERB'),
#  ('Dorothy', 'NOUN'),
#  ('fizzled', 'NOUN'),
#  ('Nippon', 'NOUN'),
#  ('Garanti', 'NOUN'),
#  ('203', 'NUM'),
#  ('answer', 'NOUN'),
#  ('created', 'VERB'),
#  ('training', 'NOUN'),
#  ('rider', 'NOUN'),
#  ('If', 'ADP'),
#  ('skittishness', 'NOUN'),
#  ('percentage', 'NOUN'),
#  ('called', 'VERB'),
#  ('technical', 'ADJ'),
#  ('campaign', 'NOUN'),
#  ('San', 'NOUN'),
#  ('Soviet', 'ADJ'),
#  ('195', 'NUM'),
#  ('C.', 'NOUN'),
#  ('Net', 'ADJ'),
#  ('politics', 'NOUN'),
#  ('Capital', 'NOUN'),
#  ('color', 'NOUN'),
#  ('15,000', 'NUM'),
#  ('summer', 'NOUN'),
#  ('Centerbank', 'NOUN'),
#  ('might', 'VERB'),
#  ('like', 'ADP'),
#  ('b', 'NOUN'),
#  ('Guffey', 'NOUN'),
#  ('Pratt', 'NOUN'),
#  ('noted', 'VERB'),
#  ('7.88', 'NUM'),
#  ('attempts', 'NOUN'),
#  ('rally', 'NOUN'),
#  ('September', 'NOUN'),
#  ('2029', 'NUM'),
#  ('Ogilvy', 'NOUN'),
#  ('joining', 'VERB'),
#  ('imposed', 'VERB'),
#  ('headquarters', 'NOUN'),
#  ('ultimate', 'ADJ'),
#  ('as', 'ADP'),
#  ('violations', 'NOUN'),
#  ('startling', 'ADJ'),
#  ('think', 'VERB'),
#  ('food', 'NOUN'),
#  ('deal', 'NOUN'),
#  ('process', 'NOUN'),
#  ('risks', 'NOUN'),
#  ('5.63', 'NUM'),
#  ('Bellows', 'NOUN'),
#  ('buy-out', 'NOUN'),
#  ('California', 'NOUN'),
#  ('willing', 'ADJ'),
#  ('classics', 'NOUN'),
#  ('highlight', 'NOUN'),
#  ('sign', 'NOUN'),
#  ('Imports', 'NOUN'),
#  ('However', 'ADV'),
#  ('matters', 'NOUN'),
#  ('President', 'NOUN'),
#  ('trying', 'VERB'),
#  ('privately', 'ADV'),
#  ('electronic', 'ADJ'),
#  ('Sen.', 'NOUN'),
#  ('--', '.'),
#  ('late', 'ADJ'),
#  ('rises', 'NOUN'),
#  ('article', 'NOUN'),
#  ('period', 'NOUN'),
#  ('capacity', 'NOUN'),
#  ('extraordinary', 'ADJ'),
#  ('frozen', 'VERB'),
#  ('currency', 'NOUN'),
#  ('rights', 'NOUN'),
#  ('history', 'NOUN'),
#  ('stock-index', 'NOUN'),
#  ('reprove', 'NOUN'),
#  ('two', 'NUM'),
#  ('office', 'NOUN'),
#  ('here', 'ADV'),
#  ('growth', 'NOUN'),
#  ('McCormick', 'NOUN'),
#  ('despite', 'ADP'),
#  ('Rather', 'ADV'),
#  ('gain', 'NOUN'),
#  ('followed', 'VERB'),
#  ("'", 'PRT'),
#  ('mentally', 'ADV'),
#  ('up', 'PRT'),
#  ('division', 'NOUN'),
#  ('Larry', 'NOUN'),
#  ('Coleco', 'NOUN'),
#  ('sleep', 'NOUN'),
#  ('actual', 'ADJ'),
#  ('200', 'NUM'),
#  ('threatened', 'VERB'),
#  ('Who', 'PRON'),
#  ('Equitable', 'NOUN'),
#  ('one-time', 'ADJ'),
#  ('Poor', 'NOUN'),
#  ('which', 'DET'),
#  ('Free', 'NOUN'),
#  ('Pickens', 'NOUN'),
#  ('newspaper', 'NOUN'),
#  ('Petroleum', 'NOUN'),
#  ('*T*-247', 'NOUN'),
#  ('County', 'NOUN'),
#  ('Japanese', 'ADJ'),
#  ('Hammerton', 'NOUN'),
#  ('Turkey', 'NOUN'),
#  ('managing', 'VERB'),
#  ('unchanged', 'ADJ'),
#  ('250,000', 'NUM'),
#  ('men', 'NOUN'),
#  ('accountant', 'NOUN'),
#  ('papers', 'NOUN'),
#  ('B-1B', 'ADJ'),
#  ('Smaby', 'NOUN'),
#  ('almost', 'ADV'),
#  ('United', 'NOUN'),
#  ('Arthur', 'NOUN'),
#  ('deliver', 'VERB'),
#  ('true', 'ADJ'),
#  ('industrial', 'ADJ'),
#  ('*RNR*-1', 'X'),
#  ('Wall', 'NOUN'),
#  ('Sea', 'NOUN'),
#  ('Israel', 'NOUN'),
#  ('but', 'CONJ'),
#  ('indexes', 'NOUN'),
#  ('issue', 'NOUN'),
#  ('ushered', 'NOUN'),
#  ('Apple', 'NOUN'),
#  ('commodity', 'NOUN'),
#  ('9', 'NUM'),
#  ('PS', 'NOUN'),
#  ('Woodward', 'NOUN'),
#  ('receive', 'VERB'),
#  ('Tramp', 'NOUN'),
#  ('Baton', 'NOUN'),
#  ('fluctuation', 'NOUN'),
#  ('Chicago', 'NOUN'),
#  ('900', 'NUM'),
#  ('baskets', 'NOUN'),
#  ('prints', 'NOUN'),
#  ('1989', 'NUM'),
#  ('Savings', 'NOUN'),
#  ('units', 'NOUN'),
#  ('most', 'ADJ'),
#  ('intrusions', 'NOUN'),
#  ('position', 'NOUN'),
#  ('fetal', 'ADJ'),
#  ('face', 'VERB'),
#  ('third-quarter', 'NOUN'),
#  ('Mitsui', 'NOUN'),
#  ('overcome', 'VERB'),
#  ('pep', 'NOUN'),
#  ('give', 'VERB'),
#  ('Exchange', 'NOUN'),
#  ('Eastern', 'NOUN'),
#  ('B.', 'NOUN'),
#  ('Bank', 'NOUN'),
#  ('complains', 'VERB'),
#  ('1', 'NUM'),
#  ('Michigan', 'NOUN'),
#  ('women', 'NOUN'),
#  ('Leming', 'NOUN'),
#  ('days', 'NOUN'),
#  ('clients', 'NOUN'),
#  ('bid', 'NOUN'),
#  ('another', 'DET'),
#  ('PLC', 'NOUN'),
#  ('stick', 'NOUN'),
#  ('10', 'NUM'),
#  ('reeling', 'NOUN'),
#  ('heavy-truck', 'NOUN'),
#  ('hint', 'NOUN'),
#  ('Nine', 'NOUN'),
#  ('chips', 'NOUN'),
#  ('battered', 'NOUN'),
#  ('cutting', 'VERB'),
#  ('childish', 'NOUN'),
#  ('deals', 'NOUN'),
#  ('patent', 'NOUN'),
#  ('0.25', 'NUM'),
#  ('choosing', 'VERB'),
#  ('however', 'ADV'),
#  ('military', 'ADJ'),
#  ('business', 'NOUN'),
#  ('*T*-19', 'X'),
#  ('immense', 'NOUN'),
#  ('say', 'VERB'),
#  ('far', 'ADV'),
#  ('China', 'NOUN'),
#  ('bought', 'VERB'),
#  ('during', 'ADP'),
#  ('*T*-107', 'NOUN'),
#  ('thus', 'ADV'),
#  ('conference', 'NOUN'),
#  ('deemed', 'VERB'),
#  ('High', 'NOUN'),
#  ('12', 'NUM'),
#  ('trade', 'NOUN'),
#  ('*-101', 'NOUN'),
#  ('Yale', 'NOUN'),
#  ('former', 'ADJ'),
#  ('considering', 'VERB'),
#  ('scandal', 'NOUN'),
#  ('Research', 'NOUN'),
#  ('stalemate', 'NOUN'),
#  ('without', 'ADP'),
#  ('take', 'VERB'),
#  ('get', 'VERB'),
#  ('himself', 'PRON'),
#  ('back', 'ADV'),
#  ('reading', 'NOUN'),
#  ('beyond', 'ADP'),
#  ('blacks', 'NOUN'),
#  ('*T*-142', 'NOUN'),
#  ('%', 'NOUN'),
#  ('the', 'DET'),
#  ('lower', 'ADJ'),
#  ('makers', 'NOUN'),
#  ('murdered', 'VERB'),
#  ('difficult', 'ADJ'),
#  ('if', 'ADP'),
#  ('four', 'NUM'),
#  ('adequate', 'NOUN'),
#  ('chief', 'NOUN'),
#  ('120', 'NUM'),
#  ('tenure', 'NOUN'),
#  ('appears', 'VERB'),
#  ('move', 'NOUN'),
#  ('Personal', 'NOUN'),
#  ('farm', 'NOUN'),
#  ('official', 'NOUN'),
#  ('airline', 'NOUN'),
#  ('refinery', 'NOUN'),
#  ('deposit', 'NOUN'),
#  ('issuing', 'NOUN'),
#  ('She', 'PRON'),
#  ('posted', 'VERB'),
#  ('homelessness', 'NOUN'),
#  ('hotel', 'NOUN'),
#  ('did', 'VERB'),
#  ('top', 'ADJ'),
#  ('several', 'ADJ'),
#  ('Raul', 'NOUN'),
#  ('handle', 'VERB'),
#  ('11', 'NUM'),
#  ('Jersey', 'NOUN'),
#  ('stations', 'NOUN'),
#  ('such', 'ADJ'),
#  ('previously', 'ADV'),
#  ('1986', 'NUM'),
#  ('six', 'NUM'),
#  ('Bodner', 'NOUN'),
#  ('70', 'NUM'),
#  ('support', 'NOUN'),
#  ('Mich.', 'NOUN'),
#  ('paper', 'NOUN'),
#  ('SuperDot', 'NOUN'),
#  ('contract', 'NOUN'),
#  ('software', 'NOUN'),
#  ('pull', 'VERB'),
#  ('1972', 'NUM'),
#  ('And', 'CONJ'),
#  ('must', 'VERB'),
#  ('advice', 'NOUN'),
#  ('million', 'NUM'),
#  ('averaged', 'NOUN'),
#  ('highly', 'ADV'),
#  ('way', 'NOUN'),
#  ('secretary', 'NOUN'),
#  ('Christopher', 'NOUN'),
#  ('judges', 'NOUN'),
#  ('believe', 'VERB'),
#  ('rate-sensitive', 'NOUN'),
#  ('seeks', 'VERB'),
#  ('Wilmington', 'NOUN'),
#  ('engineering', 'NOUN'),
#  ('became', 'VERB'),
#  ('CEOs', 'NOUN'),
#  ('These', 'DET'),
#  ('river', 'NOUN'),
#  ('migrate', 'NOUN'),
#  ('anti-drug', 'NOUN'),
#  ('minutes', 'NOUN'),
#  ('era', 'NOUN'),
#  ('views', 'NOUN'),
#  ('options', 'NOUN'),
#  ('special', 'ADJ'),
#  ('Einhorn', 'NOUN'),
#  ('sector', 'NOUN'),
#  ('zoomed', 'NOUN'),
#  ('&', 'CONJ'),
#  ('right', 'NOUN'),
#  ('Colorado', 'NOUN'),
#  ('Canadian', 'ADJ'),
#  ('years', 'NOUN'),
#  ('*-34', 'X'),
#  ('merchant', 'NOUN'),
#  ('local', 'ADJ'),
#  ('Orville', 'NOUN'),
#  ('consumer', 'NOUN'),
#  ('reduce', 'VERB'),
#  ('Corp.', 'NOUN'),
#  ('II', 'NOUN'),
#  ('Beth', 'NOUN'),
#  ('leaving', 'VERB'),
#  ('expenses', 'NOUN'),
#  ('installment', 'NOUN'),
#  ('flexibility', 'NOUN'),
#  ('traded', 'VERB'),
#  ('suggest', 'VERB'),
#  ('theory', 'NOUN'),
#  ('pointed', 'VERB'),
#  ('advertise', 'VERB'),
#  ('Adds', 'VERB'),
#  ('8', 'NUM'),
#  ('visit', 'NOUN'),
#  ('shipments', 'NOUN'),
#  ('abortion', 'NOUN'),
#  ('Britain', 'NOUN'),
#  ('publications', 'NOUN'),
#  ('Think', 'VERB'),
#  ('Chemical', 'NOUN'),
#  ('scheduled', 'VERB'),
#  ('specialists', 'NOUN'),
#  ('volatility', 'NOUN'),
#  ('Greenville', 'NOUN'),
#  ('morale-damaging', 'NOUN'),
#  ('approve', 'VERB'),
#  ('rate', 'NOUN'),
#  ('intricate', 'NOUN'),
#  ('boyfriends', 'NOUN'),
#  ('declined', 'VERB'),
#  ('code', 'NOUN'),
#  ('folded', 'NOUN'),
#  ('current-carrying', 'ADJ'),
#  ('constituent', 'NOUN'),
#  ('representative', 'NOUN'),
#  ('firms', 'NOUN'),
#  ('Nekoosa', 'NOUN'),
#  ('raise', 'VERB'),
#  ('firm', 'NOUN'),
#  ('Roederer', 'NOUN'),
#  ('internal', 'ADJ'),
#  ('cataract', 'NOUN'),
#  ('worker', 'NOUN'),
#  ('year', 'NOUN'),
#  ('7', 'NUM'),
#  ('sale', 'NOUN'),
#  ('would', 'VERB'),
#  ('usual', 'ADJ'),
#  ('spokesman', 'NOUN'),
#  ('prior', 'ADV'),
#  ('1956', 'NUM'),
#  ('fired', 'VERB'),
#  ('split', 'VERB'),
#  ('Rent-A-Car', 'NOUN'),
#  ('advertising', 'NOUN'),
#  ('Municipal', 'ADJ'),
#  ('contemporary', 'ADJ'),
#  ('continuing', 'VERB'),
#  ('Travelers', 'NOUN'),
#  ('indexers', 'NOUN'),
#  ('list', 'NOUN'),
#  ('strategy', 'NOUN'),
#  ('March', 'NOUN'),
#  ('labor', 'NOUN'),
#  ('force', 'NOUN'),
#  ('tomorrow', 'NOUN'),
#  ('8300s', 'NUM'),
#  ('about', 'ADP'),
#  ('49.9', 'NUM'),
#  ('begin', 'VERB'),
#  ('Poland', 'NOUN'),
#  ('Co.', 'NOUN'),
#  ('benchmark', 'NOUN'),
#  ('via', 'ADP'),
#  ('has', 'VERB'),
#  ('Motor', 'NOUN'),
#  ('45', 'NUM'),
#  ('Bowman', 'NOUN'),
#  ('feudal', 'NOUN'),
#  ('Labor', 'NOUN'),
#  ('seeing', 'VERB'),
#  ('they', 'PRON'),
#  ('Stamford', 'NOUN'),
#  ('net', 'ADJ'),
#  ('Your', 'PRON'),
#  ('concern', 'NOUN'),
#  ('bunches', 'NOUN'),
#  ('a', 'DET'),
#  ('*ICH*-1', 'X'),
#  ('*U*', 'X'),
#  ('pretax', 'NOUN'),
#  ('Hale', 'NOUN'),
#  ('Candlestick', 'NOUN'),
#  ('laws', 'NOUN'),
#  ('10th', 'NUM'),
#  ('contacted', 'VERB'),
#  ('National', 'NOUN'),
#  ('construction', 'NOUN'),
#  ('England', 'NOUN'),
#  ('result', 'VERB'),
#  ('other', 'ADJ'),
#  ('down', 'ADV'),
#  ('digs', 'NOUN'),
#  ('squeeze', 'NOUN'),
#  ('cost', 'NOUN'),
#  ('abide', 'NOUN'),
#  ('one', 'NUM'),
#  ('crop', 'NOUN'),
#  ('income', 'NOUN'),
#  ('Eggers', 'NOUN'),
#  ('investors', 'NOUN'),
#  ('made', 'VERB'),
#  ('environment', 'NOUN'),
#  ('14', 'NUM'),
#  ('eventually', 'ADV'),
#  ('gets', 'VERB'),
#  ('five-cent', 'NOUN'),
#  ('cents', 'NOUN'),
#  ('*-26', 'X'),
#  ('3.7', 'NUM'),
#  ('using', 'VERB'),
#  ('wake', 'NOUN'),
#  ('plunged', 'VERB'),
#  ('partner', 'NOUN'),
#  ('months', 'NOUN'),
#  ('language', 'NOUN'),
#  ('saying', 'VERB'),
#  ('death', 'NOUN'),
#  ('light', 'ADJ'),
#  ('fees', 'NOUN'),
#  ('world', 'NOUN'),
#  ('*T*-55', 'X'),
#  ('Markey', 'NOUN'),
#  ('grain', 'NOUN'),
#  ('Fujitsu', 'NOUN'),
#  ('11,000', 'NUM'),
#  ('males', 'NOUN'),
#  ('economies', 'NOUN'),
#  ('product', 'NOUN'),
#  ('computer', 'NOUN'),
#  ('appeal', 'NOUN'),
#  ('delays', 'NOUN'),
#  ('crash', 'NOUN'),
#  ('bottle', 'NOUN'),
#  ('whipping', 'NOUN'),
#  ('Lefcourt', 'NOUN'),
#  ('Wedtech', 'NOUN'),
#  ('strongest', 'ADJ'),
#  ('10,000', 'NUM'),
#  ('relations', 'NOUN'),
#  ('institutions', 'NOUN'),
#  ('*T*-3', 'X'),
#  ('1992', 'NUM'),
#  ('larger', 'ADJ'),
#  ('*', 'X'),
#  ('goods', 'NOUN'),
#  ('portion', 'NOUN'),
#  ('COMMUNICATIONS', 'NOUN'),
#  ('underperforming', 'NOUN'),
#  ('Bob', 'NOUN'),
#  ('suit', 'NOUN'),
#  ('demand', 'NOUN'),
#  ('tracking', 'NOUN'),
#  ('cigarette', 'NOUN'),
#  ('corporations', 'NOUN'),
#  ('Mae', 'NOUN'),
#  ('Blanc', 'NOUN'),
#  ('index', 'NOUN'),
#  ('profit', 'NOUN'),
#  ('review', 'NOUN'),
#  ('Guerrilla', 'NOUN'),
#  ('240', 'NUM'),
#  ('Washington', 'NOUN'),
#  ('sell', 'VERB'),
#  ('Despite', 'ADP'),
#  ('bakery', 'NOUN'),
#  ('into', 'ADP'),
#  ('understood', 'VERB'),
#  ('considered', 'VERB'),
#  ('realized', 'VERB'),
#  ('multi-crystal', 'ADJ'),
#  ('sharp', 'ADJ'),
#  ('3.2', 'NUM'),
#  ('while', 'ADP'),
#  ('suspension', 'NOUN'),
#  ('lending', 'NOUN'),
#  ('Traditional', 'NOUN'),
#  ('stay', 'VERB'),
#  ('*T*-20', 'X'),
#  ('remained', 'VERB'),
#  ('*-1', 'X'),
#  ('17.3', 'NUM'),
#  ('familiar', 'ADJ'),
#  ('notwithstanding', 'NOUN'),
#  ('part', 'NOUN'),
#  ('four-foot-high', 'NOUN'),
#  ('major', 'ADJ'),
#  ('auctions', 'NOUN'),
#  ('manager', 'NOUN'),
#  ('samples', 'NOUN'),
#  ('Yeargin', 'NOUN'),
#  ('London-based', 'ADJ'),
#  ('proportion', 'NOUN'),
#  ('return', 'NOUN'),
#  ('Temple', 'NOUN'),
#  ('nor', 'CONJ'),
#  ('withstand', 'VERB'),
#  ('9.9', 'NUM'),
#  ('character', 'NOUN'),
#  ('enthusiasm', 'NOUN'),
#  ('1.8415', 'NUM'),
#  ('well', 'ADV'),
#  ('Moody', 'NOUN'),
#  ('Central', 'NOUN'),
#  ('agency', 'NOUN'),
#  ('Williams', 'NOUN'),
#  ('markets', 'NOUN'),
#  ('against', 'ADP'),
#  ('oil', 'NOUN'),
#  ('lying', 'VERB'),
#  ('been', 'VERB'),
#  ('comes', 'VERB'),
#  ('Rill', 'NOUN'),
#  ('city', 'NOUN'),
#  ('controls', 'NOUN'),
#  ('loss', 'NOUN'),
#  ('meetings', 'NOUN'),
#  ('30', 'NUM'),
#  ('offices', 'NOUN'),
#  ('storm', 'NOUN'),
#  ('drifted', 'VERB'),
#  ('meeting', 'NOUN'),
#  ('Contracts', 'NOUN'),
#  ('Still', 'ADV'),
#  ('dollar', 'NOUN'),
#  ('event', 'NOUN'),
#  ('including', 'VERB'),
#  ('Seoul', 'NOUN'),
#  ('absorbed', 'VERB'),
#  ('development', 'NOUN'),
#  ('Craftsmen', 'NOUN'),
#  ('Board', 'NOUN'),
#  ('50', 'NUM'),
#  ('hoped', 'NOUN'),
#  ('per', 'ADP'),
#  ('*T*-4', 'X'),
#  ('student', 'NOUN'),
#  ('enforcement', 'NOUN'),
#  ('railings', 'NOUN'),
#  ('syndication', 'NOUN'),
#  ('pending', 'VERB'),
#  ('Valhi', 'NOUN'),
#  ('electric-utility', 'NOUN'),
#  ('turned', 'VERB'),
#  ('file', 'VERB'),
#  ('panel', 'NOUN'),
#  ('statewide', 'ADJ'),
#  ('having', 'VERB'),
#  ('seeking', 'VERB'),
#  ('committee', 'NOUN'),
#  ('thin', 'ADJ'),
#  ('soared', 'VERB'),
#  ('75', 'NUM'),
#  ('settle', 'VERB'),
#  ('its', 'PRON'),
#  ('needed', 'VERB'),
#  ('off', 'PRT'),
#  ('Bates', 'NOUN'),
#  ('150-point', 'NUM'),
#  ('motion', 'NOUN'),
#  ('consumption', 'NOUN'),
#  ('Over', 'ADP'),
#  ('further', 'ADJ'),
#  ('survey', 'NOUN'),
#  ('billion', 'NUM'),
#  ('electronics', 'NOUN'),
#  ('mechanical', 'ADJ'),
#  ('Louis', 'NOUN'),
#  ('research', 'NOUN'),
#  ('aide', 'NOUN'),
#  ('ways', 'NOUN'),
#  ('he', 'PRON'),
#  ('sentiment', 'NOUN'),
#  ('Common', 'ADJ'),
#  ('1,000', 'NUM'),
#  ('Express', 'NOUN'),
#  ('yield', 'VERB'),
#  ('shrinks', 'VERB'),
#  ('Industry', 'NOUN'),
#  ('fate', 'NOUN'),
#  ('A', 'DET'),
#  ('friend', 'NOUN'),
#  ('probably', 'ADV'),
#  ('pressures', 'NOUN'),
#  ('letters', 'NOUN'),
#  ('themselves', 'PRON'),
#  ('Some', 'DET'),
#  ('teachers', 'NOUN'),
#  ('tumbled', 'VERB'),
#  ('trucks', 'NOUN'),
#  ('industry', 'NOUN'),
#  ('bankrupt', 'NOUN'),
#  ('stands', 'VERB'),
#  ('young', 'ADJ'),
#  ('rich', 'ADJ'),
#  ('earlier', 'ADJ'),
#  ('single-family', 'ADJ'),
#  ('38', 'NUM'),
#  ('Under', 'ADP'),
#  ('Harold', 'NOUN'),
#  ('nearly', 'ADV'),
#  ('and', 'CONJ'),
#  ('80', 'NUM'),
#  ('Street', 'NOUN'),
#  ('managers', 'NOUN'),
#  ('discussed', 'VERB'),
#  ('maker', 'NOUN'),
#  ('record', 'NOUN'),
#  ('then', 'ADV'),
#  ('sources', 'NOUN'),
#  ('Mutual', 'NOUN'),
#  ('funds', 'NOUN'),
#  ('day', 'NOUN'),
#  ('until', 'ADP'),
#  ('voluntarily', 'ADV'),
#  ('received', 'VERB'),
#  ('Sun', 'NOUN'),
#  ('peripheral', 'ADJ'),
#  ('traditional', 'ADJ'),
#  ('joint-venture', 'NOUN'),
#  ('admitted', 'VERB'),
#  ('domestic', 'ADJ'),
#  ('Civil', 'NOUN'),
#  ('113.2', 'NUM'),
#  ('There', 'DET'),
#  ('bone', 'NOUN'),
#  ('line', 'NOUN'),
#  ('*T*-172', 'NOUN'),
#  ('Appropriations', 'NOUN'),
#  ('encourage', 'VERB'),
#  ('than', 'ADP'),
#  ('feel', 'VERB'),
#  ('much', 'ADV'),
#  ('So', 'ADV'),
#  ('Airlines', 'NOUN'),
#  ('maybe', 'NOUN'),
#  ('For', 'ADP'),
#  ('COMPUTERS', 'NOUN'),
#  ('crystals', 'NOUN'),
#  ('spinoff', 'NOUN'),
#  ('signals', 'VERB'),
#  ('tracked', 'NOUN'),
#  ('be', 'VERB'),
#  ('plate', 'NOUN'),
#  ('1991-2000', 'NUM'),
#  ('machinists', 'NOUN'),
#  ('Petersen', 'NOUN'),
#  ('listeners', 'NOUN'),
#  ('operating', 'NOUN'),
#  ('house', 'NOUN'),
#  ('floral', 'NOUN'),
#  ('keep', 'VERB'),
#  ('Meanwhile', 'ADV'),
#  ('policy', 'NOUN'),
#  ('full', 'ADJ'),
#  ('profitable', 'ADJ'),
#  ('Dover', 'NOUN'),
#  ('415', 'NUM'),
#  ('elevators', 'NOUN'),
#  ('autumn', 'NOUN'),
#  ('even', 'ADV'),
#  ("n't", 'ADV'),
#  ('Neither', 'DET'),
#  ('people', 'NOUN'),
#  ('better', 'ADV'),
#  ('reporter', 'NOUN'),
#  ('crossed', 'NOUN'),
#  ('it', 'PRON'),
#  ('Typically', 'ADV'),
#  ('neither', 'DET'),
#  ('new', 'ADJ'),
#  ('used', 'VERB'),
#  ('trailed', 'VERB'),
#  ('fell', 'VERB'),
#  ('parts', 'NOUN'),
#  ('star', 'NOUN'),
#  ('direct-mail', 'ADJ'),
#  ('terms', 'NOUN'),
#  ('family', 'NOUN'),
#  ('ban', 'NOUN'),
#  ('from', 'ADP'),
#  ('fanciful', 'NOUN'),
#  ('assumption', 'NOUN'),
#  ('15-day', 'NUM'),
#  ('Kansas', 'NOUN'),
#  ('Cray', 'NOUN'),
#  ('congressional', 'ADJ'),
#  ('by', 'ADP'),
#  ('Hackensack', 'NOUN'),
#  ('evening', 'NOUN'),
#  ('spent', 'VERB'),
#  ('citing', 'VERB'),
#  ('marks', 'NOUN'),
#  ('uncharted', 'ADJ'),
#  ('packaging', 'NOUN'),
#  ("'re", 'VERB'),
#  ('competition', 'NOUN'),
#  ('press', 'NOUN'),
#  ('when', 'ADV'),
#  ('general', 'ADJ'),
#  ('field', 'NOUN'),
#  ('Those', 'DET'),
#  ('returned', 'VERB'),
#  ...}

# %% [markdown]
# #### Viterbi Modification - Technique 2

# %% [markdown]
# For unknown words the emisiion probabilities is 0. In this modification, we will consider only transmission probabilities of unknown words

# %%
# Viterbi Heuristic
def Viterbi2(words, train_bag = train_set):
    state = []
    T = list(set([pair[1] for pair in train_bag]))
    
    for key, word in enumerate(words):
        #initialise list of probability column for a given observation
        p = [] 
        for tag in T:
            if key == 0:
                transition_p = tags_df.loc['.', tag]
            else:
                transition_p = tags_df.loc[state[-1], tag]
                
            # compute emission and state probabilities
            emission_p = word_given_tag(words[key], tag)[0]/word_given_tag(words[key], tag)[1]
            if emission_p == 0 and word not in V :
                state_probability=transition_p
                p.append(state_probability)
            else:
                state_probability = emission_p * transition_p    
                p.append(state_probability)
            
        pmax = max(p)
        # getting state for which probability is maximum
        state_max = T[p.index(pmax)] 
        state.append(state_max)
    return list(zip(words, state))

# %%
tagged_seq2 = Viterbi2(words_test)

# %%
tagged_seq2
# Out:
# [('was', 'VERB'),
#  ('constituent', 'NOUN'),
#  ('operating', 'NOUN'),
#  ('among', 'ADP'),
#  ('Association', 'NOUN'),
#  ('OSHA', 'NOUN'),
#  ('Who', 'PRON'),
#  ('threatened', 'VERB'),
#  ('the', 'DET'),
#  ('*', 'X'),
#  ('.', '.'),
#  ('daily', 'ADJ'),
#  ('Mr.', 'NOUN'),
#  ('gets', 'VERB'),
#  ('``', '.'),
#  ('``', '.'),
#  ('to', 'PRT'),
#  ('and', 'CONJ'),
#  ('several', 'ADJ'),
#  ('they', 'PRON'),
#  ('*-2', 'X'),
#  ('.', '.'),
#  ('types', 'NOUN'),
#  ("'s", 'PRT'),
#  ('.', '.'),
#  ('1986', 'NUM'),
#  ('rose', 'VERB'),
#  ('should', 'VERB'),
#  ('*-3', 'X'),
#  ('*T*-1', 'X'),
#  ('.', '.'),
#  (',', '.'),
#  ('Courter', 'NOUN'),
#  ('dividends', 'NOUN'),
#  ('prices', 'NOUN'),
#  ('in', 'ADP'),
#  ('now', 'ADV'),
#  ('year', 'NOUN'),
#  ('of', 'ADP'),
#  ('federal', 'ADJ'),
#  ('a', 'DET'),
#  ('months', 'NOUN'),
#  (',', '.'),
#  ('Express', 'NOUN'),
#  ('Jr.', 'NOUN'),
#  ('meeting', 'NOUN'),
#  ("''", '.'),
#  ('is', 'VERB'),
#  ('criminal', 'ADJ'),
#  ('*-3', 'X'),
#  ('sold', 'VERB'),
#  ('the', 'DET'),
#  ('since', 'ADP'),
#  ('in', 'ADP'),
#  ('%', 'NOUN'),
#  ('the', 'DET'),
#  ('the', 'DET'),
#  ('Southeast', 'NOUN'),
#  ('says', 'VERB'),
#  (',', '.'),
#  ('.', '.'),
#  ('a', 'DET'),
#  ('closing', 'ADJ'),
#  ('give', 'VERB'),
#  ('that', 'ADP'),
#  ('funding', 'NOUN'),
#  (',', '.'),
#  ('of', 'ADP'),
#  ('equity', 'NOUN'),
#  ('cost', 'NOUN'),
#  ('reported', 'VERB'),
#  ('says', 'VERB'),
#  ('Raul', 'NOUN'),
#  ('their', 'PRON'),
#  (':', '.'),
#  ('from', 'ADP'),
#  ('federal', 'ADJ'),
#  ('a', 'DET'),
#  ('the', 'DET'),
#  ('Hospital', 'NOUN'),
#  ('rain', 'NOUN'),
#  ('administration', 'NOUN'),
#  (',', '.'),
#  ('Nine', 'NOUN'),
#  ('market', 'NOUN'),
#  ('Connecticut', 'NOUN'),
#  ('U.S.', 'NOUN'),
#  ('in', 'ADP'),
#  ('shares', 'NOUN'),
#  ('yesterday', 'NOUN'),
#  ('that', 'ADP'),
#  ('have', 'VERB'),
#  ('Service', 'NOUN'),
#  ('some', 'DET'),
#  ('Markey', 'NOUN'),
#  ('computer', 'NOUN'),
#  ('could', 'VERB'),
#  ('of', 'ADP'),
#  ('the', 'DET'),
#  ('*T*-1', 'X'),
#  ('well-known', 'ADJ'),
#  ('The', 'DET'),
#  ('share', 'NOUN'),
#  ('believe', 'VERB'),
#  ('.', '.'),
#  ('Courter', 'NOUN'),
#  ('Stephen', 'NOUN'),
#  ('.', '.'),
#  ('Greenville', 'NOUN'),
#  ('survey', 'NOUN'),
#  ('Washington', 'NOUN'),
#  ('recent', 'ADJ'),
#  ('acceded', 'NOUN'),
#  ('cancer', 'NOUN'),
#  ('We', 'PRON'),
#  ('.', '.'),
#  ('officials', 'NOUN'),
#  ('in', 'ADP'),
#  ('judge', 'NOUN'),
#  ('$', '.'),
#  ('Article', 'NOUN'),
#  ('increase', 'NOUN'),
#  ('*', 'X'),
#  ('million', 'NUM'),
#  ('council', 'NOUN'),
#  ('in', 'ADP'),
#  ('aggressive', 'ADJ'),
#  ('million', 'NUM'),
#  ('7\\/8', 'NUM'),
#  ('continuing', 'VERB'),
#  ('.', '.'),
#  ('stations', 'NOUN'),
#  ('of', 'ADP'),
#  (',', '.'),
#  ('some', 'DET'),
#  ('1992', 'NUM'),
#  ('Pratt', 'NOUN'),
#  ('stadium', 'NOUN'),
#  ('Germany-based', 'NOUN'),
#  ("'", 'PRT'),
#  ('about', 'ADP'),
#  ('confirm', 'VERB'),
#  ('to', 'PRT'),
#  ('Waertsilae', 'NOUN'),
#  (',', '.'),
#  ('and', 'CONJ'),
#  ('B.', 'NOUN'),
#  (',', '.'),
#  ('*U*', 'X'),
#  ('cents', 'NOUN'),
#  ("'s", 'PRT'),
#  ('were', 'VERB'),
#  ('estimate', 'NOUN'),
#  ('activity', 'NOUN'),
#  ('U.S.', 'NOUN'),
#  ('on', 'ADP'),
#  ('is', 'VERB'),
#  (';', '.'),
#  ('to', 'PRT'),
#  ('New', 'NOUN'),
#  ('say', 'VERB'),
#  ('voluntarily', 'ADV'),
#  ('decided', 'VERB'),
#  ('earthquake', 'NOUN'),
#  (',', '.'),
#  ('*', 'X'),
#  ('the', 'DET'),
#  ('business', 'NOUN'),
#  ('it', 'PRON'),
#  ('new', 'ADJ'),
#  ('directors', 'NOUN'),
#  ('$', '.'),
#  ('though', 'ADP'),
#  ('proposed', 'VERB'),
#  ('*-25', 'X'),
#  ('is', 'VERB'),
#  ('capital', 'NOUN'),
#  ('says', 'VERB'),
#  ('for', 'ADP'),
#  ('Corp.', 'NOUN'),
#  ('into', 'ADP'),
#  ('6.20', 'NUM'),
#  ('.', '.'),
#  ('for', 'ADP'),
#  (',', '.'),
#  ('a', 'DET'),
#  ('$', '.'),
#  ('trading', 'NOUN'),
#  ('venture', 'NOUN'),
#  ('and', 'CONJ'),
#  ('or', 'CONJ'),
#  ('it', 'PRON'),
#  (',', '.'),
#  ('of', 'ADP'),
#  (',', '.'),
#  ('than', 'ADP'),
#  ('*-1', 'X'),
#  ('to', 'PRT'),
#  ('million', 'NUM'),
#  ('With', 'ADP'),
#  ('--', '.'),
#  ('will', 'VERB'),
#  ('to', 'PRT'),
#  ('a', 'DET'),
#  ('anticipating', 'NOUN'),
#  ('Mitsui', 'NOUN'),
#  ('student', 'NOUN'),
#  ('further', 'ADJ'),
#  ('that', 'ADP'),
#  ('0', 'X'),
#  ('County', 'NOUN'),
#  ('down', 'ADV'),
#  ('right', 'NOUN'),
#  ('sources', 'NOUN'),
#  ('the', 'DET'),
#  ('$', '.'),
#  ('WHAS', 'NOUN'),
#  ('after', 'ADP'),
#  ('indexers', 'NOUN'),
#  ('It', 'PRON'),
#  ('USX', 'NOUN'),
#  ('shares', 'NOUN'),
#  ('niches', 'NOUN'),
#  ('could', 'VERB'),
#  ('is', 'VERB'),
#  (',', '.'),
#  ('the', 'DET'),
#  ('retailing', 'NOUN'),
#  (',', '.'),
#  ('answers', 'NOUN'),
#  ('to', 'PRT'),
#  ('*T*-3', 'X'),
#  ('because', 'ADP'),
#  ('is', 'VERB'),
#  ('the', 'DET'),
#  ('the', 'DET'),
#  ('take', 'VERB'),
#  ('Each', 'DET'),
#  ('to', 'PRT'),
#  ('Administration', 'NOUN'),
#  ('3.7', 'NUM'),
#  ('stock', 'NOUN'),
#  ('unchanged', 'ADJ'),
#  ('as', 'ADP'),
#  (',', '.'),
#  ('would', 'VERB'),
#  ('the', 'DET'),
#  ('*', 'X'),
#  ('*-1', 'X'),
#  (',', '.'),
#  ('three', 'NUM'),
#  ('sort', 'NOUN'),
#  ('will', 'VERB'),
#  ('``', '.'),
#  ('notion', 'NOUN'),
#  ('took', 'VERB'),
#  ('.', '.'),
#  ('China', 'NOUN'),
#  (',', '.'),
#  ('cultivation', 'NOUN'),
#  ('units', 'NOUN'),
#  (',', '.'),
#  ('to', 'PRT'),
#  ('freedom', 'NOUN'),
#  ('New', 'NOUN'),
#  ('plunged', 'VERB'),
#  ('field', 'NOUN'),
#  ('*T*-57', 'X'),
#  ('Then', 'ADV'),
#  ('features', 'NOUN'),
#  ('%', 'NOUN'),
#  ('trade', 'NOUN'),
#  ('.', '.'),
#  ('By', 'ADP'),
#  ('investor', 'NOUN'),
#  ('new', 'ADJ'),
#  ("'s", 'PRT'),
#  ('say', 'VERB'),
#  ('main', 'ADJ'),
#  ('of', 'ADP'),
#  ('two', 'NUM'),
#  ('of', 'ADP'),
#  ('the', 'DET'),
#  ('pyramids', 'NOUN'),
#  ('0', 'X'),
#  ('*U*', 'X'),
#  ('trading', 'NOUN'),
#  (',', '.'),
#  ('became', 'VERB'),
#  (',', '.'),
#  ('development', 'NOUN'),
#  ('Jim', 'NOUN'),
#  ('will', 'VERB'),
#  ('the', 'DET'),
#  ('0', 'X'),
#  ('together', 'ADV'),
#  ('Travelers', 'NOUN'),
#  ('.', '.'),
#  ('in', 'ADP'),
#  ('those', 'DET'),
#  ('Mr.', 'NOUN'),
#  (',', '.'),
#  ('constitutional', 'ADJ'),
#  ('38', 'NUM'),
#  ('banks', 'NOUN'),
#  ('0', 'X'),
#  ('enforcement', 'NOUN'),
#  ('While', 'ADP'),
#  ('*T*-155', 'NOUN'),
#  (',', '.'),
#  ('several', 'ADJ'),
#  ('commercial', 'ADJ'),
#  ('ground', 'NOUN'),
#  ('received', 'VERB'),
#  ('some', 'DET'),
#  ('Johns', 'NOUN'),
#  ('that', 'ADP'),
#  ('introduce', 'VERB'),
#  ('Treasury', 'NOUN'),
#  ('as', 'ADP'),
#  ('extend', 'VERB'),
#  ('Sun', 'NOUN'),
#  ('.', '.'),
#  ('pass', 'VERB'),
#  ('advertisers', 'NOUN'),
#  ('to', 'PRT'),
#  ('gives', 'VERB'),
#  ('beverage', 'NOUN'),
#  ('$', '.'),
#  ('Forster', 'NOUN'),
#  ('list', 'NOUN'),
#  ("n't", 'ADV'),
#  ('chief', 'NOUN'),
#  ('billion', 'NUM'),
#  ('airline', 'NOUN'),
#  ('120', 'NUM'),
#  ('Inc.', 'NOUN'),
#  ('pay', 'VERB'),
#  ('``', '.'),
#  ('in', 'ADP'),
#  ('matter', 'NOUN'),
#  ('2.1', 'NUM'),
#  ('--', '.'),
#  ('related', 'VERB'),
#  ('%', 'NOUN'),
#  ('unsettled', 'NOUN'),
#  ('extraordinary', 'ADJ'),
#  ('elementary', 'NOUN'),
#  ('appeals', 'NOUN'),
#  ('because', 'ADP'),
#  ('Negus', 'NOUN'),
#  ('problems', 'NOUN'),
#  ('first', 'ADJ'),
#  ('five-cent', 'NOUN'),
#  ('banks', 'NOUN'),
#  ('.', '.'),
#  ('with', 'ADP'),
#  ('back', 'ADV'),
#  ('Valhi', 'NOUN'),
#  ('Year', 'NOUN'),
#  ('the', 'DET'),
#  ('big', 'ADJ'),
#  (',', '.'),
#  ('bank', 'NOUN'),
#  ('test', 'NOUN'),
#  ('offer', 'NOUN'),
#  ('.', '.'),
#  ('it', 'PRON'),
#  ('for', 'ADP'),
#  ('cigarette', 'NOUN'),
#  ('trade', 'NOUN'),
#  ('days', 'NOUN'),
#  ('*', 'X'),
#  ('rose', 'VERB'),
#  ('going', 'VERB'),
#  ('do', 'VERB'),
#  ('a', 'DET'),
#  ('-RRB-', '.'),
#  ('any', 'DET'),
#  ("'", 'PRT'),
#  ('and', 'CONJ'),
#  ("''", '.'),
#  ('18-a-share', 'NOUN'),
#  ('the', 'DET'),
#  ('growth', 'NOUN'),
#  ('0', 'X'),
#  ('drugs', 'NOUN'),
#  ('were', 'VERB'),
#  ('.', '.'),
#  ('make', 'VERB'),
#  ('unexpected', 'NOUN'),
#  ('*U*', 'X'),
#  ('2', 'NUM'),
#  ('the', 'DET'),
#  ('the', 'DET'),
#  ('and', 'CONJ'),
#  ('*-1', 'X'),
#  (',', '.'),
#  ('.', '.'),
#  (',', '.'),
#  ('*T*-2', 'X'),
#  ("'s", 'PRT'),
#  ('are', 'VERB'),
#  ('trade', 'NOUN'),
#  ('however', 'ADV'),
#  ('Big', 'NOUN'),
#  ('construction', 'NOUN'),
#  ('since', 'ADP'),
#  ('the', 'DET'),
#  ('a', 'DET'),
#  ('from', 'ADP'),
#  ('said', 'VERB'),
#  (',', '.'),
#  ('*T*-1', 'X'),
#  ('.', '.'),
#  ('for', 'ADP'),
#  ('bankrupt', 'NOUN'),
#  ('in', 'ADP'),
#  ('$', '.'),
#  ('offered', 'VERB'),
#  ('from', 'ADP'),
#  ('-RRB-', '.'),
#  ('Pro-forma', 'NOUN'),
#  ('*U*', 'X'),
#  ('at', 'ADP'),
#  ("'s", 'PRT'),
#  ('*T*-2', 'X'),
#  ('expected', 'VERB'),
#  ('Service', 'NOUN'),
#  ('placing', 'VERB'),
#  ('his', 'PRON'),
#  ('performance', 'NOUN'),
#  ('the', 'DET'),
#  ("'s", 'PRT'),
#  ('was', 'VERB'),
#  ('is', 'VERB'),
#  ('hand', 'NOUN'),
#  ('.', '.'),
#  ('forecast', 'NOUN'),
#  ('was', 'VERB'),
#  ('Hugo', 'NOUN'),
#  ('subindustry', 'NOUN'),
#  ('from', 'ADP'),
#  ('included', 'VERB'),
#  ('guild', 'NOUN'),
#  ('*U*', 'X'),
#  ('.', '.'),
#  ('of', 'ADP'),
#  ("''", '.'),
#  ('the', 'DET'),
#  ('said', 'VERB'),
#  ('*T*-1', 'X'),
#  ('the', 'DET'),
#  ('0', 'X'),
#  ("'", 'PRT'),
#  ('billion', 'NUM'),
#  ('company', 'NOUN'),
#  ('sale', 'NOUN'),
#  ('for', 'ADP'),
#  ('Nippon', 'NOUN'),
#  ('their', 'PRON'),
#  (',', '.'),
#  ('Japanese', 'ADJ'),
#  ('one', 'NUM'),
#  ('who', 'PRON'),
#  ('gunship', 'NOUN'),
#  (',', '.'),
#  ('Your', 'PRON'),
#  ("'s", 'PRT'),
#  ('are', 'VERB'),
#  ("n't", 'ADV'),
#  ('probably', 'ADV'),
#  ('.', '.'),
#  ('from', 'ADP'),
#  ('and', 'CONJ'),
#  ('interests', 'NOUN'),
#  ('supercomputer', 'NOUN'),
#  ('to', 'PRT'),
#  ('liability', 'NOUN'),
#  ('of', 'ADP'),
#  ('bonds', 'NOUN'),
#  ('$', '.'),
#  ('bottle', 'NOUN'),
#  ('the', 'DET'),
#  ('their', 'PRON'),
#  ('market', 'NOUN'),
#  ('in', 'ADP'),
#  ('Japanese', 'ADJ'),
#  ('year', 'NOUN'),
#  ('whipping', 'NOUN'),
#  ('modestly', 'ADV'),
#  ('his', 'PRON'),
#  ('of', 'ADP'),
#  ('find', 'VERB'),
#  ('process', 'NOUN'),
#  ('two', 'NUM'),
#  (',', '.'),
#  ('1990s', 'NUM'),
#  ('30', 'NUM'),
#  (',', '.'),
#  ('friendship', 'NOUN'),
#  ('demand', 'NOUN'),
#  ('stock', 'NOUN'),
#  ('protesters', 'NOUN'),
#  ('rose', 'VERB'),
#  ('has', 'VERB'),
#  ('goods', 'NOUN'),
#  ('.', '.'),
#  ('company', 'NOUN'),
#  ('these', 'DET'),
#  ('COMMUNICATIONS', 'NOUN'),
#  ('article', 'NOUN'),
#  ('an', 'DET'),
#  ('on', 'ADP'),
#  (',', '.'),
#  ('expelled', 'VERB'),
#  ('on', 'ADP'),
#  ('some', 'DET'),
#  ('Altogether', 'NOUN'),
#  ('he', 'PRON'),
#  (',', '.'),
#  ('in', 'ADP'),
#  ('big', 'ADJ'),
#  ('notes', 'NOUN'),
#  ('ban', 'NOUN'),
#  ('Sales', 'NOUN'),
#  ('in', 'ADP'),
#  ('underwriter', 'NOUN'),
#  ('%', 'NOUN'),
#  ('The', 'DET'),
#  ('of', 'ADP'),
#  ('0', 'X'),
#  ('index', 'NOUN'),
#  (',', '.'),
#  ('*T*-1', 'X'),
#  ('billion', 'NUM'),
#  ('during', 'ADP'),
#  ('those', 'DET'),
#  (',', '.'),
#  ('in', 'ADP'),
#  (',', '.'),
#  ('.', '.'),
#  ('choosing', 'VERB'),
#  ('positions', 'NOUN'),
#  ('absorbed', 'VERB'),
#  ('Christopher', 'NOUN'),
#  ('the', 'DET'),
#  ('D.', 'NOUN'),
#  ('Toronto', 'NOUN'),
#  ('as', 'ADP'),
#  ('*T*-31', 'X'),
#  ('deviant', 'NOUN'),
#  ('*', 'X'),
#  ('.', '.'),
#  ('2', 'NUM'),
#  ('*T*-1', 'X'),
#  ('tumbled', 'VERB'),
#  ('companies', 'NOUN'),
#  ('even', 'ADV'),
#  ('Mexico', 'NOUN'),
#  ('outbid', 'NOUN'),
#  ('researchers', 'NOUN'),
#  ('the', 'DET'),
#  ('also', 'ADV'),
#  ('seeing', 'VERB'),
#  ('the', 'DET'),
#  ('on', 'ADP'),
#  ('Mr.', 'NOUN'),
#  ('years', 'NOUN'),
#  ('more', 'ADJ'),
#  ('for', 'ADP'),
#  ('excessive', 'ADJ'),
#  ('Nelson', 'NOUN'),
#  ('help', 'VERB'),
#  ('probably', 'ADV'),
#  ('president', 'NOUN'),
#  ('fixed', 'VERB'),
#  ('of', 'ADP'),
#  ('the', 'DET'),
#  ('Previously', 'ADV'),
#  ('extent', 'NOUN'),
#  ('University', 'NOUN'),
#  ('been', 'VERB'),
#  (',', '.'),
#  ('minimum', 'ADJ'),
#  ('.', '.'),
#  ('Mrs.', 'NOUN'),
#  ('shipyard', 'NOUN'),
#  ('it', 'PRON'),
#  ('conference', 'NOUN'),
#  ('certain', 'ADJ'),
#  ('new', 'ADJ'),
#  ('semiliterate', 'NOUN'),
#  ('0', 'X'),
#  ('said', 'VERB'),
#  ('stock-index', 'NOUN'),
#  ('of', 'ADP'),
#  ('insiders', 'NOUN'),
#  (',', '.'),
#  ('near', 'ADP'),
#  ('in', 'ADP'),
#  ('*U*', 'X'),
#  ('seven', 'NUM'),
#  (',', '.'),
#  ('president', 'NOUN'),
#  ('Used', 'NOUN'),
#  ('was', 'VERB'),
#  ('fully', 'ADV'),
#  ('Johnny', 'NOUN'),
#  ('other', 'ADJ'),
#  ('is', 'VERB'),
#  ('be', 'VERB'),
#  ('Ford', 'NOUN'),
#  ('Imports', 'NOUN'),
#  ('could', 'VERB'),
#  ('.', '.'),
#  ('a', 'DET'),
#  ('.', '.'),
#  ('us', 'PRON'),
#  ('stock', 'NOUN'),
#  ('hauling', 'NOUN'),
#  ('International', 'NOUN'),
#  ('of', 'ADP'),
#  ('*', 'X'),
#  ('a', 'DET'),
#  ('fell', 'VERB'),
#  ('its', 'PRON'),
#  ('Donald', 'NOUN'),
#  ('group', 'NOUN'),
#  ('billion', 'NUM'),
#  ('.', '.'),
#  ('investments', 'NOUN'),
#  ('that', 'ADP'),
#  ('Angeles', 'NOUN'),
#  ('that', 'ADP'),
#  ('refinery', 'NOUN'),
#  ('the', 'DET'),
#  ('trade', 'NOUN'),
#  ('for', 'ADP'),
#  ('judges', 'NOUN'),
#  ('fined', 'VERB'),
#  ('Department', 'NOUN'),
#  (',', '.'),
#  ('*U*', 'X'),
#  ('If', 'ADP'),
#  ('fields', 'NOUN'),
#  ('as', 'ADP'),
#  ("'s", 'PRT'),
#  ('would', 'VERB'),
#  ('7.88', 'NUM'),
#  ('moves', 'NOUN'),
#  ('Boston', 'NOUN'),
#  ('*U*', 'X'),
#  ('managers', 'NOUN'),
#  (',', '.'),
#  ('*-1', 'X'),
#  ('.', '.'),
#  ('.', '.'),
#  ('of', 'ADP'),
#  ('what', 'PRON'),
#  ('The', 'DET'),
#  ('expected', 'VERB'),
#  ('raise', 'VERB'),
#  ('bad', 'ADJ'),
#  ('was', 'VERB'),
#  ('%', 'NOUN'),
#  ('soared', 'VERB'),
#  ('of', 'ADP'),
#  ('cars', 'NOUN'),
#  ('is', 'VERB'),
#  ('deals', 'NOUN'),
#  ('executive', 'NOUN'),
#  ('.', '.'),
#  ('newspapers', 'NOUN'),
#  (',', '.'),
#  ('relations', 'NOUN'),
#  ('of', 'ADP'),
#  ('other', 'ADJ'),
#  ('is', 'VERB'),
#  ('performance', 'NOUN'),
#  ('to', 'PRT'),
#  ('assets', 'NOUN'),
#  ('joining', 'VERB'),
#  ('the', 'DET'),
#  ('.', '.'),
#  ('have', 'VERB'),
#  ('``', '.'),
#  ('Congress', 'NOUN'),
#  ('to', 'PRT'),
#  ('declined', 'VERB'),
#  ('editor', 'NOUN'),
#  ('are', 'VERB'),
#  ('We', 'PRON'),
#  ('*ICH*-1', 'X'),
#  ('thrifts', 'NOUN'),
#  (',', '.'),
#  ('independent', 'ADJ'),
#  ('board', 'NOUN'),
#  (',', '.'),
#  ('the', 'DET'),
#  ('*-2', 'X'),
#  (',', '.'),
#  (',', '.'),
#  ('she', 'PRON'),
#  ('fixed', 'VERB'),
#  ("'re", 'VERB'),
#  ('lying', 'VERB'),
#  ('&', 'CONJ'),
#  ('profit', 'NOUN'),
#  ('of', 'ADP'),
#  ('.', '.'),
#  ('advertise', 'VERB'),
#  ('Friedrichs', 'NOUN'),
#  ('the', 'DET'),
#  ('to', 'PRT'),
#  ('Black', 'NOUN'),
#  ('demand', 'NOUN'),
#  ('number', 'NOUN'),
#  (',', '.'),
#  ('new', 'ADJ'),
#  ('the', 'DET'),
#  ('omnipresent', 'NOUN'),
#  ('a', 'DET'),
#  ('the', 'DET'),
#  ('earlier', 'ADJ'),
#  ('young', 'ADJ'),
#  ('plant', 'NOUN'),
#  ('Scoring', 'NOUN'),
#  ('750', 'NUM'),
#  ('even', 'ADV'),
#  ('to', 'PRT'),
#  ('been', 'VERB'),
#  ('not', 'ADV'),
#  ('*', 'X'),
#  ('*T*-55', 'X'),
#  ('and', 'CONJ'),
#  ('of', 'ADP'),
#  ('says', 'VERB'),
#  (',', '.'),
#  ('*U*', 'X'),
#  ('NBI', 'NOUN'),
#  ('$', '.'),
#  ('*-1', 'X'),
#  ('including', 'VERB'),
#  ('to', 'PRT'),
#  ('*-1', 'X'),
#  ('of', 'ADP'),
#  ('Poland', 'NOUN'),
#  ('people', 'NOUN'),
#  ('amount', 'NOUN'),
#  ('says', 'VERB'),
#  ('*T*-1', 'X'),
#  ('what', 'PRON'),
#  ('sentiment', 'NOUN'),
#  ('Elisabeth', 'NOUN'),
#  ('the', 'DET'),
#  ('Chicago', 'NOUN'),
#  ('new', 'ADJ'),
#  ('crystals', 'NOUN'),
#  ('But', 'CONJ'),
#  ('29.9', 'NOUN'),
#  ('program', 'NOUN'),
#  ('rather', 'ADV'),
#  ('would', 'VERB'),
#  ('*-1', 'X'),
#  (',', '.'),
#  ('Among', 'ADP'),
#  ('by', 'ADP'),
#  ('was', 'VERB'),
#  ('-LRB-', '.'),
#  ('which', 'DET'),
#  ('ones', 'NOUN'),
#  ('We', 'PRON'),
#  ('%', 'NOUN'),
#  ('loss', 'NOUN'),
#  ('in', 'ADP'),
#  ('improvement', 'NOUN'),
#  ('``', '.'),
#  ('consumer', 'NOUN'),
#  ('the', 'DET'),
#  (',', '.'),
#  ('RMS', 'NOUN'),
#  ('to', 'PRT'),
#  ('prices', 'NOUN'),
#  ('which', 'DET'),
#  ('lesser', 'NOUN'),
#  ('Newsweek', 'NOUN'),
#  ('.', '.'),
#  ('*-3', 'X'),
#  ('Dominion', 'NOUN'),
#  ('a', 'DET'),
#  ('*-2', 'X'),
#  ('Wednesday', 'NOUN'),
#  ('of', 'ADP'),
#  ('losses', 'NOUN'),
#  ('*', 'X'),
#  ('Mr.', 'NOUN'),
#  ('.', '.'),
#  ('but', 'CONJ'),
#  ('.', '.'),
#  ('rose', 'VERB'),
#  ('Korea', 'NOUN'),
#  ('to', 'PRT'),
#  ('the', 'DET'),
#  ('farm', 'NOUN'),
#  ('conditions', 'NOUN'),
#  ('investor', 'NOUN'),
#  ('of', 'ADP'),
#  ('.', '.'),
#  ('have', 'VERB'),
#  ('have', 'VERB'),
#  ('the', 'DET'),
#  ('write-downs', 'NOUN'),
#  ('researchers', 'NOUN'),
#  ('and', 'CONJ'),
#  ('to', 'PRT'),
#  ('Its', 'PRON'),
#  ('William', 'NOUN'),
#  ('paid', 'VERB'),
#  ('Dover', 'NOUN'),
#  ('45', 'NUM'),
#  ('installment', 'NOUN'),
#  (',', '.'),
#  ('earnings', 'NOUN'),
#  ('allegedly', 'ADV'),
#  ('He', 'PRON'),
#  ('were', 'VERB'),
#  ('0', 'X'),
#  ('deposit', 'NOUN'),
#  ('allow', 'VERB'),
#  ('the', 'DET'),
#  ('a', 'DET'),
#  ('walls', 'NOUN'),
#  ('9.9', 'NUM'),
#  ('health', 'NOUN'),
#  ('the', 'DET'),
#  (',', '.'),
#  ('U.S.', 'NOUN'),
#  ('*', 'X'),
#  ('hoped', 'NOUN'),
#  ('days', 'NOUN'),
#  ('be', 'VERB'),
#  ('*-2', 'X'),
#  ('down', 'ADV'),
#  ('chief', 'NOUN'),
#  ('offer', 'NOUN'),
#  ('--', '.'),
#  ('victims', 'NOUN'),
#  ('change', 'NOUN'),
#  ('dissemination', 'NOUN'),
#  ('less', 'ADJ'),
#  ('Its', 'PRON'),
#  ('from', 'ADP'),
#  ('fees', 'NOUN'),
#  ('Tribune', 'NOUN'),
#  ("''", '.'),
#  ('*T*-1', 'X'),
#  ('most', 'ADJ'),
#  ('Coleco', 'NOUN'),
#  ('and', 'CONJ'),
#  ('Despite', 'ADP'),
#  ('the', 'DET'),
#  ('two', 'NUM'),
#  ('found', 'VERB'),
#  ('*-2', 'X'),
#  ('Rapanelli', 'NOUN'),
#  ('between', 'ADP'),
#  ('result', 'VERB'),
#  ('than', 'ADP'),
#  ('link', 'NOUN'),
#  ('one', 'NUM'),
#  ('year', 'NOUN'),
#  ('for', 'ADP'),
#  ('Still', 'ADV'),
#  ('a', 'DET'),
#  ('special', 'ADJ'),
#  ('.', '.'),
#  ('.', '.'),
#  ('the', 'DET'),
#  ('.', '.'),
#  ('unless', 'ADP'),
#  ('Iowa', 'NOUN'),
#  ("''", '.'),
#  ('with', 'ADP'),
#  ('*-2', 'X'),
#  (',', '.'),
#  ('see', 'VERB'),
#  ('completed', 'VERB'),
#  ('.', '.'),
#  ('from', 'ADP'),
#  ('in', 'ADP'),
#  ('customers', 'NOUN'),
#  ('September', 'NOUN'),
#  ('students', 'NOUN'),
#  ('could', 'VERB'),
#  ('ever', 'ADV'),
#  ('*-1', 'X'),
#  ('off', 'PRT'),
#  ("''", '.'),
#  ('Chicago', 'NOUN'),
#  ('Columbia', 'NOUN'),
#  ('become', 'VERB'),
#  ('they', 'PRON'),
#  ('Bund', 'NOUN'),
#  ('*-101', 'NOUN'),
#  ('and', 'CONJ'),
#  ('clerics', 'NOUN'),
#  ('his', 'PRON'),
#  ('certain', 'ADJ'),
#  ('amicable', 'NOUN'),
#  ('almost', 'ADV'),
#  ('$', '.'),
#  ('on', 'ADP'),
#  ('of', 'ADP'),
#  ('profit', 'NOUN'),
#  ('as', 'ADP'),
#  ('*T*-3', 'X'),
#  ('departure', 'NOUN'),
#  ('would', 'VERB'),
#  ('smiles', 'NOUN'),
#  ('0', 'X'),
#  ('*T*-1', 'X'),
#  ('trade', 'NOUN'),
#  ('10', 'NUM'),
#  ('about', 'ADP'),
#  ('decision', 'NOUN'),
#  ('.', '.'),
#  ('selected', 'VERB'),
#  ('type', 'NOUN'),
#  ('*T*-2', 'X'),
#  ('High', 'NOUN'),
#  ('campaigning', 'NOUN'),
#  ('futures', 'NOUN'),
#  ('of', 'ADP'),
#  ('highly', 'ADV'),
#  ('.', '.'),
#  ('chairman', 'NOUN'),
#  ('decline', 'NOUN'),
#  ('down', 'ADV'),
#  (',', '.'),
#  ('advertising', 'NOUN'),
#  ('least', 'ADJ'),
#  ('.', '.'),
#  ('he', 'PRON'),
#  ('government', 'NOUN'),
#  ('15', 'NUM'),
#  ("'s", 'PRT'),
#  ('--', '.'),
#  ('have', 'VERB'),
#  ('``', '.'),
#  ('Sen.', 'NOUN'),
#  ('*-1', 'X'),
#  ('of', 'ADP'),
#  ('anti-drug', 'NOUN'),
#  ('run', 'VERB'),
#  ('legal', 'ADJ'),
#  ('about', 'ADP'),
#  ('and', 'CONJ'),
#  ('other', 'ADJ'),
#  ('1', 'NUM'),
#  ('river', 'NOUN'),
#  ('Something', 'NOUN'),
#  ('classics', 'NOUN'),
#  ('is', 'VERB'),
#  ('Home', 'NOUN'),
#  ('.', '.'),
#  ('actions', 'NOUN'),
#  ('It', 'PRON'),
#  ('it', 'PRON'),
#  ('days', 'NOUN'),
#  ('was', 'VERB'),
#  ('The', 'DET'),
#  ('he', 'PRON'),
#  ('proportion', 'NOUN'),
#  ('the', 'DET'),
#  ('panel', 'NOUN'),
#  ('80', 'NUM'),
#  ('.', '.'),
#  ('breaks', 'VERB'),
#  ('approved', 'VERB'),
#  ('legislators', 'NOUN'),
#  ('citing', 'VERB'),
#  ('it', 'PRON'),
#  ('feel', 'VERB'),
#  ('*T*-1', 'X'),
#  ('*T*-1', 'X'),
#  ('sure', 'ADJ'),
#  ('$', '.'),
#  ('private', 'ADJ'),
#  ('N.C.', 'NOUN'),
#  ("'s", 'PRT'),
#  ('Stories', 'NOUN'),
#  (',', '.'),
#  ('Crane', 'NOUN'),
#  ('by', 'ADP'),
#  ('Prater', 'NOUN'),
#  ('if', 'ADP'),
#  ('during', 'ADP'),
#  ('Says', 'VERB'),
#  ('of', 'ADP'),
#  ...]

# %% [markdown]
# ### Compare the tagging accuracies of the modifications with the vanilla Viterbi algorithm

# %%
# accuracy for vanilla Viterbi Algorithm
check = [i for i, j in zip(tagged_seq, test_set) if i == j] 
accuracy = len(check)/len(tagged_seq)
accuracy
# Out:
# 0.9119984108065157

# %%
# accuracy for modification technique 1
check = [i for i, j in zip(tagged_seq1, test_set) if i == j] 
accuracy = len(check)/len(tagged_seq1)
accuracy
# Out:
# 0.9447755264203417

# %%
# accuracy for modification technique 2
check = [i for i, j in zip(tagged_seq2, test_set) if i == j] 
accuracy = len(check)/len(tagged_seq2)
accuracy
# Out:
# 0.9398092967818832

# %% [markdown]
# ### List down cases which were incorrectly tagged by original POS tagger and got corrected by your modifications

# %%
# Testing Vanilla Viterbi on test sentences
test_tagged_seq = Viterbi(word_list)
test_tagged_seq
# Out:
# [('with', 'ADP'),
#  ('2018', 'NUM'),
#  ('as', 'ADP'),
#  ('NASA', 'NUM'),
#  ('and', 'CONJ'),
#  (',', '.'),
#  ('flights', 'NOUN'),
#  ('at', 'ADP'),
#  ('mobile', 'ADJ'),
#  ('system', 'NOUN'),
#  ('Dallas', 'NOUN'),
#  ('2011', 'NUM'),
#  ('Francisco', 'NOUN'),
#  ('Eastern', 'NOUN'),
#  ('experience', 'NOUN'),
#  ('I', 'PRON'),
#  ('tournament', 'NUM'),
#  ('ICESAT-2', 'NUM'),
#  ('businessman', 'NOUN'),
#  ('has', 'VERB'),
#  ('tablets', 'NOUN'),
#  ('operating', 'NOUN'),
#  ('access', 'NOUN'),
#  ('first', 'ADJ'),
#  ('service', 'NOUN'),
#  ('Donald', 'NOUN'),
#  ('2015', 'NUM'),
#  ('to', 'PRT'),
#  ('interact', 'NUM'),
#  ('which', 'DET'),
#  ('launch', 'NOUN'),
#  ('round', 'NOUN'),
#  ('Philadelphia', 'NOUN'),
#  ('San', 'NOUN'),
#  ('best-selling', 'ADJ'),
#  ('domineering', 'NUM'),
#  ('Before', 'ADP'),
#  ('once', 'ADV'),
#  ('time', 'NOUN'),
#  ('Android', 'NUM'),
#  ('see', 'VERB'),
#  ('been', 'VERB'),
#  ('known', 'VERB'),
#  ('developed', 'VERB'),
#  ('in', 'ADP'),
#  ('made', 'VERB'),
#  ('gave', 'VERB'),
#  ('international', 'ADJ'),
#  ('it', 'PRON'),
#  ('social', 'ADJ'),
#  ('Atlanta', 'NOUN'),
#  ("'s", 'PRT'),
#  ('would', 'VERB'),
#  ('was', 'VERB'),
#  ('me', 'PRON'),
#  ('Cup', 'NUM'),
#  ('contested', 'NUM'),
#  ('about', 'ADP'),
#  ('afternoon', 'NOUN'),
#  ('post', 'NOUN'),
#  ('deal', 'NOUN'),
#  ('invited', 'NUM'),
#  ('by', 'ADP'),
#  ('FIFA', 'NUM'),
#  ('trips', 'NUM'),
#  ('Trump', 'NOUN'),
#  ('This', 'DET'),
#  ('users', 'NOUN'),
#  ('television', 'NOUN'),
#  ('Satellite', 'NUM'),
#  ('cheapest', 'ADJ'),
#  ('tweets', 'NUM'),
#  ('politics', 'NOUN'),
#  ('football', 'NOUN'),
#  ('is', 'VERB'),
#  ('leaving', 'VERB'),
#  ('media', 'NOUN'),
#  ('11th', 'ADJ'),
#  ('price', 'NOUN'),
#  ('3', 'NUM'),
#  ('World', 'NOUN'),
#  ('that', 'ADP'),
#  ('Twitter', 'NUM'),
#  ('Google', 'NUM'),
#  ('messages', 'NUM'),
#  ('the', 'DET'),
#  ('held', 'VERB'),
#  ('smartphones', 'NUM'),
#  ('21st', 'NUM'),
#  ('a', 'DET'),
#  ('personality', 'NUM'),
#  ('every', 'DET'),
#  ('since', 'ADP'),
#  ('2013', 'NUM'),
#  ('Denver', 'NOUN'),
#  ('arriving', 'NUM'),
#  ('The', 'DET'),
#  ('worldwide', 'NUM'),
#  ('like', 'ADP'),
#  ('Show', 'NOUN'),
#  ('of', 'ADP'),
#  ('be', 'VERB'),
#  ('entering', 'VERB'),
#  ('OS', 'NUM'),
#  ('on', 'ADP'),
#  ('firehose', 'NUM'),
#  ('an', 'DET'),
#  ('Europe', 'NOUN'),
#  ('news', 'NOUN'),
#  ('years', 'NOUN'),
#  ('four', 'NUM'),
#  ('from', 'ADP'),
#  ('.', '.'),
#  ('online', 'NUM'),
#  ('networking', 'NOUN')]

# %%
# Testing Viterbi Modifiction Technique 1 on test sentences
test_tagged_seq1 = Viterbi1(word_list)
test_tagged_seq1
# Out:
# [('with', 'ADP'),
#  ('2018', 'NUM'),
#  ('as', 'ADP'),
#  ('NASA', 'NOUN'),
#  ('and', 'CONJ'),
#  (',', '.'),
#  ('flights', 'NOUN'),
#  ('at', 'ADP'),
#  ('mobile', 'ADJ'),
#  ('system', 'NOUN'),
#  ('Dallas', 'NOUN'),
#  ('2011', 'NUM'),
#  ('Francisco', 'NOUN'),
#  ('Eastern', 'NOUN'),
#  ('experience', 'NOUN'),
#  ('I', 'PRON'),
#  ('tournament', 'NOUN'),
#  ('ICESAT-2', 'NOUN'),
#  ('businessman', 'NOUN'),
#  ('has', 'VERB'),
#  ('tablets', 'NOUN'),
#  ('operating', 'NOUN'),
#  ('access', 'NOUN'),
#  ('first', 'ADJ'),
#  ('service', 'NOUN'),
#  ('Donald', 'NOUN'),
#  ('2015', 'NUM'),
#  ('to', 'PRT'),
#  ('interact', 'NOUN'),
#  ('which', 'DET'),
#  ('launch', 'NOUN'),
#  ('round', 'NOUN'),
#  ('Philadelphia', 'NOUN'),
#  ('San', 'NOUN'),
#  ('best-selling', 'ADJ'),
#  ('domineering', 'NOUN'),
#  ('Before', 'ADP'),
#  ('once', 'ADV'),
#  ('time', 'NOUN'),
#  ('Android', 'NOUN'),
#  ('see', 'VERB'),
#  ('been', 'VERB'),
#  ('known', 'VERB'),
#  ('developed', 'VERB'),
#  ('in', 'ADP'),
#  ('made', 'VERB'),
#  ('gave', 'VERB'),
#  ('international', 'ADJ'),
#  ('it', 'PRON'),
#  ('social', 'ADJ'),
#  ('Atlanta', 'NOUN'),
#  ("'s", 'PRT'),
#  ('would', 'VERB'),
#  ('was', 'VERB'),
#  ('me', 'PRON'),
#  ('Cup', 'NOUN'),
#  ('contested', 'NOUN'),
#  ('about', 'ADP'),
#  ('afternoon', 'NOUN'),
#  ('post', 'NOUN'),
#  ('deal', 'NOUN'),
#  ('invited', 'NOUN'),
#  ('by', 'ADP'),
#  ('FIFA', 'NOUN'),
#  ('trips', 'NOUN'),
#  ('Trump', 'NOUN'),
#  ('This', 'DET'),
#  ('users', 'NOUN'),
#  ('television', 'NOUN'),
#  ('Satellite', 'NOUN'),
#  ('cheapest', 'ADJ'),
#  ('tweets', 'NOUN'),
#  ('politics', 'NOUN'),
#  ('football', 'NOUN'),
#  ('is', 'VERB'),
#  ('leaving', 'VERB'),
#  ('media', 'NOUN'),
#  ('11th', 'ADJ'),
#  ('price', 'NOUN'),
#  ('3', 'NUM'),
#  ('World', 'NOUN'),
#  ('that', 'ADP'),
#  ('Twitter', 'NOUN'),
#  ('Google', 'NOUN'),
#  ('messages', 'NOUN'),
#  ('the', 'DET'),
#  ('held', 'VERB'),
#  ('smartphones', 'NOUN'),
#  ('21st', 'NUM'),
#  ('a', 'DET'),
#  ('personality', 'NOUN'),
#  ('every', 'DET'),
#  ('since', 'ADP'),
#  ('2013', 'NUM'),
#  ('Denver', 'NOUN'),
#  ('arriving', 'NOUN'),
#  ('The', 'DET'),
#  ('worldwide', 'NOUN'),
#  ('like', 'ADP'),
#  ('Show', 'NOUN'),
#  ('of', 'ADP'),
#  ('be', 'VERB'),
#  ('entering', 'VERB'),
#  ('OS', 'NOUN'),
#  ('on', 'ADP'),
#  ('firehose', 'NOUN'),
#  ('an', 'DET'),
#  ('Europe', 'NOUN'),
#  ('news', 'NOUN'),
#  ('years', 'NOUN'),
#  ('four', 'NUM'),
#  ('from', 'ADP'),
#  ('.', '.'),
#  ('online', 'NOUN'),
#  ('networking', 'NOUN')]

# %%
# Testing Viterbi Modifiction Technique 2 on test sentences
test_tagged_seq2 = Viterbi2(word_list)
test_tagged_seq2
# Out:
# [('with', 'ADP'),
#  ('2018', 'NOUN'),
#  ('as', 'ADP'),
#  ('NASA', 'NOUN'),
#  ('and', 'CONJ'),
#  (',', '.'),
#  ('flights', 'NOUN'),
#  ('at', 'ADP'),
#  ('mobile', 'ADJ'),
#  ('system', 'NOUN'),
#  ('Dallas', 'NOUN'),
#  ('2011', 'NOUN'),
#  ('Francisco', 'NOUN'),
#  ('Eastern', 'NOUN'),
#  ('experience', 'NOUN'),
#  ('I', 'PRON'),
#  ('tournament', 'NOUN'),
#  ('ICESAT-2', 'NOUN'),
#  ('businessman', 'NOUN'),
#  ('has', 'VERB'),
#  ('tablets', 'NOUN'),
#  ('operating', 'NOUN'),
#  ('access', 'NOUN'),
#  ('first', 'ADJ'),
#  ('service', 'NOUN'),
#  ('Donald', 'NOUN'),
#  ('2015', 'NOUN'),
#  ('to', 'PRT'),
#  ('interact', 'NOUN'),
#  ('which', 'DET'),
#  ('launch', 'NOUN'),
#  ('round', 'NOUN'),
#  ('Philadelphia', 'NOUN'),
#  ('San', 'NOUN'),
#  ('best-selling', 'ADJ'),
#  ('domineering', 'NOUN'),
#  ('Before', 'ADP'),
#  ('once', 'ADV'),
#  ('time', 'NOUN'),
#  ('Android', 'NOUN'),
#  ('see', 'VERB'),
#  ('been', 'VERB'),
#  ('known', 'VERB'),
#  ('developed', 'VERB'),
#  ('in', 'ADP'),
#  ('made', 'VERB'),
#  ('gave', 'VERB'),
#  ('international', 'ADJ'),
#  ('it', 'PRON'),
#  ('social', 'ADJ'),
#  ('Atlanta', 'NOUN'),
#  ("'s", 'PRT'),
#  ('would', 'VERB'),
#  ('was', 'VERB'),
#  ('me', 'PRON'),
#  ('Cup', 'NOUN'),
#  ('contested', 'NOUN'),
#  ('about', 'ADP'),
#  ('afternoon', 'NOUN'),
#  ('post', 'NOUN'),
#  ('deal', 'NOUN'),
#  ('invited', 'NOUN'),
#  ('by', 'ADP'),
#  ('FIFA', 'NOUN'),
#  ('trips', 'NOUN'),
#  ('Trump', 'NOUN'),
#  ('This', 'DET'),
#  ('users', 'NOUN'),
#  ('television', 'NOUN'),
#  ('Satellite', 'NOUN'),
#  ('cheapest', 'ADJ'),
#  ('tweets', 'NOUN'),
#  ('politics', 'NOUN'),
#  ('football', 'NOUN'),
#  ('is', 'VERB'),
#  ('leaving', 'VERB'),
#  ('media', 'NOUN'),
#  ('11th', 'ADJ'),
#  ('price', 'NOUN'),
#  ('3', 'NUM'),
#  ('World', 'NOUN'),
#  ('that', 'ADP'),
#  ('Twitter', 'NOUN'),
#  ('Google', 'NOUN'),
#  ('messages', 'NOUN'),
#  ('the', 'DET'),
#  ('held', 'VERB'),
#  ('smartphones', 'NOUN'),
#  ('21st', 'NOUN'),
#  ('a', 'DET'),
#  ('personality', 'NOUN'),
#  ('every', 'DET'),
#  ('since', 'ADP'),
#  ('2013', 'NOUN'),
#  ('Denver', 'NOUN'),
#  ('arriving', 'NOUN'),
#  ('The', 'DET'),
#  ('worldwide', 'NOUN'),
#  ('like', 'ADP'),
#  ('Show', 'NOUN'),
#  ('of', 'ADP'),
#  ('be', 'VERB'),
#  ('entering', 'VERB'),
#  ('OS', 'NOUN'),
#  ('on', 'ADP'),
#  ('firehose', 'NOUN'),
#  ('an', 'DET'),
#  ('Europe', 'NOUN'),
#  ('news', 'NOUN'),
#  ('years', 'NOUN'),
#  ('four', 'NUM'),
#  ('from', 'ADP'),
#  ('.', '.'),
#  ('online', 'NOUN'),
#  ('networking', 'NOUN')]

# %% [markdown]
# #### Unknown words which were wrongly tagged by vanilla Viterbi tagger

# %%
# Below tags are incorrectly tagged by vailla viterbi
vanilla_incorrect_tags = [j[1] for i, j in enumerate(zip(test_tagged_seq1, test_tagged_seq)) if j[0]!=j[1]]
vanilla_incorrect_tags
# Out:
# [('NASA', 'NUM'),
#  ('tournament', 'NUM'),
#  ('ICESAT-2', 'NUM'),
#  ('interact', 'NUM'),
#  ('domineering', 'NUM'),
#  ('Android', 'NUM'),
#  ('Cup', 'NUM'),
#  ('contested', 'NUM'),
#  ('invited', 'NUM'),
#  ('FIFA', 'NUM'),
#  ('trips', 'NUM'),
#  ('Satellite', 'NUM'),
#  ('tweets', 'NUM'),
#  ('Twitter', 'NUM'),
#  ('Google', 'NUM'),
#  ('messages', 'NUM'),
#  ('smartphones', 'NUM'),
#  ('personality', 'NUM'),
#  ('arriving', 'NUM'),
#  ('worldwide', 'NUM'),
#  ('OS', 'NUM'),
#  ('firehose', 'NUM'),
#  ('online', 'NUM')]

# %% [markdown]
# #### Unknown words for which tags were correctly modified by modification technique 1 (Rule based tagger with Viterbi)

# %%
# Modification 1 technique have modified the tags of words as below
modf1_tags = [j[0] for i, j in enumerate(zip(test_tagged_seq1, test_tagged_seq)) if j[0]!=j[1]]
modf1_tags
# Out:
# [('NASA', 'NOUN'),
#  ('tournament', 'NOUN'),
#  ('ICESAT-2', 'NOUN'),
#  ('interact', 'NOUN'),
#  ('domineering', 'NOUN'),
#  ('Android', 'NOUN'),
#  ('Cup', 'NOUN'),
#  ('contested', 'NOUN'),
#  ('invited', 'NOUN'),
#  ('FIFA', 'NOUN'),
#  ('trips', 'NOUN'),
#  ('Satellite', 'NOUN'),
#  ('tweets', 'NOUN'),
#  ('Twitter', 'NOUN'),
#  ('Google', 'NOUN'),
#  ('messages', 'NOUN'),
#  ('smartphones', 'NOUN'),
#  ('personality', 'NOUN'),
#  ('arriving', 'NOUN'),
#  ('worldwide', 'NOUN'),
#  ('OS', 'NOUN'),
#  ('firehose', 'NOUN'),
#  ('online', 'NOUN')]

# %% [markdown]
# #### Unknown words for which tags were corrected by modification technique 2 (Assigning transistion probabilities to unknown words)

# %%
# Modification 2 technique have modified the tags of words as below
modf2_tags = [j[0] for i, j in enumerate(zip(test_tagged_seq2, test_tagged_seq)) if j[0]!=j[1]]
modf2_tags
# Out:
# [('2018', 'NOUN'),
#  ('NASA', 'NOUN'),
#  ('2011', 'NOUN'),
#  ('tournament', 'NOUN'),
#  ('ICESAT-2', 'NOUN'),
#  ('2015', 'NOUN'),
#  ('interact', 'NOUN'),
#  ('domineering', 'NOUN'),
#  ('Android', 'NOUN'),
#  ('Cup', 'NOUN'),
#  ('contested', 'NOUN'),
#  ('invited', 'NOUN'),
#  ('FIFA', 'NOUN'),
#  ('trips', 'NOUN'),
#  ('Satellite', 'NOUN'),
#  ('tweets', 'NOUN'),
#  ('Twitter', 'NOUN'),
#  ('Google', 'NOUN'),
#  ('messages', 'NOUN'),
#  ('smartphones', 'NOUN'),
#  ('21st', 'NOUN'),
#  ('personality', 'NOUN'),
#  ('2013', 'NOUN'),
#  ('arriving', 'NOUN'),
#  ('worldwide', 'NOUN'),
#  ('OS', 'NOUN'),
#  ('firehose', 'NOUN'),
#  ('online', 'NOUN')]
